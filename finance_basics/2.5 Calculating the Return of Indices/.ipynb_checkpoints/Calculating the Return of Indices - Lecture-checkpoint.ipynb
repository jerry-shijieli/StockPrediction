# %%
import numpy as np
import pandas as pd
from pandas_datareader import data as wb
import matplotlib.pyplot as plt

# %%
tickers = ['^GSPC', '^IXIC', '^GDAXI', '^FTSE']

ind_data = pd.DataFrame()

for t in tickers:
    ind_data[t] = wb.DataReader(t, data_source='yahoo', start='1997-1-1')['Adj Close']

# %%
ind_data.head()
# Out:
#                  ^GSPC        ^IXIC       ^GDAXI        ^FTSE
# Date
# 1997-01-02  737.010010  1280.699951  2848.800049  4057.399902
# 1997-01-03  748.030029  1310.680054  2859.300049  4089.500000
# 1997-01-06  747.650024  1316.400024  2881.300049  4106.500000
# 1997-01-07  753.229980  1327.729980  2886.100098  4078.800049
# 1997-01-08  748.409973  1320.349976  2906.300049  4087.500000

# %%
ind_data.tail()
# Out:
#                   ^GSPC        ^IXIC        ^GDAXI        ^FTSE
# Date
# 2017-03-17  2378.250000  5901.000000  12095.240234  7425.000000
# 2017-03-20  2373.469971  5901.529785  12052.900391  7429.799805
# 2017-03-21  2344.020020  5793.830078  11962.129883  7378.299805
# 2017-03-22  2348.449951  5821.640137  11904.120117  7324.700195
# 2017-03-23  2345.959961  5817.689941  12039.679688  7340.700195

# %%
(ind_data / ind_data.iloc[0] * 100).plot(figsize=(15, 6));
plt.show()

# %%
ind_returns = (ind_data / ind_data.shift(1)) - 1

ind_returns.tail()
# Out:
#                ^GSPC     ^IXIC    ^GDAXI     ^FTSE
# Date
# 2017-03-17 -0.001314  0.000041  0.000998  0.001214
# 2017-03-20 -0.002010  0.000090 -0.003501  0.000646
# 2017-03-21 -0.012408 -0.018249 -0.007531 -0.006932
# 2017-03-22  0.001890  0.004800 -0.004849 -0.007264
# 2017-03-23 -0.001060 -0.000679  0.011388  0.002184

# %%
annual_ind_returns = ind_returns.mean() * 250
annual_ind_returns
# Out:
# ^GSPC     0.075810
# ^IXIC     0.107043
# ^GDAXI    0.088072
# ^FTSE     0.042592
# dtype: float64

# %% [markdown]
# ***

# %%
tickers = ['PG', '^GSPC', '^DJI']

data_2 = pd.DataFrame()

for t in tickers:
    data_2[t] = wb.DataReader(t, data_source='yahoo', start='2007-1-1')['Adj Close']

# %%
data_2.tail()
# Out:
#                    PG        ^GSPC          ^DJI
# Date
# 2017-03-17  91.000000  2378.250000  20914.619141
# 2017-03-20  91.220001  2373.469971  20905.859375
# 2017-03-21  91.190002  2344.020020  20668.009766
# 2017-03-22  90.989998  2348.449951  20661.300781
# 2017-03-23  90.769997  2345.959961  20656.580078

# %%
(data_2 / data_2.iloc[0] * 100).plot(figsize=(15, 6));
plt.show()
