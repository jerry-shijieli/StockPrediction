# %% [markdown]
# ## Simple Returns - Part II

# %% [markdown]
# $$
# \frac{P_1 - P_0}{P_0} = \frac{P_1}{P_0} - 1
# $$

# %%
import numpy as np
import pandas as pd
from pandas_datareader import data as wb
# MSFT = wb.DataReader('MSFT', data_source='yahoo', start='2000-1-1')
data_path = '../dataset/MSFT.csv'
MSFT = pd.read_csv(data_path, header=0, index_col=0)
MSFT['simple_return'] = (MSFT['Adj Close'] / MSFT['Adj Close'].shift(1)) - 1
print MSFT['simple_return']
# Out:
# Date
# 2000-01-03         NaN
# 2000-01-04   -0.033780
# 2000-01-05    0.010544
# 2000-01-06   -0.033498
# 2000-01-07    0.013068
# 2000-01-10    0.007291
# 2000-01-11   -0.025612
# 2000-01-12   -0.032571
# 2000-01-13    0.018901
# 2000-01-14    0.041159
# 2000-01-18    0.027283
# 2000-01-19   -0.072087
# 2000-01-20   -0.009346
# 2000-01-21   -0.021226
# 2000-01-24   -0.024096
# 2000-01-25    0.015432
# 2000-01-26   -0.033435
# 2000-01-27   -0.006289
# 2000-01-28   -0.005063
# 2000-01-31   -0.003817
# 2000-02-01    0.051724
# 2000-02-02   -0.020644
# 2000-02-03    0.027898
# 2000-02-04    0.028347
# 2000-02-07    0.000587
# 2000-02-08    0.031067
# 2000-02-09   -0.054008
# 2000-02-10    0.019231
# 2000-02-11   -0.057193
# 2000-02-14   -0.003127
#                 ...
# 2017-04-06    0.002593
# 2017-04-07   -0.000761
# 2017-04-10   -0.002284
# 2017-04-11   -0.000763
# 2017-04-12   -0.003818
# 2017-04-13   -0.004293
# 2017-04-17    0.008160
# 2017-04-18   -0.001375
# ...

# %% [markdown]
# Plot the simple returns on a graph.

# %%
MSFT['simple_return'].plot(figsize=(15,5))
import matplotlib.pyplot as plt
plt.show()

# %% [markdown]
# Calculate the average daily return.

# %%
avg_return_d = MSFT['simple_return'].mean()
avg_return_d
# Out:
# 0.0002269548939803719

# %% [markdown]
# Estimate the average annual return.

# %%
avg_return_a = MSFT['simple_return'].mean() * 250
avg_return_a
# Out:
# 0.05673872349509298

# %% [markdown]
# Print the percentage version of the result as a float with 2 digits after the decimal point.

# %%
print str(round(avg_return_a, 4)*100) + '%'
# Out:
# 5.67%
