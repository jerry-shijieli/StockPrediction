# %% [markdown]
# Continue with v1, but dynamically update the parameters weekly (5 trading days per week)

# %%
from rectangle_fuzzy import *

import pandas as pd
import numpy as np
import operator
import matplotlib.pyplot as plt
# %matplotlib inline
from time import time

from collections import defaultdict
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error

# %%
# helper functions
def binary_to_decimal(binary, di=0):
    decimal = 0
    for i in range(len(binary)):
        if i<len(binary)-di+1:
            power = len(binary)-(i+1)-di
            decimal += int(binary[i]) * (2**power)
        else:
            power = len(binary)-(i+1)-di
            decimal += int(binary[i]) * (2**(-power))
    return decimal

def universe_partition_adjusted(data, n=10, d1=10, d2=10):
    x_max, x_min = data.max(axis=0), data.min(axis=0)   
    delta = x_max - x_min
    std_val = data.std(axis=0)
    len_val = np.round(std_val / (n+5)) # partition interval
    u_max, u_min = int(x_max+(d2+1)*(delta/100)), int(x_min-(d1+1)*(delta/100)) # bound of universe discourse
    u_b = np.arange(u_min, u_max, step=float(len_val)) # cutting points
    u_discourse = u_b
    return u_discourse

def compute_fitness(data, n, d1, d2, option='Price'):
    reserved_days = 100
    first_date = data['Date'][0] - pd.DateOffset(days=1)
    train_data = data.iloc[:-reserved_days]
    valid_data = data.iloc[-(reserved_days+1):]
    fit_prices = list()
    u_discourse = universe_partition_adjusted(train_data[option], n, d1, d2)
    A_list = set_fuzzy_numbers(u_discourse)
    train_data_membership_series = membership_assignment(train_data[option], fuzzy_numbers=u_discourse)
    transition_FLR = FLR(train_data_membership_series)
    train_data_days = train_data['Date'].apply(lambda x: x-first_date).dt.days.tolist()
    jump_weights = FLR_weight(transition_FLR, train_data_days[:len(transition_FLR)])
    transition_weights = FRG_weight(transition_FLR, train_data_days[:len(transition_FLR)])
    for price in valid_data.iloc[:-1][option]:
        index = get_membership(price, u_discourse)
        next_price = forecast_price(forecast_jump(index, jump_weights, A_list), forecast_transition(index, transition_weights, A_list), gamma=0.9)
        fit_prices.append(next_price)
    return np.sqrt(mean_squared_error(valid_data.iloc[1:][option], fit_prices))

def parameter_tuning_ASHLO(data, option):
    # initialize hyperparameters
    d1_digits = 4
    n_digits = 6
    d2_digits = 4
    population = 20
    iter_max = 100
    pr = 0.1
    pi = 0.9
    # initialize data structures
    dim_IKD = d1_digits+n_digits+d2_digits
    RMSE_list = list() # training data RMSE as fitness function value
    IKD = np.zeros((population, dim_IKD), dtype=int) # individual learning 
    SKD = np.array([]) # social network learning
    RMSE_min = 0 # best fitness value
    for i in range(population):
        for j in range(dim_IKD):
            r = np.random.rand()
            if r>0.5:
                IKD[i, j] = 0
            else:
                IKD[i, j] = 1
        d1 = binary_to_decimal(IKD[i, 0:d1_digits])
        d2 = binary_to_decimal(IKD[i, (d1_digits+n_digits): dim_IKD])
        n_par = binary_to_decimal(IKD[i, d1_digits:(d1_digits+n_digits)])
        rmse = compute_fitness(data, n_par, d1, d2)
        RMSE_list.append(rmse)
    RMSE_min = np.min(RMSE_list) # best individual fitness
    SKD = np.array(IKD[np.argmin(RMSE_list)])
    # learning iterations
    for iter_count in range(iter_max):
        temp_IKD = np.zeros((population, dim_IKD))
        temp_rmse_list = list()
        # learning process
        for i in range(population):
            for j in range(dim_IKD):
                p = np.random.rand()
                if p < pi:
                    r = np.random.rand()
                    if r > 0.5:
                        temp_IKD[i, j] = 1
                elif pi <= p <= pr:
                    temp_IKD[i,j] = IKD[i, j]
                else:
                    temp_IKD[i,j] = SKD[j]
        # update fitness of newly learned knowledge 
        for i in range(population):
            d1 = binary_to_decimal(temp_IKD[i, 0:d1_digits])
            d2 = binary_to_decimal(temp_IKD[i, (d1_digits+n_digits): dim_IKD])
            n_par = binary_to_decimal(temp_IKD[i, d1_digits:(d1_digits+n_digits)])
            rmse = compute_fitness(data, n_par, d1, d2)
            temp_rmse_list.append(rmse)

        # update knowledge base if necessary
        RMSE_max = np.max(RMSE_list) # worst individual fitness
        RMSE_max_index = np.argmax(RMSE_list)
        for i in range(population):
            if temp_rmse_list[i] < RMSE_max:
                IKD[RMSE_max_index] = temp_IKD[i]
                RMSE_list[RMSE_max_index] = temp_rmse_list[i]
                RMSE_max = np.max(RMSE_list)
                RMSE_max_index = np.argmax(RMSE_list)
        temp_rmse_min = np.min(RMSE_list) # best individual fitness
        if RMSE_min > temp_rmse_min:
            SKD = np.array(IKD[np.argmin(RMSE_list)])
            RMSE_min = temp_rmse_min
    # output optimal parameter settings        
    d1 = binary_to_decimal(SKD[0:d1_digits])
    d2 = binary_to_decimal(SKD[(d1_digits+n_digits): ])
    n_par = binary_to_decimal(SKD[d1_digits:(d1_digits+n_digits)])
    return d1, n_par, d2

# %%
# Load data 
start_time = time()
datafile = '../data/IBEX35.csv'
dateparse = lambda x: pd.datetime.strptime(x, '%m/%d/%y')
df = pd.read_csv(datafile, header=0, parse_dates=['Date'], date_parser=dateparse)

split_date = pd.datetime.strptime('2014-12-31', '%Y-%m-%d')
train_data = df[df['Date'] < split_date]
test_data = df[df['Date'] >= split_date]
first_date = train_data['Date'][0] - pd.DateOffset(days=1)

option = 'Price'
update_interval = 1 # days

# %%
# forecasting using test data
start_time = time()
pred_prices = list()
error_percentages = list() # percentage of forecasting residual
actual_prices = test_data[option].tolist()[1:]
indices = test_data.index
for i in range(len(indices)-1):
    print("Iteration #%s" % str(i))
    prev = test_data.iloc[i]
    train_data.append(prev)
    if (i % update_interval)==0:
        print("\tUpdate parameter setting and fuzzy sets ...")
        d1, n_par, d2 = parameter_tuning_ASHLO(train_data, option)
        print("\t\td1=%f, d2=%f, n=%f" % (d1, d2, n_par))
        u_discourse = universe_partition_adjusted(train_data[option], n_par, d1, d2)
        A_list = set_fuzzy_numbers(u_discourse)
        train_data_membership_series = membership_assignment(train_data[option], fuzzy_numbers=u_discourse)
        transition_FLR = FLR(train_data_membership_series)
        train_data_days = train_data['Date'].apply(lambda x: x-first_date).dt.days.tolist() # convert Timedelta to numeric days
        jump_weights = FLR_weight(transition_FLR, train_data_days[:len(transition_FLR)])
        transition_weights = FRG_weight(transition_FLR, train_data_days[:len(transition_FLR)])
    price = prev[option]
    index = get_membership(price, u_discourse)
    next_price = forecast_price(forecast_jump(index, jump_weights, A_list), forecast_transition(index, transition_weights, A_list), gamma=0.9)
    pred_prices.append(next_price)
    pred_ep = (np.abs(actual_prices[i] - next_price)/actual_prices[i])
    error_percentages.append(pred_ep)
    print("\t---- error percentage = %f" % pred_ep)
    
print "RMSE = "+str(np.sqrt(mean_squared_error(actual_prices, pred_prices)))
print("Average Error Percentage = %f" % np.mean(error_percentages))
print "Time cost: "+str(time()-start_time)+" seconds"
# Out:
# Iteration #0
# 	Update parameter setting and fuzzy sets ...
# 		d1=3.000000, d2=15.000000, n=7.000000
# 	---- error percentage = 0.009134
# Iteration #1
# 	Update parameter setting and fuzzy sets ...
# 		d1=3.000000, d2=0.000000, n=7.000000
# 	---- error percentage = 0.010267
# Iteration #2
# 	Update parameter setting and fuzzy sets ...
# 		d1=3.000000, d2=15.000000, n=7.000000
# 	---- error percentage = 0.025011
# Iteration #3
# 	Update parameter setting and fuzzy sets ...
# 		d1=3.000000, d2=4.000000, n=7.000000
# 	---- error percentage = 0.010860
# Iteration #4
# 	Update parameter setting and fuzzy sets ...
# 		d1=3.000000, d2=10.000000, n=7.000000
# 	---- error percentage = 0.010212
# Iteration #5
# 	Update parameter setting and fuzzy sets ...
# 		d1=3.000000, d2=3.000000, n=7.000000
# 	---- error percentage = 0.003451
# Iteration #6
# 	Update parameter setting and fuzzy sets ...
# 		d1=4.000000, d2=0.000000, n=15.000000
# 	---- error percentage = 0.029354
# Iteration #7
# 	Update parameter setting and fuzzy sets ...
# 		d1=3.000000, d2=7.000000, n=7.000000
# 	---- error percentage = 0.001452
# Iteration #8
# 	Update parameter setting and fuzzy sets ...
# 		d1=4.000000, d2=0.000000, n=15.000000
# 	---- error percentage = 0.002852
# Iteration #9
# 	Update parameter setting and fuzzy sets ...
# 		d1=3.000000, d2=0.000000, n=7.000000
# 	---- error percentage = 0.017736
# Iteration #10
# 	Update parameter setting and fuzzy sets ...
# 		d1=3.000000, d2=0.000000, n=7.000000
# 	---- error percentage = 0.000195
# Iteration #11
# 	Update parameter setting and fuzzy sets ...
# 		d1=3.000000, d2=3.000000, n=7.000000
# 	---- error percentage = 0.013949
# Iteration #12
# 	Update parameter setting and fuzzy sets ...
# 		d1=3.000000, d2=10.000000, n=7.000000
# 	---- error percentage = 0.007656
# Iteration #13
# 	Update parameter setting and fuzzy sets ...
# 		d1=3.000000, d2=4.000000, n=7.000000
# 	---- error percentage = 0.011491
# Iteration #14
# 	Update parameter setting and fuzzy sets ...
# 		d1=3.000000, d2=0.000000, n=7.000000
# 	---- error percentage = 0.008705
# Iteration #15
# 	Update parameter setting and fuzzy sets ...
# 		d1=3.000000, d2=0.000000, n=7.000000
# 	---- error percentage = 0.021904
# Iteration #16
# 	Update parameter setting and fuzzy sets ...
# 		d1=3.000000, d2=5.000000, n=7.000000
# 	---- error percentage = 0.012308
# Iteration #17
# 	Update parameter setting and fuzzy sets ...
# 		d1=3.000000, d2=1.000000, n=7.000000
# 	---- error percentage = 0.019799
# Iteration #18
# 	Update parameter setting and fuzzy sets ...
# 		d1=3.000000, d2=3.000000, n=7.000000
# 	---- error percentage = 0.004190
# Iteration #19
# 	Update parameter setting and fuzzy sets ...
# 		d1=3.000000, d2=0.000000, n=7.000000
# 	---- error percentage = 0.031820
# Iteration #20
# 	Update parameter setting and fuzzy sets ...
# 		d1=3.000000, d2=4.000000, n=7.000000
# 	---- error percentage = 0.017987
# Iteration #21
# 	Update parameter setting and fuzzy sets ...
# 		d1=15.000000, d2=6.000000, n=7.000000
# 	---- error percentage = 0.014229
# Iteration #22
# 	Update parameter setting and fuzzy sets ...
# 		d1=6.000000, d2=0.000000, n=24.000000
# 	---- error percentage = 0.002937
# Iteration #23
# 	Update parameter setting and fuzzy sets ...
# 		d1=3.000000, d2=0.000000, n=7.000000
# 	---- error percentage = 0.015314
# Iteration #24
# 	Update parameter setting and fuzzy sets ...
# 		d1=3.000000, d2=2.000000, n=7.000000
# 	---- error percentage = 0.017238
# Iteration #25
# 	Update parameter setting and fuzzy sets ...
# 		d1=3.000000, d2=0.000000, n=7.000000
# 	---- error percentage = 0.008424
# Iteration #26
# 	Update parameter setting and fuzzy sets ...
# 		d1=3.000000, d2=3.000000, n=7.000000
# 	---- error percentage = 0.007043
# Iteration #27
# 	Update parameter setting and fuzzy sets ...
# 		d1=3.000000, d2=11.000000, n=7.000000
# 	---- error percentage = 0.006588
# Iteration #28
# 	Update parameter setting and fuzzy sets ...
# 		d1=3.000000, d2=2.000000, n=7.000000
# 	---- error percentage = 0.011765
# Iteration #29
# 	Update parameter setting and fuzzy sets ...
# 		d1=6.000000, d2=0.000000, n=20.000000
# 	---- error percentage = 0.012281
# Iteration #30
# 	Update parameter setting and fuzzy sets ...
# 		d1=3.000000, d2=0.000000, n=7.000000
# 	---- error percentage = 0.023157
# Iteration #31
# 	Update parameter setting and fuzzy sets ...
# 		d1=3.000000, d2=3.000000, n=7.000000
# 	---- error percentage = 0.008018
# Iteration #32
# 	Update parameter setting and fuzzy sets ...
# 		d1=3.000000, d2=0.000000, n=7.000000
# 	---- error percentage = 0.012297
# Iteration #33
# 	Update parameter setting and fuzzy sets ...
# 		d1=3.000000, d2=0.000000, n=7.000000
# 	---- error percentage = 0.012330
# Iteration #34
# 	Update parameter setting and fuzzy sets ...
# 		d1=3.000000, d2=4.000000, n=7.000000
# 	---- error percentage = 0.002868
# Iteration #35
# 	Update parameter setting and fuzzy sets ...
# 		d1=3.000000, d2=4.000000, n=7.000000
# 	---- error percentage = 0.007152
# Iteration #36
# 	Update parameter setting and fuzzy sets ...
# 		d1=3.000000, d2=5.000000, n=7.000000
# 	---- error percentage = 0.009424
# Iteration #37
# 	Update parameter setting and fuzzy sets ...
# 		d1=3.000000, d2=1.000000, n=7.000000
# 	---- error percentage = 0.005534
# Iteration #38
# 	Update parameter setting and fuzzy sets ...
# 		d1=15.000000, d2=2.000000, n=7.000000
# 	---- error percentage = 0.002681
# Iteration #39
# 	Update parameter setting and fuzzy sets ...
# 		d1=3.000000, d2=0.000000, n=7.000000
# 	---- error percentage = 0.001462
# Iteration #40
# 	Update parameter setting and fuzzy sets ...
# 		d1=3.000000, d2=1.000000, n=7.000000
# 	---- error percentage = 0.009287
# Iteration #41
# 	Update parameter setting and fuzzy sets ...
# 		d1=3.000000, d2=1.000000, n=7.000000
# 	---- error percentage = 0.010052
# Iteration #42
# 	Update parameter setting and fuzzy sets ...
# 		d1=3.000000, d2=3.000000, n=7.000000
# 	---- error percentage = 0.006915
# Iteration #43
# 	Update parameter setting and fuzzy sets ...
# 		d1=3.000000, d2=2.000000, n=7.000000
# 	---- error percentage = 0.010497
# Iteration #44
# 	Update parameter setting and fuzzy sets ...
# 		d1=4.000000, d2=1.000000, n=15.000000
# 	---- error percentage = 0.001498
# Iteration #45
# 	Update parameter setting and fuzzy sets ...
# 		d1=3.000000, d2=9.000000, n=7.000000
# 	---- error percentage = 0.007085
# Iteration #46
# 	Update parameter setting and fuzzy sets ...
# 		d1=3.000000, d2=8.000000, n=7.000000
# 	---- error percentage = 0.012052
# Iteration #47
# 	Update parameter setting and fuzzy sets ...
# 		d1=3.000000, d2=12.000000, n=7.000000
# 	---- error percentage = 0.007903
# Iteration #48
# 	Update parameter setting and fuzzy sets ...
# 		d1=3.000000, d2=1.000000, n=7.000000
# 	---- error percentage = 0.008138
# Iteration #49
# 	Update parameter setting and fuzzy sets ...
# 		d1=3.000000, d2=4.000000, n=7.000000
# 	---- error percentage = 0.004519
# Iteration #50
# 	Update parameter setting and fuzzy sets ...
# 		d1=3.000000, d2=2.000000, n=7.000000
# 	---- error percentage = 0.001244
# Iteration #51
# 	Update parameter setting and fuzzy sets ...
# 		d1=3.000000, d2=2.000000, n=7.000000
# 	---- error percentage = 0.002100
# Iteration #52
# 	Update parameter setting and fuzzy sets ...
# 		d1=3.000000, d2=7.000000, n=7.000000
# 	---- error percentage = 0.004674
# Iteration #53
# 	Update parameter setting and fuzzy sets ...
# 		d1=3.000000, d2=14.000000, n=7.000000
# 	---- error percentage = 0.007726
# Iteration #54
# 	Update parameter setting and fuzzy sets ...
# 		d1=3.000000, d2=6.000000, n=7.000000
# 	---- error percentage = 0.000034
# Iteration #55
# 	Update parameter setting and fuzzy sets ...
# 		d1=3.000000, d2=10.000000, n=7.000000
# 	---- error percentage = 0.003984
# Iteration #56
# 	Update parameter setting and fuzzy sets ...
# 		d1=3.000000, d2=1.000000, n=7.000000
# 	---- error percentage = 0.027733
# Iteration #57
# 	Update parameter setting and fuzzy sets ...
# 		d1=3.000000, d2=1.000000, n=7.000000
# 	---- error percentage = 0.030668
# Iteration #58
# 	Update parameter setting and fuzzy sets ...
# 		d1=3.000000, d2=1.000000, n=7.000000
# 	---- error percentage = 0.041753
# Iteration #59
# 	Update parameter setting and fuzzy sets ...
# 		d1=3.000000, d2=2.000000, n=7.000000
# 	---- error percentage = 0.020730
# Iteration #60
# 	Update parameter setting and fuzzy sets ...
# 		d1=3.000000, d2=0.000000, n=7.000000
# 	---- error percentage = 0.034150
# Iteration #61
# 	Update parameter setting and fuzzy sets ...
# 		d1=3.000000, d2=1.000000, n=7.000000
# 	---- error percentage = 0.033316
# Iteration #62
# 	Update parameter setting and fuzzy sets ...
# 		d1=3.000000, d2=14.000000, n=7.000000
# 	---- error percentage = 0.001890
# Iteration #63
# 	Update parameter setting and fuzzy sets ...
# 		d1=3.000000, d2=0.000000, n=7.000000
# 	---- error percentage = 0.035185
# Iteration #64
# 	Update parameter setting and fuzzy sets ...
# 		d1=3.000000, d2=0.000000, n=7.000000
# 	---- error percentage = 0.043647
# Iteration #65
# 	Update parameter setting and fuzzy sets ...
# 		d1=3.000000, d2=2.000000, n=7.000000
# 	---- error percentage = 0.047076
# Iteration #66
# 	Update parameter setting and fuzzy sets ...
# 		d1=3.000000, d2=14.000000, n=7.000000
# 	---- error percentage = 0.012153
# Iteration #67
# 	Update parameter setting and fuzzy sets ...
# 		d1=3.000000, d2=0.000000, n=7.000000
# 	---- error percentage = 0.052222
# Iteration #68
# 	Update parameter setting and fuzzy sets ...
# 		d1=3.000000, d2=0.000000, n=7.000000
# 	---- error percentage = 0.057616
# Iteration #69
# 	Update parameter setting and fuzzy sets ...
# 		d1=3.000000, d2=5.000000, n=7.000000
# 	---- error percentage = 0.043357
# Iteration #70
# 	Update parameter setting and fuzzy sets ...
# 		d1=3.000000, d2=7.000000, n=7.000000
# 	---- error percentage = 0.039052
# Iteration #71
# 	Update parameter setting and fuzzy sets ...
# 		d1=3.000000, d2=1.000000, n=7.000000
# 	---- error percentage = 0.056580
# Iteration #72
# 	Update parameter setting and fuzzy sets ...
# 		d1=3.000000, d2=4.000000, n=7.000000
# 	---- error percentage = 0.044219
# Iteration #73
# 	Update parameter setting and fuzzy sets ...
# 		d1=3.000000, d2=2.000000, n=7.000000
# 	---- error percentage = 0.034709
# Iteration #74
# 	Update parameter setting and fuzzy sets ...
# 		d1=3.000000, d2=8.000000, n=7.000000
# 	---- error percentage = 0.005478
# Iteration #75
# 	Update parameter setting and fuzzy sets ...
# 		d1=3.000000, d2=4.000000, n=7.000000
# 	---- error percentage = 0.016370
# Iteration #76
# 	Update parameter setting and fuzzy sets ...
# 		d1=3.000000, d2=10.000000, n=7.000000
# 	---- error percentage = 0.005868
# Iteration #77
# 	Update parameter setting and fuzzy sets ...
# 		d1=6.000000, d2=0.000000, n=24.000000
# 	---- error percentage = 0.026710
# Iteration #78
# 	Update parameter setting and fuzzy sets ...
# 		d1=3.000000, d2=0.000000, n=7.000000
# 	---- error percentage = 0.034142
# Iteration #79
# 	Update parameter setting and fuzzy sets ...
# 		d1=3.000000, d2=10.000000, n=7.000000
# 	---- error percentage = 0.009387
# Iteration #80
# 	Update parameter setting and fuzzy sets ...
# 		d1=3.000000, d2=0.000000, n=7.000000
# 	---- error percentage = 0.049587
# Iteration #81
# 	Update parameter setting and fuzzy sets ...
# 		d1=3.000000, d2=3.000000, n=7.000000
# 	---- error percentage = 0.039154
# Iteration #82
# 	Update parameter setting and fuzzy sets ...
# 		d1=3.000000, d2=7.000000, n=7.000000
# 	---- error percentage = 0.001176
# Iteration #83
# 	Update parameter setting and fuzzy sets ...
# 		d1=3.000000, d2=6.000000, n=7.000000
# 	---- error percentage = 0.008753
# Iteration #84
# 	Update parameter setting and fuzzy sets ...
# 		d1=3.000000, d2=13.000000, n=7.000000
# 	---- error percentage = 0.008299
# Iteration #85
# 	Update parameter setting and fuzzy sets ...
# 		d1=3.000000, d2=3.000000, n=7.000000
# 	---- error percentage = 0.005736
# Iteration #86
# 	Update parameter setting and fuzzy sets ...
# 		d1=6.000000, d2=0.000000, n=24.000000
# 	---- error percentage = 0.005089
# Iteration #87
# 	Update parameter setting and fuzzy sets ...
# 		d1=3.000000, d2=0.000000, n=7.000000
# 	---- error percentage = 0.016232
# Iteration #88
# 	Update parameter setting and fuzzy sets ...
# 		d1=3.000000, d2=0.000000, n=7.000000
# 	---- error percentage = 0.031109
# Iteration #89
# 	Update parameter setting and fuzzy sets ...
# 		d1=3.000000, d2=0.000000, n=7.000000
# 	---- error percentage = 0.022414
# Iteration #90
# 	Update parameter setting and fuzzy sets ...
# 		d1=3.000000, d2=7.000000, n=7.000000
# 	---- error percentage = 0.005895
# Iteration #91
# 	Update parameter setting and fuzzy sets ...
# 		d1=3.000000, d2=0.000000, n=7.000000
# 	---- error percentage = 0.020044
# Iteration #92
# 	Update parameter setting and fuzzy sets ...
# 		d1=3.000000, d2=1.000000, n=7.000000
# 	---- error percentage = 0.031541
# Iteration #93
# 	Update parameter setting and fuzzy sets ...
# 		d1=3.000000, d2=1.000000, n=7.000000
# 	---- error percentage = 0.022827
# Iteration #94
# 	Update parameter setting and fuzzy sets ...
# 		d1=3.000000, d2=2.000000, n=7.000000
# 	---- error percentage = 0.021219
# Iteration #95
# 	Update parameter setting and fuzzy sets ...
# 		d1=3.000000, d2=0.000000, n=7.000000
# 	---- error percentage = 0.037122
# Iteration #96
# 	Update parameter setting and fuzzy sets ...
# 		d1=3.000000, d2=0.000000, n=7.000000
# 	---- error percentage = 0.038192
# Iteration #97
# 	Update parameter setting and fuzzy sets ...
# 		d1=3.000000, d2=1.000000, n=7.000000
# 	---- error percentage = 0.044563
# Iteration #98
# 	Update parameter setting and fuzzy sets ...
# 		d1=3.000000, d2=15.000000, n=7.000000
# 	---- error percentage = 0.011890
# Iteration #99
# 	Update parameter setting and fuzzy sets ...
# 		d1=3.000000, d2=1.000000, n=7.000000
# 	---- error percentage = 0.019393
# Iteration #100
# 	Update parameter setting and fuzzy sets ...
# 		d1=3.000000, d2=9.000000, n=7.000000
# 	---- error percentage = 0.003133
# Iteration #101
# 	Update parameter setting and fuzzy sets ...
# 		d1=3.000000, d2=1.000000, n=7.000000
# 	---- error percentage = 0.027212
# Iteration #102
# 	Update parameter setting and fuzzy sets ...
# 		d1=3.000000, d2=12.000000, n=7.000000
# 	---- error percentage = 0.002412
# Iteration #103
# 	Update parameter setting and fuzzy sets ...
# 		d1=3.000000, d2=3.000000, n=7.000000
# 	---- error percentage = 0.008942
# Iteration #104
# 	Update parameter setting and fuzzy sets ...
# 		d1=3.000000, d2=12.000000, n=7.000000
# 	---- error percentage = 0.007535
# Iteration #105
# 	Update parameter setting and fuzzy sets ...
# 		d1=3.000000, d2=7.000000, n=7.000000
# 	---- error percentage = 0.000345
# Iteration #106
# 	Update parameter setting and fuzzy sets ...
# 		d1=3.000000, d2=0.000000, n=7.000000
# 	---- error percentage = 0.010998
# Iteration #107
# 	Update parameter setting and fuzzy sets ...
# 		d1=3.000000, d2=4.000000, n=7.000000
# 	---- error percentage = 0.013117
# Iteration #108
# 	Update parameter setting and fuzzy sets ...
# 		d1=6.000000, d2=0.000000, n=20.000000
# 	---- error percentage = 0.000931
# Iteration #109
# 	Update parameter setting and fuzzy sets ...
# 		d1=3.000000, d2=1.000000, n=7.000000
# 	---- error percentage = 0.013255
# Iteration #110
# 	Update parameter setting and fuzzy sets ...
# 		d1=3.000000, d2=6.000000, n=7.000000
# 	---- error percentage = 0.001629
# Iteration #111
# 	Update parameter setting and fuzzy sets ...
# 		d1=3.000000, d2=0.000000, n=7.000000
# 	---- error percentage = 0.018223
# Iteration #112
# 	Update parameter setting and fuzzy sets ...
# 		d1=3.000000, d2=0.000000, n=7.000000
# 	---- error percentage = 0.007649
# Iteration #113
# 	Update parameter setting and fuzzy sets ...
# 		d1=3.000000, d2=5.000000, n=7.000000
# 	---- error percentage = 0.022290
# Iteration #114
# 	Update parameter setting and fuzzy sets ...
# 		d1=3.000000, d2=6.000000, n=7.000000
# 	---- error percentage = 0.012226
# Iteration #115
# 	Update parameter setting and fuzzy sets ...
# 		d1=3.000000, d2=0.000000, n=7.000000
# 	---- error percentage = 0.008081
# Iteration #116
# 	Update parameter setting and fuzzy sets ...
# 		d1=3.000000, d2=5.000000, n=7.000000
# 	---- error percentage = 0.010115
# Iteration #117
# 	Update parameter setting and fuzzy sets ...
# 		d1=15.000000, d2=2.000000, n=7.000000
# 	---- error percentage = 0.006957
# Iteration #118
# 	Update parameter setting and fuzzy sets ...
# 		d1=3.000000, d2=2.000000, n=7.000000
# 	---- error percentage = 0.025650
# Iteration #119
# 	Update parameter setting and fuzzy sets ...
# 		d1=3.000000, d2=2.000000, n=7.000000
# 	---- error percentage = 0.029780
# Iteration #120
# 	Update parameter setting and fuzzy sets ...
# 		d1=3.000000, d2=10.000000, n=7.000000
# 	---- error percentage = 0.000416
# Iteration #121
# 	Update parameter setting and fuzzy sets ...
# 		d1=3.000000, d2=0.000000, n=7.000000
# 	---- error percentage = 0.014850
# Iteration #122
# 	Update parameter setting and fuzzy sets ...
# 		d1=3.000000, d2=1.000000, n=7.000000
# 	---- error percentage = 0.014298
# Iteration #123
# 	Update parameter setting and fuzzy sets ...
# 		d1=3.000000, d2=14.000000, n=7.000000
# 	---- error percentage = 0.007252
# Iteration #124
# 	Update parameter setting and fuzzy sets ...
# 		d1=3.000000, d2=11.000000, n=7.000000
# 	---- error percentage = 0.030636
# Iteration #125
# 	Update parameter setting and fuzzy sets ...
# 		d1=3.000000, d2=0.000000, n=7.000000
# 	---- error percentage = 0.004216
# Iteration #126
# 	Update parameter setting and fuzzy sets ...
# 		d1=3.000000, d2=1.000000, n=7.000000
# 	---- error percentage = 0.003351
# Iteration #127
# 	Update parameter setting and fuzzy sets ...
# 		d1=3.000000, d2=4.000000, n=7.000000
# 	---- error percentage = 0.005715
# Iteration #128
# 	Update parameter setting and fuzzy sets ...
# 		d1=3.000000, d2=15.000000, n=7.000000
# 	---- error percentage = 0.022713
# Iteration #129
# 	Update parameter setting and fuzzy sets ...
# 		d1=3.000000, d2=6.000000, n=7.000000
# 	---- error percentage = 0.001267
# Iteration #130
# 	Update parameter setting and fuzzy sets ...
# 		d1=3.000000, d2=1.000000, n=7.000000
# 	---- error percentage = 0.017060
# Iteration #131
# 	Update parameter setting and fuzzy sets ...
# 		d1=3.000000, d2=0.000000, n=7.000000
# 	---- error percentage = 0.010190
# Iteration #132
# 	Update parameter setting and fuzzy sets ...
# 		d1=3.000000, d2=4.000000, n=7.000000
# 	---- error percentage = 0.045623
# Iteration #133
# 	Update parameter setting and fuzzy sets ...
# 		d1=3.000000, d2=0.000000, n=7.000000
# 	---- error percentage = 0.018923
# Iteration #134
# 	Update parameter setting and fuzzy sets ...
# 		d1=15.000000, d2=0.000000, n=7.000000
# 	---- error percentage = 0.011770
# Iteration #135
# 	Update parameter setting and fuzzy sets ...
# 		d1=3.000000, d2=2.000000, n=7.000000
# 	---- error percentage = 0.008695
# Iteration #136
# 	Update parameter setting and fuzzy sets ...
# 		d1=3.000000, d2=3.000000, n=7.000000
# 	---- error percentage = 0.021142
# Iteration #137
# 	Update parameter setting and fuzzy sets ...
# 		d1=3.000000, d2=0.000000, n=7.000000
# 	---- error percentage = 0.040948
# Iteration #138
# 	Update parameter setting and fuzzy sets ...
# 		d1=3.000000, d2=8.000000, n=7.000000
# 	---- error percentage = 0.014700
# Iteration #139
# 	Update parameter setting and fuzzy sets ...
# 		d1=7.000000, d2=1.000000, n=24.000000
# 	---- error percentage = 0.036969
# Iteration #140
# 	Update parameter setting and fuzzy sets ...
# 		d1=3.000000, d2=0.000000, n=7.000000
# 	---- error percentage = 0.027323
# Iteration #141
# 	Update parameter setting and fuzzy sets ...
# 		d1=3.000000, d2=0.000000, n=7.000000
# 	---- error percentage = 0.041031
# Iteration #142
# 	Update parameter setting and fuzzy sets ...
# 		d1=3.000000, d2=6.000000, n=7.000000
# 	---- error percentage = 0.014336
# Iteration #143
# 	Update parameter setting and fuzzy sets ...
# 		d1=3.000000, d2=2.000000, n=7.000000
# 	---- error percentage = 0.007876
# Iteration #144
# 	Update parameter setting and fuzzy sets ...
# 		d1=3.000000, d2=2.000000, n=7.000000
# 	---- error percentage = 0.001380
# Iteration #145
# 	Update parameter setting and fuzzy sets ...
# 		d1=3.000000, d2=6.000000, n=7.000000
# 	---- error percentage = 0.015348
# Iteration #146
# 	Update parameter setting and fuzzy sets ...
# 		d1=3.000000, d2=0.000000, n=7.000000
# 	---- error percentage = 0.023766
# Iteration #147
# 	Update parameter setting and fuzzy sets ...
# 		d1=3.000000, d2=0.000000, n=7.000000
# 	---- error percentage = 0.010751
# Iteration #148
# 	Update parameter setting and fuzzy sets ...
# 		d1=3.000000, d2=4.000000, n=7.000000
# 	---- error percentage = 0.002325
# Iteration #149
# 	Update parameter setting and fuzzy sets ...
# 		d1=3.000000, d2=3.000000, n=7.000000
# 	---- error percentage = 0.010687
# Iteration #150
# 	Update parameter setting and fuzzy sets ...
# 		d1=3.000000, d2=10.000000, n=7.000000
# 	---- error percentage = 0.002858
# Iteration #151
# 	Update parameter setting and fuzzy sets ...
# 		d1=3.000000, d2=0.000000, n=7.000000
# 	---- error percentage = 0.016477
# Iteration #152
# 	Update parameter setting and fuzzy sets ...
# 		d1=3.000000, d2=6.000000, n=7.000000
# 	---- error percentage = 0.003406
# Iteration #153
# 	Update parameter setting and fuzzy sets ...
# 		d1=3.000000, d2=1.000000, n=7.000000
# 	---- error percentage = 0.014368
# Iteration #154
# 	Update parameter setting and fuzzy sets ...
# 		d1=3.000000, d2=1.000000, n=7.000000
# 	---- error percentage = 0.017776
# Iteration #155
# 	Update parameter setting and fuzzy sets ...
# 		d1=3.000000, d2=1.000000, n=7.000000
# 	---- error percentage = 0.002136
# Iteration #156
# 	Update parameter setting and fuzzy sets ...
# 		d1=3.000000, d2=4.000000, n=7.000000
# 	---- error percentage = 0.002945
# Iteration #157
# 	Update parameter setting and fuzzy sets ...
# 		d1=3.000000, d2=2.000000, n=7.000000
# 	---- error percentage = 0.009745
# Iteration #158
# 	Update parameter setting and fuzzy sets ...
# 		d1=4.000000, d2=0.000000, n=15.000000
# 	---- error percentage = 0.001791
# Iteration #159
# 	Update parameter setting and fuzzy sets ...
# 		d1=3.000000, d2=4.000000, n=7.000000
# 	---- error percentage = 0.008741
# Iteration #160
# 	Update parameter setting and fuzzy sets ...
# 		d1=5.000000, d2=0.000000, n=20.000000
# 	---- error percentage = 0.003521
# Iteration #161
# 	Update parameter setting and fuzzy sets ...
# 		d1=3.000000, d2=2.000000, n=7.000000
# 	---- error percentage = 0.005928
# Iteration #162
# 	Update parameter setting and fuzzy sets ...
# 		d1=3.000000, d2=4.000000, n=7.000000
# 	---- error percentage = 0.027548
# Iteration #163
# 	Update parameter setting and fuzzy sets ...
# 		d1=6.000000, d2=0.000000, n=24.000000
# 	---- error percentage = 0.046171
# Iteration #164
# 	Update parameter setting and fuzzy sets ...
# 		d1=3.000000, d2=0.000000, n=7.000000
# 	---- error percentage = 0.007099
# Iteration #165
# 	Update parameter setting and fuzzy sets ...
# 		d1=3.000000, d2=1.000000, n=7.000000
# 	---- error percentage = 0.013776
# Iteration #166
# 	Update parameter setting and fuzzy sets ...
# 		d1=3.000000, d2=0.000000, n=7.000000
# 	---- error percentage = 0.018024
# Iteration #167
# 	Update parameter setting and fuzzy sets ...
# 		d1=3.000000, d2=0.000000, n=7.000000
# 	---- error percentage = 0.011271
# Iteration #168
# 	Update parameter setting and fuzzy sets ...
# 		d1=3.000000, d2=1.000000, n=7.000000
# 	---- error percentage = 0.000522
# Iteration #169
# 	Update parameter setting and fuzzy sets ...
# 		d1=5.000000, d2=0.000000, n=20.000000
# 	---- error percentage = 0.017959
# Iteration #170
# 	Update parameter setting and fuzzy sets ...
# 		d1=3.000000, d2=0.000000, n=7.000000
# 	---- error percentage = 0.010705
# Iteration #171
# 	Update parameter setting and fuzzy sets ...
# 		d1=3.000000, d2=3.000000, n=7.000000
# 	---- error percentage = 0.002137
# Iteration #172
# 	Update parameter setting and fuzzy sets ...
# 		d1=3.000000, d2=7.000000, n=7.000000
# 	---- error percentage = 0.009874
# Iteration #173
# 	Update parameter setting and fuzzy sets ...
# 		d1=3.000000, d2=0.000000, n=7.000000
# 	---- error percentage = 0.005765
# Iteration #174
# 	Update parameter setting and fuzzy sets ...
# 		d1=3.000000, d2=3.000000, n=7.000000
# 	---- error percentage = 0.000777
# Iteration #175
# 	Update parameter setting and fuzzy sets ...
# 		d1=3.000000, d2=3.000000, n=7.000000
# 	---- error percentage = 0.020919
# Iteration #176
# 	Update parameter setting and fuzzy sets ...
# 		d1=3.000000, d2=6.000000, n=7.000000
# 	---- error percentage = 0.018899
# Iteration #177
# 	Update parameter setting and fuzzy sets ...
# 		d1=3.000000, d2=1.000000, n=7.000000
# 	---- error percentage = 0.007446
# Iteration #178
# 	Update parameter setting and fuzzy sets ...
# 		d1=3.000000, d2=0.000000, n=7.000000
# 	---- error percentage = 0.010564
# Iteration #179
# 	Update parameter setting and fuzzy sets ...
# 		d1=4.000000, d2=0.000000, n=15.000000
# 	---- error percentage = 0.006741
# Iteration #180
# 	Update parameter setting and fuzzy sets ...
# 		d1=3.000000, d2=2.000000, n=7.000000
# 	---- error percentage = 0.017468
# Iteration #181
# 	Update parameter setting and fuzzy sets ...
# 		d1=3.000000, d2=1.000000, n=7.000000
# 	---- error percentage = 0.014682
# Iteration #182
# 	Update parameter setting and fuzzy sets ...
# 		d1=15.000000, d2=0.000000, n=7.000000
# 	---- error percentage = 0.000106
# Iteration #183
# 	Update parameter setting and fuzzy sets ...
# 		d1=3.000000, d2=1.000000, n=7.000000
# 	---- error percentage = 0.022300
# Iteration #184
# 	Update parameter setting and fuzzy sets ...
# 		d1=15.000000, d2=1.000000, n=7.000000
# 	---- error percentage = 0.001509
# Iteration #185
# 	Update parameter setting and fuzzy sets ...
# 		d1=3.000000, d2=11.000000, n=7.000000
# 	---- error percentage = 0.035571
# Iteration #186
# 	Update parameter setting and fuzzy sets ...
# 		d1=3.000000, d2=0.000000, n=7.000000
# 	---- error percentage = 0.003329
# Iteration #187
# 	Update parameter setting and fuzzy sets ...
# 		d1=3.000000, d2=4.000000, n=7.000000
# 	---- error percentage = 0.008418
# Iteration #188
# 	Update parameter setting and fuzzy sets ...
# 		d1=3.000000, d2=0.000000, n=7.000000
# 	---- error percentage = 0.007262
# Iteration #189
# 	Update parameter setting and fuzzy sets ...
# 		d1=3.000000, d2=0.000000, n=7.000000
# 	---- error percentage = 0.026217
# Iteration #190
# 	Update parameter setting and fuzzy sets ...
# 		d1=3.000000, d2=1.000000, n=7.000000
# 	---- error percentage = 0.033163
# Iteration #191
# 	Update parameter setting and fuzzy sets ...
# 		d1=3.000000, d2=7.000000, n=7.000000
# 	---- error percentage = 0.006202
# Iteration #192
# 	Update parameter setting and fuzzy sets ...
# 		d1=3.000000, d2=8.000000, n=7.000000
# 	---- error percentage = 0.004839
# Iteration #193
# 	Update parameter setting and fuzzy sets ...
# 		d1=3.000000, d2=1.000000, n=7.000000
# 	---- error percentage = 0.008203
# Iteration #194
# 	Update parameter setting and fuzzy sets ...
# 		d1=3.000000, d2=12.000000, n=7.000000
# 	---- error percentage = 0.022000
# Iteration #195
# 	Update parameter setting and fuzzy sets ...
# 		d1=3.000000, d2=2.000000, n=7.000000
# 	---- error percentage = 0.012862
# Iteration #196
# 	Update parameter setting and fuzzy sets ...
# 		d1=3.000000, d2=1.000000, n=7.000000
# 	---- error percentage = 0.006762
# Iteration #197
# 	Update parameter setting and fuzzy sets ...
# 		d1=3.000000, d2=8.000000, n=7.000000
# 	---- error percentage = 0.015784
# Iteration #198
# 	Update parameter setting and fuzzy sets ...
# 		d1=3.000000, d2=4.000000, n=7.000000
# 	---- error percentage = 0.002614
# Iteration #199
# 	Update parameter setting and fuzzy sets ...
# 		d1=3.000000, d2=5.000000, n=7.000000
# 	---- error percentage = 0.006299
# Iteration #200
# 	Update parameter setting and fuzzy sets ...
# 		d1=3.000000, d2=3.000000, n=7.000000
# 	---- error percentage = 0.014004
# Iteration #201
# 	Update parameter setting and fuzzy sets ...
# 		d1=3.000000, d2=10.000000, n=7.000000
# 	---- error percentage = 0.008575
# Iteration #202
# 	Update parameter setting and fuzzy sets ...
# 		d1=3.000000, d2=1.000000, n=7.000000
# 	---- error percentage = 0.005705
# Iteration #203
# 	Update parameter setting and fuzzy sets ...
# 		d1=3.000000, d2=4.000000, n=7.000000
# 	---- error percentage = 0.001482
# Iteration #204
# 	Update parameter setting and fuzzy sets ...
# 		d1=3.000000, d2=0.000000, n=7.000000
# 	---- error percentage = 0.000937
# Iteration #205
# 	Update parameter setting and fuzzy sets ...
# 		d1=3.000000, d2=0.000000, n=7.000000
# 	---- error percentage = 0.007925
# Iteration #206
# 	Update parameter setting and fuzzy sets ...
# 		d1=3.000000, d2=12.000000, n=7.000000
# 	---- error percentage = 0.001308
# Iteration #207
# 	Update parameter setting and fuzzy sets ...
# 		d1=3.000000, d2=0.000000, n=7.000000
# 	---- error percentage = 0.031853
# Iteration #208
# 	Update parameter setting and fuzzy sets ...
# 		d1=3.000000, d2=14.000000, n=7.000000
# 	---- error percentage = 0.001494
# Iteration #209
# 	Update parameter setting and fuzzy sets ...
# 		d1=3.000000, d2=6.000000, n=7.000000
# 	---- error percentage = 0.000005
# Iteration #210
# 	Update parameter setting and fuzzy sets ...
# 		d1=3.000000, d2=4.000000, n=7.000000
# 	---- error percentage = 0.013298
# Iteration #211
# 	Update parameter setting and fuzzy sets ...
# 		d1=3.000000, d2=15.000000, n=7.000000
# 	---- error percentage = 0.015306
# Iteration #212
# 	Update parameter setting and fuzzy sets ...
# 		d1=3.000000, d2=5.000000, n=7.000000
# 	---- error percentage = 0.006162
# Iteration #213
# 	Update parameter setting and fuzzy sets ...
# 		d1=3.000000, d2=0.000000, n=7.000000
# 	---- error percentage = 0.009078
# Iteration #214
# 	Update parameter setting and fuzzy sets ...
# 		d1=3.000000, d2=6.000000, n=7.000000
# 	---- error percentage = 0.010268
# Iteration #215
# 	Update parameter setting and fuzzy sets ...
# 		d1=3.000000, d2=3.000000, n=7.000000
# 	---- error percentage = 0.014460
# Iteration #216
# 	Update parameter setting and fuzzy sets ...
# 		d1=3.000000, d2=4.000000, n=7.000000
# 	---- error percentage = 0.005496
# Iteration #217
# 	Update parameter setting and fuzzy sets ...
# 		d1=3.000000, d2=6.000000, n=7.000000
# 	---- error percentage = 0.003113
# Iteration #218
# 	Update parameter setting and fuzzy sets ...
# 		d1=3.000000, d2=3.000000, n=7.000000
# 	---- error percentage = 0.000637
# Iteration #219
# 	Update parameter setting and fuzzy sets ...
# 		d1=3.000000, d2=1.000000, n=7.000000
# 	---- error percentage = 0.009094
# Iteration #220
# 	Update parameter setting and fuzzy sets ...
# 		d1=6.000000, d2=5.000000, n=20.000000
# 	---- error percentage = 0.001369
# Iteration #221
# 	Update parameter setting and fuzzy sets ...
# 		d1=3.000000, d2=5.000000, n=7.000000
# 	---- error percentage = 0.002126
# Iteration #222
# 	Update parameter setting and fuzzy sets ...
# 		d1=3.000000, d2=0.000000, n=7.000000
# 	---- error percentage = 0.025134
# Iteration #223
# 	Update parameter setting and fuzzy sets ...
# 		d1=3.000000, d2=3.000000, n=7.000000
# 	---- error percentage = 0.010432
# Iteration #224
# 	Update parameter setting and fuzzy sets ...
# 		d1=15.000000, d2=0.000000, n=7.000000
# 	---- error percentage = 0.016355
# Iteration #225
# 	Update parameter setting and fuzzy sets ...
# 		d1=3.000000, d2=2.000000, n=7.000000
# 	---- error percentage = 0.007550
# Iteration #226
# 	Update parameter setting and fuzzy sets ...
# 		d1=6.000000, d2=0.000000, n=20.000000
# 	---- error percentage = 0.005790
# Iteration #227
# 	Update parameter setting and fuzzy sets ...
# 		d1=3.000000, d2=3.000000, n=7.000000
# 	---- error percentage = 0.000057
# Iteration #228
# 	Update parameter setting and fuzzy sets ...
# 		d1=3.000000, d2=7.000000, n=7.000000
# 	---- error percentage = 0.010749
# Iteration #229
# 	Update parameter setting and fuzzy sets ...
# 		d1=3.000000, d2=5.000000, n=7.000000
# 	---- error percentage = 0.005916
# Iteration #230
# 	Update parameter setting and fuzzy sets ...
# 		d1=3.000000, d2=2.000000, n=7.000000
# 	---- error percentage = 0.002175
# Iteration #231
# 	Update parameter setting and fuzzy sets ...
# 		d1=3.000000, d2=2.000000, n=7.000000
# 	---- error percentage = 0.001071
# Iteration #232
# 	Update parameter setting and fuzzy sets ...
# 		d1=3.000000, d2=0.000000, n=7.000000
# 	---- error percentage = 0.007724
# Iteration #233
# 	Update parameter setting and fuzzy sets ...
# 		d1=3.000000, d2=15.000000, n=7.000000
# 	---- error percentage = 0.000697
# Iteration #234
# 	Update parameter setting and fuzzy sets ...
# 		d1=3.000000, d2=7.000000, n=7.000000
# 	---- error percentage = 0.011343
# Iteration #235
# 	Update parameter setting and fuzzy sets ...
# 		d1=3.000000, d2=3.000000, n=7.000000
# 	---- error percentage = 0.003774
# Iteration #236
# 	Update parameter setting and fuzzy sets ...
# 		d1=3.000000, d2=5.000000, n=7.000000
# 	---- error percentage = 0.001855
# Iteration #237
# 	Update parameter setting and fuzzy sets ...
# 		d1=3.000000, d2=1.000000, n=7.000000
# 	---- error percentage = 0.032501
# Iteration #238
# 	Update parameter setting and fuzzy sets ...
# 		d1=3.000000, d2=2.000000, n=7.000000
# 	---- error percentage = 0.009250
# Iteration #239
# 	Update parameter setting and fuzzy sets ...
# 		d1=3.000000, d2=3.000000, n=7.000000
# 	---- error percentage = 0.008760
# Iteration #240
# 	Update parameter setting and fuzzy sets ...
# 		d1=3.000000, d2=1.000000, n=7.000000
# 	---- error percentage = 0.018238
# Iteration #241
# 	Update parameter setting and fuzzy sets ...
# 		d1=15.000000, d2=2.000000, n=7.000000
# 	---- error percentage = 0.009363
# Iteration #242
# 	Update parameter setting and fuzzy sets ...
# 		d1=3.000000, d2=3.000000, n=7.000000
# 	---- error percentage = 0.000376
# Iteration #243
# 	Update parameter setting and fuzzy sets ...
# 		d1=3.000000, d2=1.000000, n=7.000000
# 	---- error percentage = 0.012277
# Iteration #244
# 	Update parameter setting and fuzzy sets ...
# 		d1=3.000000, d2=2.000000, n=7.000000
# 	---- error percentage = 0.021145
# Iteration #245
# 	Update parameter setting and fuzzy sets ...
# 		d1=3.000000, d2=12.000000, n=7.000000
# 	---- error percentage = 0.024461
# Iteration #246
# 	Update parameter setting and fuzzy sets ...
# 		d1=3.000000, d2=2.000000, n=7.000000
# 	---- error percentage = 0.013374
# Iteration #247
# 	Update parameter setting and fuzzy sets ...
# 		d1=3.000000, d2=1.000000, n=7.000000
# 	---- error percentage = 0.015973
# Iteration #248
# 	Update parameter setting and fuzzy sets ...
# 		d1=3.000000, d2=2.000000, n=7.000000
# 	---- error percentage = 0.026897
# Iteration #249
# 	Update parameter setting and fuzzy sets ...
# 		d1=3.000000, d2=2.000000, n=7.000000
# 	---- error percentage = 0.007607
# Iteration #250
# 	Update parameter setting and fuzzy sets ...
# 		d1=3.000000, d2=2.000000, n=7.000000
# 	---- error percentage = 0.007752
# Iteration #251
# 	Update parameter setting and fuzzy sets ...
# 		d1=3.000000, d2=1.000000, n=7.000000
# 	---- error percentage = 0.014416
# Iteration #252
# 	Update parameter setting and fuzzy sets ...
# 		d1=5.000000, d2=1.000000, n=20.000000
# 	---- error percentage = 0.000312
# Iteration #253
# 	Update parameter setting and fuzzy sets ...
# 		d1=3.000000, d2=0.000000, n=7.000000
# 	---- error percentage = 0.008885
# Iteration #254
# 	Update parameter setting and fuzzy sets ...
# 		d1=3.000000, d2=15.000000, n=7.000000
# 	---- error percentage = 0.004256
# Iteration #255
# 	Update parameter setting and fuzzy sets ...
# 		d1=3.000000, d2=15.000000, n=7.000000
# 	---- error percentage = 0.009673
# RMSE = 205.663346869
# Average Error Percentage = 0.013908
# Time cost: 19675.7991221 seconds

# %%
df_test = pd.DataFrame(test_data.iloc[1:]['Date'])
df_test['data testing'] = pd.Series(actual_prices).values
df_test['forecasting'] = pd.Series(pred_prices).values
df_test.index = df_test['Date']
plt.figure(figsize=(14,7))
df_test['data testing'].plot(style='k-', linewidth=2, label='data testing')
df_test['forecasting'].plot(style='g:', linewidth=3, label='forecasting')
plt.ylabel('Price', fontsize=18)
plt.legend(loc='best')
plt.title("IBEX35_forecasting", fontsize=24)
