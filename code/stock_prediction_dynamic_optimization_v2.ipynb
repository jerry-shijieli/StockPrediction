# %% [markdown]
# Continue with v1, but dynamically update the parameters weekly (5 trading days per week)

# %%
from rectangle_fuzzy import *

import pandas as pd
import numpy as np
import operator
import matplotlib.pyplot as plt
# %matplotlib inline
from time import time

from collections import defaultdict
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error

# %%
# helper functions
def binary_to_decimal(binary, di=0):
    decimal = 0
    for i in range(len(binary)):
        if i<len(binary)-di+1:
            power = len(binary)-(i+1)-di
            decimal += int(binary[i]) * (2**power)
        else:
            power = len(binary)-(i+1)-di
            decimal += int(binary[i]) * (2**(-power))
    return decimal

def universe_partition_adjusted(data, n=10, d1=10, d2=10):
    x_max, x_min = data.max(axis=0), data.min(axis=0)   
    delta = x_max - x_min
    std_val = data.std(axis=0)
    len_val = np.round(std_val / (n+5)) # partition interval
    u_max, u_min = int(x_max+(d2+1)*(delta/100)), int(x_min-(d1+1)*(delta/100)) # bound of universe discourse
    u_b = np.arange(u_min, u_max, step=float(len_val)) # cutting points
    u_discourse = u_b
    return u_discourse

def compute_fitness(data, n, d1, d2, option='Price'):
    reserved_days = 200
    first_date = data['Date'][0] - pd.DateOffset(days=1)
    train_data = data.iloc[:-reserved_days]
    valid_data = data.iloc[-(reserved_days+1):]
    fit_prices = list()
    u_discourse = universe_partition_adjusted(train_data[option], n, d1, d2)
    A_list = set_fuzzy_numbers(u_discourse)
    train_data_membership_series = membership_assignment(train_data[option], fuzzy_numbers=u_discourse)
    transition_FLR = FLR(train_data_membership_series)
    train_data_days = train_data['Date'].apply(lambda x: x-first_date).dt.days.tolist()
    jump_weights = FLR_weight(transition_FLR, train_data_days[:len(transition_FLR)])
    transition_weights = FRG_weight(transition_FLR, train_data_days[:len(transition_FLR)])
    for price in valid_data.iloc[:-1][option]:
        index = get_membership(price, u_discourse)
        next_price = forecast_price(forecast_jump(index, jump_weights, A_list), forecast_transition(index, transition_weights, A_list), gamma=0.9)
        fit_prices.append(next_price)
    return np.sqrt(mean_squared_error(valid_data.iloc[1:][option], fit_prices))

def parameter_tuning_ASHLO(data, option):
    # initialize hyperparameters
    d1_digits = 4
    n_digits = 6
    d2_digits = 4
    population = 20
    iter_max = 100
    pr = 0.1
    pi = 0.9
    # initialize data structures
    dim_IKD = d1_digits+n_digits+d2_digits
    RMSE_list = list() # training data RMSE as fitness function value
    IKD = np.zeros((population, dim_IKD), dtype=int) # individual learning 
    SKD = np.array([]) # social network learning
    RMSE_min = 0 # best fitness value
    for i in range(population):
        for j in range(dim_IKD):
            r = np.random.rand()
            if r>0.5:
                IKD[i, j] = 0
            else:
                IKD[i, j] = 1
        d1 = binary_to_decimal(IKD[i, 0:d1_digits])
        d2 = binary_to_decimal(IKD[i, (d1_digits+n_digits): dim_IKD])
        n_par = binary_to_decimal(IKD[i, d1_digits:(d1_digits+n_digits)])
        rmse = compute_fitness(data, n_par, d1, d2)
        RMSE_list.append(rmse)
    RMSE_min = np.min(RMSE_list) # best individual fitness
    SKD = np.array(IKD[np.argmin(RMSE_list)])
    # learning iterations
    for iter_count in range(iter_max):
        temp_IKD = np.zeros((population, dim_IKD))
        temp_rmse_list = list()
        # learning process
        for i in range(population):
            for j in range(dim_IKD):
                p = np.random.rand()
                if p < pi:
                    r = np.random.rand()
                    if r > 0.5:
                        temp_IKD[i, j] = 1
                elif pi <= p <= pr:
                    temp_IKD[i,j] = IKD[i, j]
                else:
                    temp_IKD[i,j] = SKD[j]
        # update fitness of newly learned knowledge 
        for i in range(population):
            d1 = binary_to_decimal(temp_IKD[i, 0:d1_digits])
            d2 = binary_to_decimal(temp_IKD[i, (d1_digits+n_digits): dim_IKD])
            n_par = binary_to_decimal(temp_IKD[i, d1_digits:(d1_digits+n_digits)])
            rmse = compute_fitness(data, n_par, d1, d2)
            temp_rmse_list.append(rmse)

        # update knowledge base if necessary
        RMSE_max = np.max(RMSE_list) # worst individual fitness
        RMSE_max_index = np.argmax(RMSE_list)
        for i in range(population):
            if temp_rmse_list[i] < RMSE_max:
                IKD[RMSE_max_index] = temp_IKD[i]
                RMSE_list[RMSE_max_index] = temp_rmse_list[i]
                RMSE_max = np.max(RMSE_list)
                RMSE_max_index = np.argmax(RMSE_list)
        temp_rmse_min = np.min(RMSE_list) # best individual fitness
        if RMSE_min > temp_rmse_min:
            SKD = np.array(IKD[np.argmin(RMSE_list)])
            RMSE_min = temp_rmse_min
    # output optimal parameter settings        
    d1 = binary_to_decimal(SKD[0:d1_digits])
    d2 = binary_to_decimal(SKD[(d1_digits+n_digits): ])
    n_par = binary_to_decimal(SKD[d1_digits:(d1_digits+n_digits)])
    return d1, n_par, d2

# %%
def mean_absolute_percentage_error(y_true, y_pred):
    y_true, y_pred = np.array(y_true), np.array(y_pred)
    return np.mean(np.abs((y_true-y_pred)/y_true))*100 # beware of zero division

# %%
# Load data 
start_time = time()
datafile = '../data/IBEX35.csv'
dateparse = lambda x: pd.datetime.strptime(x, '%m/%d/%y')
df = pd.read_csv(datafile, header=0, parse_dates=['Date'], date_parser=dateparse)

split_date = pd.datetime.strptime('2014-12-31', '%Y-%m-%d')
train_data = df[df['Date'] < split_date]
test_data = df[df['Date'] >= split_date]
first_date = train_data['Date'][0] - pd.DateOffset(days=1)

option = 'Price'
update_interval = 5 # days

# %%
# forecasting using test data
start_time = time()
pred_prices = list()
error_percentages = list() # percentage of forecasting residual
actual_prices = test_data[option].tolist()[1:]
indices = test_data.index
for i in range(len(indices)-1):
    print("Iteration #%s" % str(i))
    prev = test_data.iloc[i]
    train_data.append(prev)
    if (i % update_interval)==0:
        print("\tUpdate parameter setting and fuzzy sets ...")
        d1, n_par, d2 = parameter_tuning_ASHLO(train_data, option)
        print("\t\td1=%f, d2=%f, n=%f" % (d1, d2, n_par))
        u_discourse = universe_partition_adjusted(train_data[option], n_par, d1, d2)
        A_list = set_fuzzy_numbers(u_discourse)
        train_data_membership_series = membership_assignment(train_data[option], fuzzy_numbers=u_discourse)
        transition_FLR = FLR(train_data_membership_series)
        train_data_days = train_data['Date'].apply(lambda x: x-first_date).dt.days.tolist() # convert Timedelta to numeric days
        jump_weights = FLR_weight(transition_FLR, train_data_days[:len(transition_FLR)])
        transition_weights = FRG_weight(transition_FLR, train_data_days[:len(transition_FLR)])
    price = prev[option]
    index = get_membership(price, u_discourse)
    next_price = forecast_price(forecast_jump(index, jump_weights, A_list), forecast_transition(index, transition_weights, A_list), gamma=0.9)
    pred_prices.append(next_price)
    pred_ep = (np.abs(actual_prices[i] - next_price)/actual_prices[i])
    error_percentages.append(pred_ep)
    print("\t---- error percentage = %f" % pred_ep)
    
print "MAD = "+str(mean_absolute_error(actual_prices, pred_prices))
print "RMSE = "+str(np.sqrt(mean_squared_error(actual_prices, pred_prices)))
print "MAPE = "+str(mean_absolute_percentage_error(actual_prices, pred_prices))
print "Time cost: "+str(time()-start_time)+" seconds"
# Out:
# Iteration #0
# 	Update parameter setting and fuzzy sets ...
# 		d1=3.000000, d2=15.000000, n=40.000000
# 	---- error percentage = 0.011137
# Iteration #1
# 	---- error percentage = 0.011935
# Iteration #2
# 	---- error percentage = 0.022939
# Iteration #3
# 	---- error percentage = 0.010978
# Iteration #4
# 	---- error percentage = 0.009777
# Iteration #5
# 	Update parameter setting and fuzzy sets ...
# 		d1=12.000000, d2=15.000000, n=58.000000
# 	---- error percentage = 0.002379
# Iteration #6
# 	---- error percentage = 0.028202
# Iteration #7
# 	---- error percentage = 0.005163
# Iteration #8
# 	---- error percentage = 0.003838
# Iteration #9
# 	---- error percentage = 0.014096
# Iteration #10
# 	Update parameter setting and fuzzy sets ...
# 		d1=3.000000, d2=15.000000, n=55.000000
# 	---- error percentage = 0.001233
# Iteration #11
# 	---- error percentage = 0.012925
# Iteration #12
# 	---- error percentage = 0.010858
# Iteration #13
# 	---- error percentage = 0.012867
# Iteration #14
# 	---- error percentage = 0.005361
# Iteration #15
# 	Update parameter setting and fuzzy sets ...
# 		d1=3.000000, d2=15.000000, n=40.000000
# 	---- error percentage = 0.020289
# Iteration #16
# 	---- error percentage = 0.009902
# Iteration #17
# 	---- error percentage = 0.016385
# Iteration #18
# 	---- error percentage = 0.001086
# Iteration #19
# 	---- error percentage = 0.028581
# Iteration #20
# 	Update parameter setting and fuzzy sets ...
# 		d1=3.000000, d2=15.000000, n=57.000000
# 	---- error percentage = 0.015916
# Iteration #21
# 	---- error percentage = 0.016834
# Iteration #22
# 	---- error percentage = 0.003099
# Iteration #23
# 	---- error percentage = 0.017838
# Iteration #24
# 	---- error percentage = 0.014997
# Iteration #25
# 	Update parameter setting and fuzzy sets ...
# 		d1=3.000000, d2=15.000000, n=40.000000
# 	---- error percentage = 0.008963
# Iteration #26
# 	---- error percentage = 0.006904
# Iteration #27
# 	---- error percentage = 0.007478
# Iteration #28
# 	---- error percentage = 0.010133
# Iteration #29
# 	---- error percentage = 0.014018
# Iteration #30
# 	Update parameter setting and fuzzy sets ...
# 		d1=3.000000, d2=15.000000, n=39.000000
# 	---- error percentage = 0.024776
# Iteration #31
# 	---- error percentage = 0.010376
# Iteration #32
# 	---- error percentage = 0.012879
# Iteration #33
# 	---- error percentage = 0.016079
# Iteration #34
# 	---- error percentage = 0.000045
# Iteration #35
# 	Update parameter setting and fuzzy sets ...
# 		d1=3.000000, d2=15.000000, n=58.000000
# 	---- error percentage = 0.008465
# Iteration #36
# 	---- error percentage = 0.010017
# Iteration #37
# 	---- error percentage = 0.001565
# Iteration #38
# 	---- error percentage = 0.000251
# Iteration #39
# 	---- error percentage = 0.000166
# Iteration #40
# 	Update parameter setting and fuzzy sets ...
# 		d1=3.000000, d2=15.000000, n=39.000000
# 	---- error percentage = 0.009756
# Iteration #41
# 	---- error percentage = 0.004791
# Iteration #42
# 	---- error percentage = 0.000934
# Iteration #43
# 	---- error percentage = 0.014799
# Iteration #44
# 	---- error percentage = 0.002823
# Iteration #45
# 	Update parameter setting and fuzzy sets ...
# 		d1=3.000000, d2=15.000000, n=40.000000
# 	---- error percentage = 0.006988
# Iteration #46
# 	---- error percentage = 0.011718
# Iteration #47
# 	---- error percentage = 0.004873
# Iteration #48
# 	---- error percentage = 0.010623
# Iteration #49
# 	---- error percentage = 0.006097
# Iteration #50
# 	Update parameter setting and fuzzy sets ...
# 		d1=3.000000, d2=15.000000, n=39.000000
# 	---- error percentage = 0.003496
# Iteration #51
# 	---- error percentage = 0.001423
# Iteration #52
# 	---- error percentage = 0.001696
# Iteration #53
# 	---- error percentage = 0.004141
# Iteration #54
# 	---- error percentage = 0.001453
# Iteration #55
# 	Update parameter setting and fuzzy sets ...
# 		d1=3.000000, d2=15.000000, n=58.000000
# 	---- error percentage = 0.003300
# Iteration #56
# 	---- error percentage = 0.026644
# Iteration #57
# 	---- error percentage = 0.003095
# Iteration #58
# 	---- error percentage = 0.011835
# Iteration #59
# 	---- error percentage = 0.013964
# Iteration #60
# 	Update parameter setting and fuzzy sets ...
# 		d1=3.000000, d2=15.000000, n=59.000000
# 	---- error percentage = 0.005281
# Iteration #61
# 	---- error percentage = 0.000965
# Iteration #62
# 	---- error percentage = 0.004771
# Iteration #63
# 	---- error percentage = 0.002836
# Iteration #64
# 	---- error percentage = 0.008399
# Iteration #65
# 	Update parameter setting and fuzzy sets ...
# 		d1=3.000000, d2=15.000000, n=39.000000
# 	---- error percentage = 0.012662
# Iteration #66
# 	---- error percentage = 0.007969
# Iteration #67
# 	---- error percentage = 0.002914
# Iteration #68
# 	---- error percentage = 0.009932
# Iteration #69
# 	---- error percentage = 0.009128
# Iteration #70
# 	Update parameter setting and fuzzy sets ...
# 		d1=3.000000, d2=15.000000, n=58.000000
# 	---- error percentage = 0.012231
# Iteration #71
# 	---- error percentage = 0.007512
# Iteration #72
# 	---- error percentage = 0.010032
# Iteration #73
# 	---- error percentage = 0.007669
# Iteration #74
# 	---- error percentage = 0.013982
# Iteration #75
# 	Update parameter setting and fuzzy sets ...
# 		d1=12.000000, d2=15.000000, n=56.000000
# 	---- error percentage = 0.003268
# Iteration #76
# 	---- error percentage = 0.001559
# Iteration #77
# 	---- error percentage = 0.002965
# Iteration #78
# 	---- error percentage = 0.004555
# Iteration #79
# 	---- error percentage = 0.005609
# Iteration #80
# 	Update parameter setting and fuzzy sets ...
# 		d1=4.000000, d2=15.000000, n=21.000000
# 	---- error percentage = 0.012205
# Iteration #81
# 	---- error percentage = 0.000975
# Iteration #82
# 	---- error percentage = 0.022603
# Iteration #83
# 	---- error percentage = 0.000881
# Iteration #84
# 	---- error percentage = 0.004844
# Iteration #85
# 	Update parameter setting and fuzzy sets ...
# 		d1=3.000000, d2=15.000000, n=39.000000
# 	---- error percentage = 0.028550
# Iteration #86
# 	---- error percentage = 0.002378
# Iteration #87
# 	---- error percentage = 0.013996
# Iteration #88
# 	---- error percentage = 0.015402
# Iteration #89
# 	---- error percentage = 0.009558
# Iteration #90
# 	Update parameter setting and fuzzy sets ...
# 		d1=12.000000, d2=15.000000, n=58.000000
# 	---- error percentage = 0.003244
# Iteration #91
# 	---- error percentage = 0.006416
# Iteration #92
# 	---- error percentage = 0.010986
# Iteration #93
# 	---- error percentage = 0.009093
# Iteration #94
# 	---- error percentage = 0.005345
# Iteration #95
# 	Update parameter setting and fuzzy sets ...
# 		d1=3.000000, d2=15.000000, n=57.000000
# 	---- error percentage = 0.007889
# Iteration #96
# 	---- error percentage = 0.001928
# Iteration #97
# 	---- error percentage = 0.007293
# Iteration #98
# 	---- error percentage = 0.014138
# Iteration #99
# 	---- error percentage = 0.011883
# Iteration #100
# 	Update parameter setting and fuzzy sets ...
# 		d1=12.000000, d2=15.000000, n=57.000000
# 	---- error percentage = 0.001588
# Iteration #101
# 	---- error percentage = 0.009246
# Iteration #102
# 	---- error percentage = 0.000792
# Iteration #103
# 	---- error percentage = 0.010636
# Iteration #104
# 	---- error percentage = 0.004321
# Iteration #105
# 	Update parameter setting and fuzzy sets ...
# 		d1=12.000000, d2=15.000000, n=58.000000
# 	---- error percentage = 0.000905
# Iteration #106
# 	---- error percentage = 0.009993
# Iteration #107
# 	---- error percentage = 0.012450
# Iteration #108
# 	---- error percentage = 0.002424
# Iteration #109
# 	---- error percentage = 0.011944
# Iteration #110
# 	Update parameter setting and fuzzy sets ...
# 		d1=12.000000, d2=15.000000, n=55.000000
# 	---- error percentage = 0.000735
# Iteration #111
# 	---- error percentage = 0.021653
# Iteration #112
# 	---- error percentage = 0.002084
# Iteration #113
# 	---- error percentage = 0.021169
# Iteration #114
# 	---- error percentage = 0.011323
# Iteration #115
# 	Update parameter setting and fuzzy sets ...
# 		d1=3.000000, d2=15.000000, n=59.000000
# 	---- error percentage = 0.011333
# Iteration #116
# 	---- error percentage = 0.009510
# Iteration #117
# 	---- error percentage = 0.008547
# Iteration #118
# 	---- error percentage = 0.026233
# Iteration #119
# 	---- error percentage = 0.024280
# Iteration #120
# 	Update parameter setting and fuzzy sets ...
# 		d1=3.000000, d2=15.000000, n=59.000000
# 	---- error percentage = 0.003230
# Iteration #121
# 	---- error percentage = 0.015908
# Iteration #122
# 	---- error percentage = 0.000928
# Iteration #123
# 	---- error percentage = 0.009036
# Iteration #124
# 	---- error percentage = 0.030673
# Iteration #125
# 	Update parameter setting and fuzzy sets ...
# 		d1=3.000000, d2=15.000000, n=39.000000
# 	---- error percentage = 0.003790
# Iteration #126
# 	---- error percentage = 0.005681
# Iteration #127
# 	---- error percentage = 0.009018
# Iteration #128
# 	---- error percentage = 0.025602
# Iteration #129
# 	---- error percentage = 0.001527
# Iteration #130
# 	Update parameter setting and fuzzy sets ...
# 		d1=12.000000, d2=15.000000, n=58.000000
# 	---- error percentage = 0.019390
# Iteration #131
# 	---- error percentage = 0.011505
# Iteration #132
# 	---- error percentage = 0.043822
# Iteration #133
# 	---- error percentage = 0.019614
# Iteration #134
# 	---- error percentage = 0.003287
# Iteration #135
# 	Update parameter setting and fuzzy sets ...
# 		d1=3.000000, d2=15.000000, n=39.000000
# 	---- error percentage = 0.002433
# Iteration #136
# 	---- error percentage = 0.012942
# Iteration #137
# 	---- error percentage = 0.011573
# Iteration #138
# 	---- error percentage = 0.003527
# Iteration #139
# 	---- error percentage = 0.005724
# Iteration #140
# 	Update parameter setting and fuzzy sets ...
# 		d1=3.000000, d2=15.000000, n=39.000000
# 	---- error percentage = 0.015633
# Iteration #141
# 	---- error percentage = 0.013539
# Iteration #142
# 	---- error percentage = 0.011570
# Iteration #143
# 	---- error percentage = 0.014629
# Iteration #144
# 	---- error percentage = 0.006986
# Iteration #145
# 	Update parameter setting and fuzzy sets ...
# 		d1=7.000000, d2=15.000000, n=55.000000
# 	---- error percentage = 0.010908
# Iteration #146
# 	---- error percentage = 0.003530
# Iteration #147
# 	---- error percentage = 0.014309
# Iteration #148
# 	---- error percentage = 0.002240
# Iteration #149
# 	---- error percentage = 0.004775
# Iteration #150
# 	Update parameter setting and fuzzy sets ...
# 		d1=12.000000, d2=15.000000, n=57.000000
# 	---- error percentage = 0.004789
# Iteration #151
# 	---- error percentage = 0.006037
# Iteration #152
# 	---- error percentage = 0.001842
# Iteration #153
# 	---- error percentage = 0.000811
# Iteration #154
# 	---- error percentage = 0.002650
# Iteration #155
# 	Update parameter setting and fuzzy sets ...
# 		d1=3.000000, d2=15.000000, n=56.000000
# 	---- error percentage = 0.020372
# Iteration #156
# 	---- error percentage = 0.001789
# Iteration #157
# 	---- error percentage = 0.008582
# Iteration #158
# 	---- error percentage = 0.002568
# Iteration #159
# 	---- error percentage = 0.009541
# Iteration #160
# 	Update parameter setting and fuzzy sets ...
# 		d1=3.000000, d2=15.000000, n=40.000000
# 	---- error percentage = 0.003780
# Iteration #161
# 	---- error percentage = 0.008770
# Iteration #162
# 	---- error percentage = 0.030225
# Iteration #163
# 	---- error percentage = 0.045876
# Iteration #164
# 	---- error percentage = 0.008863
# Iteration #165
# 	Update parameter setting and fuzzy sets ...
# 		d1=3.000000, d2=15.000000, n=58.000000
# 	---- error percentage = 0.010353
# Iteration #166
# 	---- error percentage = 0.020584
# Iteration #167
# 	---- error percentage = 0.008426
# Iteration #168
# 	---- error percentage = 0.002606
# Iteration #169
# 	---- error percentage = 0.017092
# Iteration #170
# 	Update parameter setting and fuzzy sets ...
# 		d1=3.000000, d2=15.000000, n=59.000000
# 	---- error percentage = 0.012801
# Iteration #171
# 	---- error percentage = 0.000578
# Iteration #172
# 	---- error percentage = 0.008956
# Iteration #173
# 	---- error percentage = 0.006845
# Iteration #174
# 	---- error percentage = 0.004250
# Iteration #175
# 	Update parameter setting and fuzzy sets ...
# 		d1=3.000000, d2=15.000000, n=58.000000
# 	---- error percentage = 0.021635
# Iteration #176
# 	---- error percentage = 0.015393
# Iteration #177
# 	---- error percentage = 0.007028
# Iteration #178
# 	---- error percentage = 0.010738
# Iteration #179
# 	---- error percentage = 0.005746
# Iteration #180
# 	Update parameter setting and fuzzy sets ...
# 		d1=3.000000, d2=15.000000, n=57.000000
# 	---- error percentage = 0.016213
# Iteration #181
# 	---- error percentage = 0.014981
# Iteration #182
# 	---- error percentage = 0.003147
# Iteration #183
# 	---- error percentage = 0.024136
# Iteration #184
# 	---- error percentage = 0.002027
# Iteration #185
# 	Update parameter setting and fuzzy sets ...
# 		d1=3.000000, d2=15.000000, n=59.000000
# 	---- error percentage = 0.034814
# Iteration #186
# 	---- error percentage = 0.004825
# Iteration #187
# 	---- error percentage = 0.004758
# Iteration #188
# 	---- error percentage = 0.006291
# Iteration #189
# 	---- error percentage = 0.025962
# Iteration #190
# 	Update parameter setting and fuzzy sets ...
# 		d1=3.000000, d2=15.000000, n=57.000000
# 	---- error percentage = 0.030991
# Iteration #191
# 	---- error percentage = 0.009236
# Iteration #192
# 	---- error percentage = 0.001472
# Iteration #193
# 	---- error percentage = 0.013265
# Iteration #194
# 	---- error percentage = 0.022349
# Iteration #195
# 	Update parameter setting and fuzzy sets ...
# 		d1=12.000000, d2=15.000000, n=58.000000
# 	---- error percentage = 0.015435
# Iteration #196
# 	---- error percentage = 0.003542
# Iteration #197
# 	---- error percentage = 0.013743
# Iteration #198
# 	---- error percentage = 0.003602
# Iteration #199
# 	---- error percentage = 0.009449
# Iteration #200
# 	Update parameter setting and fuzzy sets ...
# 		d1=3.000000, d2=15.000000, n=39.000000
# 	---- error percentage = 0.016451
# Iteration #201
# 	---- error percentage = 0.005906
# Iteration #202
# 	---- error percentage = 0.004136
# Iteration #203
# 	---- error percentage = 0.004769
# Iteration #204
# 	---- error percentage = 0.003352
# Iteration #205
# 	Update parameter setting and fuzzy sets ...
# 		d1=12.000000, d2=15.000000, n=59.000000
# 	---- error percentage = 0.006286
# Iteration #206
# 	---- error percentage = 0.000043
# Iteration #207
# 	---- error percentage = 0.030627
# Iteration #208
# 	---- error percentage = 0.001938
# Iteration #209
# 	---- error percentage = 0.001892
# Iteration #210
# 	Update parameter setting and fuzzy sets ...
# 		d1=12.000000, d2=15.000000, n=58.000000
# 	---- error percentage = 0.013164
# Iteration #211
# 	---- error percentage = 0.012224
# Iteration #212
# 	---- error percentage = 0.005715
# Iteration #213
# 	---- error percentage = 0.011589
# Iteration #214
# 	---- error percentage = 0.011248
# Iteration #215
# 	Update parameter setting and fuzzy sets ...
# 		d1=12.000000, d2=15.000000, n=56.000000
# 	---- error percentage = 0.012227
# Iteration #216
# 	---- error percentage = 0.004133
# Iteration #217
# 	---- error percentage = 0.005242
# Iteration #218
# 	---- error percentage = 0.001581
# Iteration #219
# 	---- error percentage = 0.008320
# Iteration #220
# 	Update parameter setting and fuzzy sets ...
# 		d1=3.000000, d2=15.000000, n=39.000000
# 	---- error percentage = 0.000998
# Iteration #221
# 	---- error percentage = 0.001665
# Iteration #222
# 	---- error percentage = 0.023435
# Iteration #223
# 	---- error percentage = 0.012027
# Iteration #224
# 	---- error percentage = 0.019521
# Iteration #225
# 	Update parameter setting and fuzzy sets ...
# 		d1=12.000000, d2=15.000000, n=55.000000
# 	---- error percentage = 0.008091
# Iteration #226
# 	---- error percentage = 0.006101
# Iteration #227
# 	---- error percentage = 0.002415
# Iteration #228
# 	---- error percentage = 0.012653
# Iteration #229
# 	---- error percentage = 0.003683
# Iteration #230
# 	Update parameter setting and fuzzy sets ...
# 		d1=3.000000, d2=15.000000, n=39.000000
# 	---- error percentage = 0.005771
# Iteration #231
# 	---- error percentage = 0.004360
# Iteration #232
# 	---- error percentage = 0.005329
# Iteration #233
# 	---- error percentage = 0.000780
# Iteration #234
# 	---- error percentage = 0.011425
# Iteration #235
# 	Update parameter setting and fuzzy sets ...
# 		d1=12.000000, d2=15.000000, n=55.000000
# 	---- error percentage = 0.000287
# Iteration #236
# 	---- error percentage = 0.005939
# Iteration #237
# 	---- error percentage = 0.031165
# Iteration #238
# 	---- error percentage = 0.008882
# Iteration #239
# 	---- error percentage = 0.012075
# Iteration #240
# 	Update parameter setting and fuzzy sets ...
# 		d1=3.000000, d2=15.000000, n=39.000000
# 	---- error percentage = 0.018357
# Iteration #241
# 	---- error percentage = 0.009927
# Iteration #242
# 	---- error percentage = 0.000091
# Iteration #243
# 	---- error percentage = 0.011989
# Iteration #244
# 	---- error percentage = 0.019291
# Iteration #245
# 	Update parameter setting and fuzzy sets ...
# 		d1=3.000000, d2=15.000000, n=56.000000
# 	---- error percentage = 0.025210
# Iteration #246
# 	---- error percentage = 0.014002
# Iteration #247
# 	---- error percentage = 0.012294
# Iteration #248
# 	---- error percentage = 0.029745
# Iteration #249
# 	---- error percentage = 0.006834
# Iteration #250
# 	Update parameter setting and fuzzy sets ...
# 		d1=3.000000, d2=15.000000, n=40.000000
# 	---- error percentage = 0.005057
# Iteration #251
# 	---- error percentage = 0.014274
# Iteration #252
# 	---- error percentage = 0.000402
# Iteration #253
# 	---- error percentage = 0.007053
# Iteration #254
# 	---- error percentage = 0.002708
# Iteration #255
# 	Update parameter setting and fuzzy sets ...
# 		d1=12.000000, d2=15.000000, n=56.000000
# 	---- error percentage = 0.004833
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-da421268066f> in <module>()
#      28     print("\t---- error percentage = %f" % pred_ep)
#      29
# ---> 30 print "MAD = "+str(mean_absolute_error(actual_prices, pred_prices))
#      31 print "RMSE = "+str(np.sqrt(mean_squared_error(actual_prices, pred_prices)))
#      32 print "MAPE = "+str(mean_absolute_percentage_error(actual_prices, pred_prices))
#
# NameError: name 'mean_absolute_error' is not defined

# %%
df_test = pd.DataFrame(test_data.iloc[1:]['Date'])
df_test['data testing'] = pd.Series(actual_prices).values
df_test['forecasting'] = pd.Series(pred_prices).values
df_test.index = df_test['Date']
plt.figure(figsize=(14,7))
df_test['data testing'].plot(style='k-', linewidth=2, label='data testing')
df_test['forecasting'].plot(style='g:', linewidth=3, label='forecasting')
plt.ylabel('Price', fontsize=18)
plt.legend(loc='best')
plt.title("IBEX35_forecasting", fontsize=24)

# %%
plt.figure(figsize=(14,7))
df_test["residual"] = df_test["data testing"] - df_test["forecasting"]
df_test["residual"].plot(style='bo', linewidth=3, label='residual')
plt.ylabel('Residual', fontsize=18)
plt.axhline(y=0.0, color='k', linestyle='--')
plt.legend(loc='best')
plt.title("IBEX35_forecasting_residual", fontsize=24)
