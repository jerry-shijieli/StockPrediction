# %% [markdown]
# Continue with v1, but dynamically update the parameters weekly (5 trading days per week)

# %%
from rectangle_fuzzy import *

import pandas as pd
import numpy as np
import operator
import matplotlib.pyplot as plt
# %matplotlib inline
from time import time

from collections import defaultdict
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error

# %%
# helper functions
def binary_to_decimal(binary, di=0):
    decimal = 0
    for i in range(len(binary)):
        if i<len(binary)-di+1:
            power = len(binary)-(i+1)-di
            decimal += int(binary[i]) * (2**power)
        else:
            power = len(binary)-(i+1)-di
            decimal += int(binary[i]) * (2**(-power))
    return decimal

def universe_partition_adjusted(data, n=10, d1=10, d2=10):
    x_max, x_min = data.max(axis=0), data.min(axis=0)   
    delta = x_max - x_min
    std_val = data.std(axis=0)
    len_val = np.round(std_val / (n+5)) # partition interval
    u_max, u_min = int(x_max+(d2+1)*delta/100), int(x_min-(d1+1)*delta/100) # bound of universe discourse
    u_b = np.arange(u_min, u_max, step=float(len_val)) # cutting points
    u_discourse = u_b
    return u_discourse

def compute_fitness(data, n, d1, d2, option='Price'):
    reserved_days = 10
    first_date = data['Date'][0] - pd.DateOffset(days=1)
    train_data = data.iloc[:-reserved_days]
    valid_data = data.iloc[-(reserved_days+1):]
    fit_prices = list()
    u_discourse = universe_partition_adjusted(train_data[option], n, d1, d2)
    A_list = set_fuzzy_numbers(u_discourse)
    train_data_membership_series = membership_assignment(train_data[option], fuzzy_numbers=u_discourse)
    transition_FLR = FLR(train_data_membership_series)
    train_data_days = train_data['Date'].apply(lambda x: x-first_date).dt.days.tolist()
    jump_weights = FLR_weight(transition_FLR, train_data_days[:len(transition_FLR)])
    transition_weights = FRG_weight(transition_FLR, train_data_days[:len(transition_FLR)])
    for price in valid_data.iloc[:-1][option]:
        index = get_membership(price, u_discourse)
        next_price = forecast_price(forecast_jump(index, jump_weights, A_list), forecast_transition(index, transition_weights, A_list), gamma=0.9)
        fit_prices.append(next_price)
    return np.sqrt(mean_squared_error(valid_data.iloc[1:][option], fit_prices))

def parameter_tuning_ASHLO(data, option):
    # initialize hyperparameters
    d1_digits = 4
    n_digits = 6
    d2_digits = 4
    population = 20
    iter_max = 100
    pr = 0.1
    pi = 0.9
    # initialize data structures
    dim_IKD = d1_digits+n_digits+d2_digits
    RMSE_list = list() # training data RMSE as fitness function value
    IKD = np.zeros((population, dim_IKD), dtype=int) # individual learning 
    SKD = np.array([]) # social network learning
    RMSE_min = 0 # best fitness value
    for i in range(population):
        for j in range(dim_IKD):
            r = np.random.rand()
            if r>0.5:
                IKD[i, j] = 0
            else:
                IKD[i, j] = 1
        d1 = binary_to_decimal(IKD[i, 0:d1_digits])
        d2 = binary_to_decimal(IKD[i, (d1_digits+n_digits): dim_IKD])
        n_par = binary_to_decimal(IKD[i, d1_digits:(d1_digits+n_digits)])
        rmse = compute_fitness(data, n_par, d1, d2)
        RMSE_list.append(rmse)
    RMSE_min = np.min(RMSE_list)
    SKD = np.array(IKD[np.argmin(RMSE_list)])
    # learning iterations
    for iter_count in range(iter_max):
        temp_IKD = np.zeros((population, dim_IKD))
        temp_rmse_list = list()
        # learning process
        for i in range(population):
            for j in range(dim_IKD):
                p = np.random.rand()
                if p < pi:
                    r = np.random.rand()
                    if r > 0.5:
                        temp_IKD[i, j] = 1
                elif pi <= p <= pr:
                    temp_IKD[i,j] = IKD[i, j]
                else:
                    temp_IKD[i,j] = SKD[j]
        # update fitness of newly learned knowledge 
        for i in range(population):
            d1 = binary_to_decimal(temp_IKD[i, 0:d1_digits])
            d2 = binary_to_decimal(temp_IKD[i, (d1_digits+n_digits): dim_IKD])
            n_par = binary_to_decimal(temp_IKD[i, d1_digits:(d1_digits+n_digits)])
            rmse = compute_fitness(data, n_par, d1, d2)
            temp_rmse_list.append(rmse)

        # update knowledge base if necessary
        RMSE_max = np.max(RMSE_list) # worst individual fitness
        RMSE_max_index = np.argmax(RMSE_list)
        for i in range(population):
            if temp_rmse_list[i] < RMSE_max:
                IKD[RMSE_max_index] = temp_IKD[i]
                RMSE_list[RMSE_max_index] = temp_rmse_list[i]
                RMSE_max = np.max(RMSE_list)
                RMSE_max_index = np.argmax(RMSE_list)
        temp_rmse_min = np.min(RMSE_list) # best individual fitness
        if RMSE_min > temp_rmse_min:
            SKD = np.array(IKD[np.argmin(RMSE_list)])
            RMSE_min = temp_rmse_min
    # output optimal parameter settings        
    d1 = binary_to_decimal(temp_IKD[i, 0:d1_digits])
    d2 = binary_to_decimal(temp_IKD[i, (d1_digits+n_digits): dim_IKD])
    n_par = binary_to_decimal(temp_IKD[i, d1_digits:(d1_digits+n_digits)])
    return d1, n_par, d2

# %%
# Load data 
start_time = time()
datafile = '../data/IBEX35.csv'
dateparse = lambda x: pd.datetime.strptime(x, '%m/%d/%y')
df = pd.read_csv(datafile, header=0, parse_dates=['Date'], date_parser=dateparse)

split_date = pd.datetime.strptime('2014-12-31', '%Y-%m-%d')
train_data = df[df['Date'] < split_date]
test_data = df[df['Date'] >= split_date]
first_date = train_data['Date'][0] - pd.DateOffset(days=1)

option = 'Price'
update_interval = 10 # days

# %%
# forecasting using test data
start_time = time()
pred_prices = list()
error_percentages = list() # percentage of forecasting residual
actual_prices = test_data[option].tolist()[1:]
indices = test_data.index
for i in range(len(indices)-1):
    print("Iteration #%s" % str(i))
    prev = test_data.iloc[i]
    train_data.append(prev)
    if (i % update_interval)==0:
        print("\tUpdate parameter setting and fuzzy sets ...")
        d1, n_par, d2 = parameter_tuning_ASHLO(train_data, option)
        print("\t\td1=%f, d2=%f, n=%f" % (d1, d2, n_par))
        u_discourse = universe_partition_adjusted(train_data[option], n_par, d1, d2)
        A_list = set_fuzzy_numbers(u_discourse)
        train_data_membership_series = membership_assignment(train_data[option], fuzzy_numbers=u_discourse)
        transition_FLR = FLR(train_data_membership_series)
        train_data_days = train_data['Date'].apply(lambda x: x-first_date).dt.days.tolist() # convert Timedelta to numeric days
        jump_weights = FLR_weight(transition_FLR, train_data_days[:len(transition_FLR)])
        transition_weights = FRG_weight(transition_FLR, train_data_days[:len(transition_FLR)])
    price = prev[option]
    index = get_membership(price, u_discourse)
    next_price = forecast_price(forecast_jump(index, jump_weights, A_list), forecast_transition(index, transition_weights, A_list), gamma=0.9)
    pred_prices.append(next_price)
    pred_ep = (np.abs(actual_prices[i] - next_price)/actual_prices[i])
    error_percentages.append(pred_ep)
    print("\t---- error percentage = %f" % pred_ep)
    
print "RMSE = "+str(np.sqrt(mean_squared_error(actual_prices, pred_prices)))
print("Average Error Percentage = %f" % np.mean(error_percentages))
print "Time cost: "+str(time()-start_time)+" seconds"
# Out:
# Iteration #0
# 	Update parameter setting and fuzzy sets ...
# 		d1=15.000000, d2=2.000000, n=61.000000
# Iteration #1
# Iteration #2
# Iteration #3
# Iteration #4
# Iteration #5
# 	Update parameter setting and fuzzy sets ...
# 		d1=7.000000, d2=11.000000, n=26.000000
# Iteration #6
# Iteration #7
# Iteration #8
# Iteration #9
# Iteration #10
# 	Update parameter setting and fuzzy sets ...
# 		d1=12.000000, d2=0.000000, n=13.000000
# Iteration #11
# Iteration #12
# Iteration #13
# Iteration #14
# Iteration #15
# 	Update parameter setting and fuzzy sets ...
# 		d1=12.000000, d2=1.000000, n=63.000000
# Iteration #16
# Iteration #17
# Iteration #18
# Iteration #19
# Iteration #20
# 	Update parameter setting and fuzzy sets ...
# 		d1=13.000000, d2=1.000000, n=49.000000
# Iteration #21
# Iteration #22
# Iteration #23
# Iteration #24
# Iteration #25
# 	Update parameter setting and fuzzy sets ...
# 		d1=12.000000, d2=13.000000, n=25.000000
# Iteration #26
# Iteration #27
# Iteration #28
# Iteration #29
# Iteration #30
# 	Update parameter setting and fuzzy sets ...
# 		d1=2.000000, d2=4.000000, n=27.000000
# Iteration #31
# Iteration #32
# Iteration #33
# Iteration #34
# Iteration #35
# 	Update parameter setting and fuzzy sets ...
# 		d1=2.000000, d2=3.000000, n=33.000000
# Iteration #36
# Iteration #37
# Iteration #38
# Iteration #39
# Iteration #40
# 	Update parameter setting and fuzzy sets ...
# 		d1=8.000000, d2=9.000000, n=33.000000
# Iteration #41
# Iteration #42
# Iteration #43
# Iteration #44
# Iteration #45
# 	Update parameter setting and fuzzy sets ...
# 		d1=9.000000, d2=14.000000, n=46.000000
# Iteration #46
# Iteration #47
# Iteration #48
# Iteration #49
# Iteration #50
# 	Update parameter setting and fuzzy sets ...
# 		d1=8.000000, d2=14.000000, n=25.000000
# Iteration #51
# Iteration #52
# Iteration #53
# Iteration #54
# Iteration #55
# 	Update parameter setting and fuzzy sets ...
# 		d1=1.000000, d2=15.000000, n=19.000000
# Iteration #56
# Iteration #57
# Iteration #58
# Iteration #59
# Iteration #60
# 	Update parameter setting and fuzzy sets ...
# 		d1=9.000000, d2=9.000000, n=47.000000
# Iteration #61
# Iteration #62
# Iteration #63
# Iteration #64
# Iteration #65
# 	Update parameter setting and fuzzy sets ...
# 		d1=10.000000, d2=14.000000, n=52.000000
# Iteration #66
# Iteration #67
# Iteration #68
# Iteration #69
# Iteration #70
# 	Update parameter setting and fuzzy sets ...
# 		d1=1.000000, d2=3.000000, n=52.000000
# Iteration #71
# Iteration #72
# Iteration #73
# Iteration #74
# Iteration #75
# 	Update parameter setting and fuzzy sets ...
# 		d1=10.000000, d2=11.000000, n=63.000000
# Iteration #76
# Iteration #77
# Iteration #78
# Iteration #79
# Iteration #80
# 	Update parameter setting and fuzzy sets ...
# 		d1=10.000000, d2=15.000000, n=16.000000
# Iteration #81
# Iteration #82
# Iteration #83
# Iteration #84
# Iteration #85
# 	Update parameter setting and fuzzy sets ...
# 		d1=15.000000, d2=13.000000, n=51.000000
# Iteration #86
# Iteration #87
# Iteration #88
# Iteration #89
# Iteration #90
# 	Update parameter setting and fuzzy sets ...
# 		d1=8.000000, d2=11.000000, n=45.000000
# Iteration #91
# Iteration #92
# Iteration #93
# Iteration #94
# Iteration #95
# 	Update parameter setting and fuzzy sets ...
# 		d1=1.000000, d2=15.000000, n=61.000000
# Iteration #96
# Iteration #97
# Iteration #98
# Iteration #99
# Iteration #100
# 	Update parameter setting and fuzzy sets ...
# 		d1=1.000000, d2=8.000000, n=47.000000
# Iteration #101
# Iteration #102
# Iteration #103
# Iteration #104
# Iteration #105
# 	Update parameter setting and fuzzy sets ...
# 		d1=8.000000, d2=4.000000, n=29.000000
# Iteration #106
# Iteration #107
# Iteration #108
# Iteration #109
# Iteration #110
# 	Update parameter setting and fuzzy sets ...
# 		d1=13.000000, d2=15.000000, n=35.000000
# Iteration #111
# Iteration #112
# Iteration #113
# Iteration #114
# Iteration #115
# 	Update parameter setting and fuzzy sets ...
# 		d1=7.000000, d2=12.000000, n=45.000000
# Iteration #116
# Iteration #117
# Iteration #118
# Iteration #119
# Iteration #120
# 	Update parameter setting and fuzzy sets ...
# 		d1=1.000000, d2=8.000000, n=48.000000
# Iteration #121
# Iteration #122
# Iteration #123
# Iteration #124
# Iteration #125
# 	Update parameter setting and fuzzy sets ...
# 		d1=0.000000, d2=9.000000, n=13.000000
# Iteration #126
# Iteration #127
# Iteration #128
# Iteration #129
# Iteration #130
# 	Update parameter setting and fuzzy sets ...
# 		d1=13.000000, d2=14.000000, n=33.000000
# Iteration #131
# Iteration #132
# Iteration #133
# Iteration #134
# Iteration #135
# 	Update parameter setting and fuzzy sets ...
# 		d1=10.000000, d2=12.000000, n=1.000000
# Iteration #136
# Iteration #137
# Iteration #138
# Iteration #139
# Iteration #140
# 	Update parameter setting and fuzzy sets ...
# 		d1=13.000000, d2=10.000000, n=1.000000
# Iteration #141
# Iteration #142
# Iteration #143
# Iteration #144
# Iteration #145
# 	Update parameter setting and fuzzy sets ...
# 		d1=9.000000, d2=12.000000, n=20.000000
# Iteration #146
# Iteration #147
# Iteration #148
# Iteration #149
# Iteration #150
# 	Update parameter setting and fuzzy sets ...
# 		d1=4.000000, d2=8.000000, n=29.000000
# Iteration #151
# Iteration #152
# Iteration #153
# Iteration #154
# Iteration #155
# 	Update parameter setting and fuzzy sets ...
# 		d1=12.000000, d2=11.000000, n=54.000000
# Iteration #156
# Iteration #157
# Iteration #158
# Iteration #159
# Iteration #160
# 	Update parameter setting and fuzzy sets ...
# 		d1=13.000000, d2=1.000000, n=28.000000
# Iteration #161
# Iteration #162
# Iteration #163
# Iteration #164
# Iteration #165
# 	Update parameter setting and fuzzy sets ...
# 		d1=10.000000, d2=11.000000, n=17.000000
# Iteration #166
# Iteration #167
# Iteration #168
# Iteration #169
# Iteration #170
# 	Update parameter setting and fuzzy sets ...
# 		d1=10.000000, d2=3.000000, n=22.000000
# Iteration #171
# Iteration #172
# Iteration #173
# Iteration #174
# Iteration #175
# 	Update parameter setting and fuzzy sets ...
# 		d1=1.000000, d2=6.000000, n=26.000000
# Iteration #176
# Iteration #177
# Iteration #178
# Iteration #179
# Iteration #180
# 	Update parameter setting and fuzzy sets ...
# 		d1=7.000000, d2=5.000000, n=33.000000
# Iteration #181
# Iteration #182
# Iteration #183
# Iteration #184
# Iteration #185
# 	Update parameter setting and fuzzy sets ...
# 		d1=4.000000, d2=14.000000, n=49.000000
# Iteration #186
# Iteration #187
# Iteration #188
# Iteration #189
# Iteration #190
# 	Update parameter setting and fuzzy sets ...
# 		d1=6.000000, d2=12.000000, n=16.000000
# Iteration #191
# Iteration #192
# Iteration #193
# Iteration #194
# Iteration #195
# 	Update parameter setting and fuzzy sets ...
# 		d1=7.000000, d2=1.000000, n=11.000000
# Iteration #196
# Iteration #197
# Iteration #198
# Iteration #199
# Iteration #200
# 	Update parameter setting and fuzzy sets ...
# 		d1=12.000000, d2=9.000000, n=45.000000
# Iteration #201
# Iteration #202
# Iteration #203
# Iteration #204
# Iteration #205
# 	Update parameter setting and fuzzy sets ...
# 		d1=15.000000, d2=4.000000, n=22.000000
# Iteration #206
# Iteration #207
# Iteration #208
# Iteration #209
# Iteration #210
# 	Update parameter setting and fuzzy sets ...
# 		d1=9.000000, d2=3.000000, n=16.000000
# Iteration #211
# Iteration #212
# Iteration #213
# Iteration #214
# Iteration #215
# 	Update parameter setting and fuzzy sets ...
# 		d1=1.000000, d2=0.000000, n=33.000000
# Iteration #216
# Iteration #217
# Iteration #218
# Iteration #219
# Iteration #220
# 	Update parameter setting and fuzzy sets ...
# 		d1=10.000000, d2=5.000000, n=59.000000
# Iteration #221
# Iteration #222
# Iteration #223
# Iteration #224
# Iteration #225
# 	Update parameter setting and fuzzy sets ...
# 		d1=3.000000, d2=11.000000, n=33.000000
# Iteration #226
# Iteration #227
# Iteration #228
# Iteration #229
# Iteration #230
# 	Update parameter setting and fuzzy sets ...
# 		d1=10.000000, d2=1.000000, n=8.000000
# Iteration #231
# Iteration #232
# Iteration #233
# Iteration #234
# Iteration #235
# 	Update parameter setting and fuzzy sets ...
# 		d1=5.000000, d2=14.000000, n=52.000000
# Iteration #236
# Iteration #237
# Iteration #238
# Iteration #239
# Iteration #240
# 	Update parameter setting and fuzzy sets ...
# 		d1=5.000000, d2=0.000000, n=12.000000
# Iteration #241
# Iteration #242
# Iteration #243
# Iteration #244
# Iteration #245
# 	Update parameter setting and fuzzy sets ...
# 		d1=14.000000, d2=5.000000, n=59.000000
# Iteration #246
# Iteration #247
# Iteration #248
# Iteration #249
# Iteration #250
# 	Update parameter setting and fuzzy sets ...
# 		d1=12.000000, d2=5.000000, n=1.000000
# Iteration #251
# Iteration #252
# Iteration #253
# Iteration #254
# Iteration #255
# 	Update parameter setting and fuzzy sets ...
# 		d1=5.000000, d2=11.000000, n=8.000000
# RMSE = 146.828465793
# Time cost: 605.341389894 seconds

# %%
df_test = pd.DataFrame(test_data.iloc[1:]['Date'])
df_test['data testing'] = pd.Series(actual_prices).values
df_test['forecasting'] = pd.Series(pred_prices).values
df_test.index = df_test['Date']
plt.figure(figsize=(14,7))
df_test['data testing'].plot(style='k-', linewidth=2, label='data testing')
df_test['forecasting'].plot(style='g:', linewidth=3, label='forecasting')
plt.ylabel('Price', fontsize=18)
plt.legend(loc='best')
plt.title("IBEX35_forecasting", fontsize=24)
