# %% [markdown]
# Since the reference paper didn't make full use of the trapezoidal fuzzy function, we can change it to a simpler rectangular shape only when performing membership computation. Here we use the universe discourse directly.

# %%
import pandas as pd
import numpy as np
import operator
import matplotlib.pyplot as plt
import plotly.plotly as py
import plotly.graph_objs as go
# %matplotlib inline
from time import time

from collections import defaultdict
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
from plotly.offline import init_notebook_mode

py.sign_in('imaginationsuper', 'PQj7gXzsTJFqNKsXkWMT')
init_notebook_mode(connected=True)
# Out:
# <script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window.Plotly) {{require(['plotly'],function(plotly) {window.Plotly=plotly;});}}</script>

# %%
def universe_partition(data, d1=10, d2=10):
    x_max, x_min = data.max(axis=0), data.min(axis=0)    
    std_val = data.std(axis=0)
    len_val = np.round(std_val / 10)
#     len_val = 20
#     u_max, u_min = 12600+len_val, 6600-len_val
    u_max, u_min = int(x_max+d2), int(x_min-d1) # bound of universe discourse
    u_b = np.arange(u_min, u_max, step=float(len_val)) # cutting points
    u_discourse = u_b
    return u_discourse

def set_fuzzy_numbers(u_discourse_raw):
    u_s = u_discourse_raw[:-1]
    u_e = u_discourse_raw[1:]
    u_discourse = zip(u_s, u_e)
    fuzzy_numbers = list()
    for i, u_i in enumerate(u_discourse):
        if (i!=0) and (i!=len(u_discourse)-1):
            u_l, u_r = u_discourse[i-1], u_discourse[i+1]
            A_l, A_r = np.mean(u_l), np.mean(u_r)
            fuzzy_numbers.append(np.array([A_l, u_i[0], u_i[1], A_r]))
    return fuzzy_numbers

# %%
def membership_assignment(value_time_series, fuzzy_numbers):
    membership_list = np.digitize(value_time_series, fuzzy_numbers)-2
    return membership_list.tolist()

def get_membership(value, fuzzy_numbers):
    membership_index = np.digitize([value], fuzzy_numbers)[0]-2
    return membership_index

# %%
def FLR(membership_time_series): # transition between consecutive observations
    transitions = list()
    for j, Aj in enumerate(membership_time_series):
        if j!=0:
            Ai = membership_time_series[j-1]
            transitions.append((Ai, Aj))
    return transitions

def FLR_weight(transitions, time_series): # compute jump frequency by FLR
    jumps = map(lambda x: x[1]-x[0], transitions) # compute jumps by transitions 
    jump_time_series = zip(jumps, time_series) # assign timestamp for each jump beta^t_p,p+k
    jump_counts = defaultdict(list) 
    for key, value in jump_time_series:
        jump_counts[key].append(value) # count jump by its timestamps
    jump_counts = {key: sum(value) for key, value in jump_counts.items()} # sum up total time for each jump
    total_count = float(sum(jump_counts.values()))
    for key, value in jump_counts.iteritems(): 
        jump_counts[key] = value / total_count # normalize jumps as weights
    return jump_counts

def FRG_weight(transitions, time_series): 
    transition_time_series = zip(transitions, time_series)
    transition_groups = map(lambda x: (x[0][0], (x[0][1], x[1])), transition_time_series) 
    transition_weights = defaultdict(list)
    for key, value in transition_groups:
        transition_weights[key].append(value) # group transitions by initial state A_i
    transition_weights = {key: dict(value) for key, value in transition_weights.items()}
    for key, value in transition_weights.iteritems():
        total_weight = float(sum(value.values()))
        value = {k: (v/total_weight) for k, v in value.items()} # normalize weight inside each group
        transition_weights[key] = value
    return transition_weights

# %%
# forecasting by fuzzy numbers
def fuzzy_add(A, B): # Proposition #1 (1)
    return A + B # A and B are numpy array type

def fuzzy_scale(c, A): # Proposition #1 (2)
    cA = c*A # A is numpy array type
    if c>=0:
        return cA
    else:
        return cA[::-1]

def forecast_jump(i, s, A_list):
    jumps = s.keys() # possible jumps
    m = len(A_list) # number of fuzzy numbers in model
    sA_list = list()
    sk_list = list()
    Aip_list = list()
    sA = np.array([0.0]*len(A_list[0]))
    for k in jumps:
        ip = k+i
        if (ip>=0 and ip<m): # check if index is within range
            sk_list.append(s[k])
            Aip_list.append(A_list[ip])
    sk_list = np.array(sk_list) / sum(sk_list) # normalize locally
    for i in range(sk_list.size):
        sA_list.append(fuzzy_scale(sk_list[i], Aip_list[i]))
    if len(sA_list)>0:
        for sa in sA_list:
            sA = fuzzy_add(sA, sa)
    return sA
    
def forecast_transition(i, w, A_list):
    wA = np.array([0.0]*len(A_list[0])) # default FLG relation
    if i in w.keys():
        for kj, v in w[i].iteritems():
            wA = fuzzy_add(wA, fuzzy_scale(v, A_list[kj]))
    return wA

def forecast_price(As, Aw, gamma=0.1):
    if gamma<0 or gamma>1:
        raise ValueError("gamma should be between 0.0 and 1.0 (inclusive on both ends)")     
    wAi = fuzzy_scale(1-gamma, Aw)
    if (np.sum(wAi) == 0): # no FLR observed in history
        sAi = As
    else:
        sAi = fuzzy_scale(gamma, As)
    Ai_pred = fuzzy_add(sAi, wAi)
    return np.mean(Ai_pred)

# %%
start_time = time()
datafile = '../data/IBEX35.csv'
dateparse = lambda x: pd.datetime.strptime(x, '%m/%d/%y')
df = pd.read_csv(datafile, header=0, parse_dates=['Date'], date_parser=dateparse)

split_date = pd.datetime.strptime('2014-12-31', '%Y-%m-%d')
train_data = df[df['Date'] < split_date]
test_data = df[df['Date'] >= split_date]
first_date = train_data['Date'][0] - pd.DateOffset(days=1)

# %%
option = 'Price'
pred_prices = list()
actual_prices = test_data[option].tolist()[1:]
indices = test_data.index
for i in range(len(indices)-1):
    stm = time()
    #id = indices[i]
    prev = test_data.iloc[i]
    train_data.append(prev)
    print("Update data: %s seconds" % str(time() - stm))
    stm = time()
    u_discourse = universe_partition(train_data[option], d1=1053, d2=912)
    print("Partition discourse: %s seconds" % str(time() - stm))
    stm = time()
    A_list = set_fuzzy_numbers(u_discourse)
    print("Create fuzzy number: %s seconds" % str(time() - stm))
    stm = time()
    train_data_membership_series = membership_assignment(train_data[option], fuzzy_numbers=u_discourse)
#     train_data_ms = [ms+1 for ms in train_data_membership_series]
    print("Update fuzzy membership: %s seconds" % str(time() - stm))
    stm = time()
    transition_FLR = FLR(train_data_membership_series)
    print("Update FLR: %s seconds" % str(time() - stm))
    stm = time()
    train_data_days = train_data['Date'].apply(lambda x: x-first_date).dt.days.tolist() # convert Timedelta to numeric days
    jump_weights = FLR_weight(transition_FLR, train_data_days[:len(transition_FLR)])
    print("Update jump weights: %s seconds" % str(time() - stm))
    stm = time()
    transition_weights = FRG_weight(transition_FLR, train_data_days[:len(transition_FLR)])
    print("Update transition weights: %s seconds" % str(time() - stm))
    stm = time()
    # forecasting current test data
    price = prev[option]
    index = get_membership(price, u_discourse)
    print("Assign membership for test case: %s seconds" % str(time() - stm))
    stm = time()
    next_price = forecast_price(forecast_jump(index, jump_weights, A_list), forecast_transition(index, transition_weights, A_list), gamma=0.9)
    print("Forecast next price: %s seconds" % str(time() - stm))
    stm = time()
    pred_prices.append(next_price)
    
print "RMSE = "+str(np.sqrt(mean_squared_error(actual_prices, pred_prices)))
print "Time cost: "+str(time()-start_time)+" seconds"
# Out:
# Update data: 0.00424194335938 seconds
# Partition discourse: 0.00065016746521 seconds
# Create fuzzy number: 0.00159502029419 seconds
# Update fuzzy membership: 6.60419464111e-05 seconds
# Update FLR: 0.000181913375854 seconds
# Update jump weights: 0.0139260292053 seconds
# Update transition weights: 0.000464916229248 seconds
# Assign membership for test case: 5.29289245605e-05 seconds
# Forecast next price: 0.000134944915771 seconds
# Update data: 0.00234198570251 seconds
# Partition discourse: 0.00065803527832 seconds
# Create fuzzy number: 0.00136494636536 seconds
# Update fuzzy membership: 6.103515625e-05 seconds
# Update FLR: 0.000112056732178 seconds
# Update jump weights: 0.0142850875854 seconds
# Update transition weights: 0.000385046005249 seconds
# Assign membership for test case: 5.00679016113e-05 seconds
# Forecast next price: 0.000121831893921 seconds
# Update data: 0.00234484672546 seconds
# Partition discourse: 0.000282049179077 seconds
# Create fuzzy number: 0.00134611129761 seconds
# Update fuzzy membership: 4.91142272949e-05 seconds
# Update FLR: 0.000107765197754 seconds
# Update jump weights: 0.01580286026 seconds
# Update transition weights: 0.000532865524292 seconds
# Assign membership for test case: 6.38961791992e-05 seconds
# Forecast next price: 0.000211000442505 seconds
# Update data: 0.00299906730652 seconds
# Partition discourse: 0.000293016433716 seconds
# Create fuzzy number: 0.00144410133362 seconds
# Update fuzzy membership: 7.5101852417e-05 seconds
# Update FLR: 0.000280857086182 seconds
# Update jump weights: 0.0211770534515 seconds
# Update transition weights: 0.000606060028076 seconds
# Assign membership for test case: 0.000195026397705 seconds
# Forecast next price: 0.000203132629395 seconds
# Update data: 0.00317001342773 seconds
# Partition discourse: 0.000505924224854 seconds
# Create fuzzy number: 0.00255990028381 seconds
# Update fuzzy membership: 0.000119924545288 seconds
# Update FLR: 0.000147819519043 seconds
# Update jump weights: 0.0159149169922 seconds
# Update transition weights: 0.000555038452148 seconds
# Assign membership for test case: 6.19888305664e-05 seconds
# Forecast next price: 0.000200986862183 seconds
# Update data: 0.00276803970337 seconds
# Partition discourse: 0.000505924224854 seconds
# Create fuzzy number: 0.00154280662537 seconds
# Update fuzzy membership: 7.48634338379e-05 seconds
# Update FLR: 0.000118017196655 seconds
# Update jump weights: 0.0228450298309 seconds
# Update transition weights: 0.000603914260864 seconds
# Assign membership for test case: 0.000125885009766 seconds
# Forecast next price: 0.000200986862183 seconds
# Update data: 0.00382494926453 seconds
# Partition discourse: 0.000458955764771 seconds
# Create fuzzy number: 0.00194501876831 seconds
# Update fuzzy membership: 0.00022292137146 seconds
# Update FLR: 0.000194072723389 seconds
# Update jump weights: 0.0678269863129 seconds
# Update transition weights: 0.000504016876221 seconds
# Assign membership for test case: 6.60419464111e-05 seconds
# Forecast next price: 0.000205039978027 seconds
# Update data: 0.00287079811096 seconds
# Partition discourse: 0.00031304359436 seconds
# Create fuzzy number: 0.00136590003967 seconds
# Update FLR: 0.000116109848022 seconds
# Update jump weights: 0.0154440402985 seconds
# Update transition weights: 0.000502109527588 seconds
# Assign membership for test case: 5.50746917725e-05 seconds
# Forecast next price: 0.000125169754028 seconds
# Update data: 0.00243282318115 seconds
# Partition discourse: 0.000282049179077 seconds
# Create fuzzy number: 0.0013599395752 seconds
# Update fuzzy membership: 0.000173091888428 seconds
# Update FLR: 0.000244855880737 seconds
# Update jump weights: 0.0160088539124 seconds
# Update transition weights: 0.000698089599609 seconds
# Assign membership for test case: 8.41617584229e-05 seconds
# Forecast next price: 0.000211954116821 seconds
# Update data: 0.00462198257446 seconds
# Partition discourse: 0.000385046005249 seconds
# Create fuzzy number: 0.00144195556641 seconds
# Update fuzzy membership: 5.60283660889e-05 seconds
# Update FLR: 0.000119924545288 seconds
# Update jump weights: 0.0160100460052 seconds
# Update transition weights: 0.000440120697021 seconds
# Assign membership for test case: 6.29425048828e-05 seconds
# Forecast next price: 0.000118017196655 seconds
# Update data: 0.00284695625305 seconds
# Partition discourse: 0.000290870666504 seconds
# Create fuzzy number: 0.00141215324402 seconds
# Update fuzzy membership: 5.98430633545e-05 seconds
# Update FLR: 0.000130891799927 seconds
# Update jump weights: 0.015918970108 seconds
# Update transition weights: 0.000416994094849 seconds
# Assign membership for test case: 5.60283660889e-05 seconds
# Forecast next price: 0.000113010406494 seconds
# Update data: 0.00251507759094 seconds
# Partition discourse: 0.000335931777954 seconds
# Create fuzzy number: 0.00171303749084 seconds
# Update fuzzy membership: 0.000118970870972 seconds
# Update FLR: 0.000237941741943 seconds
# Update jump weights: 0.0182781219482 seconds
# Update transition weights: 0.000566005706787 seconds
# Assign membership for test case: 0.000143051147461 seconds
# Forecast next price: 0.00026798248291 seconds
# Update data: 0.00339102745056 seconds
# Partition discourse: 0.000309944152832 seconds
# Create fuzzy number: 0.00136804580688 seconds
# Update fuzzy membership: 5.79357147217e-05 seconds
# Update FLR: 0.000118970870972 seconds
# Update jump weights: 0.0154039859772 seconds
# Update transition weights: 0.000419139862061 seconds
# Assign membership for test case: 4.88758087158e-05 seconds
# Forecast next price: 0.000113964080811 seconds
# Update data: 0.00255489349365 seconds
# Partition discourse: 0.000295877456665 seconds
# Create fuzzy number: 0.00156307220459 seconds
# Update fuzzy membership: 5.50746917725e-05 seconds
# Update FLR: 0.000123023986816 seconds
# Update jump weights: 0.0186679363251 seconds
# Update transition weights: 0.00140500068665 seconds
# Assign membership for test case: 0.000152111053467 seconds
# Forecast next price: 0.000472068786621 seconds
# Update data: 0.00520586967468 seconds
# Partition discourse: 0.000326871871948 seconds
# Create fuzzy number: 0.00148701667786 seconds
# Update fuzzy membership: 7.5101852417e-05 seconds
# Update FLR: 0.0001380443573 seconds
# Update jump weights: 0.0200798511505 seconds
# Update transition weights: 0.000745058059692 seconds
# Assign membership for test case: 7.70092010498e-05 seconds
# Forecast next price: 0.000133991241455 seconds
# Update data: 0.00281286239624 seconds
# Partition discourse: 0.000339984893799 seconds
# Create fuzzy number: 0.00137782096863 seconds
# Update fuzzy membership: 6.103515625e-05 seconds
# Update transition weights: 0.000526189804077 seconds
# Assign membership for test case: 5.98430633545e-05 seconds
# Forecast next price: 0.000116109848022 seconds
# Update data: 0.0024299621582 seconds
# Partition discourse: 0.00028395652771 seconds
# Create fuzzy number: 0.00183701515198 seconds
# Update fuzzy membership: 0.00025486946106 seconds
# Update FLR: 0.00022292137146 seconds
# Update jump weights: 0.0158698558807 seconds
# Update transition weights: 0.000592947006226 seconds
# Assign membership for test case: 9.91821289062e-05 seconds
# Forecast next price: 0.000181913375854 seconds
# Update data: 0.00273489952087 seconds
# Partition discourse: 0.000288963317871 seconds
# Create fuzzy number: 0.00135803222656 seconds
# Update fuzzy membership: 5.29289245605e-05 seconds
# Update FLR: 0.000127077102661 seconds
# Update jump weights: 0.0174589157104 seconds
# Update transition weights: 0.00114917755127 seconds
# Assign membership for test case: 0.000137090682983 seconds
# Forecast next price: 0.00033712387085 seconds
# Update data: 0.00282788276672 seconds
# Partition discourse: 0.00028920173645 seconds
# Create fuzzy number: 0.00135707855225 seconds
# Update fuzzy membership: 5.60283660889e-05 seconds
# Update FLR: 0.000126123428345 seconds
# Update jump weights: 0.0168490409851 seconds
# Update transition weights: 0.000502109527588 seconds
# Assign membership for test case: 0.000118970870972 seconds
# Forecast next price: 0.000174999237061 seconds
# Update data: 0.00293612480164 seconds
# Partition discourse: 0.000291109085083 seconds
# Create fuzzy number: 0.0013530254364 seconds
# Update fuzzy membership: 5.57899475098e-05 seconds
# Update FLR: 0.000126123428345 seconds
# Update jump weights: 0.0163671970367 seconds
# Update transition weights: 0.000465869903564 seconds
# Assign membership for test case: 6.19888305664e-05 seconds
# Forecast next price: 0.000116109848022 seconds
# Update data: 0.0041389465332 seconds
# Partition discourse: 0.000793933868408 seconds
# Create fuzzy number: 0.00179982185364 seconds
# Update fuzzy membership: 7.10487365723e-05 seconds
# Update FLR: 0.000123023986816 seconds
# Update jump weights: 0.0173289775848 seconds
# Update transition weights: 0.000425815582275 seconds
# Assign membership for test case: 5.19752502441e-05 seconds
# Forecast next price: 0.000149011611938 seconds
# Update data: 0.00340485572815 seconds
# Partition discourse: 0.000293016433716 seconds
# Create fuzzy number: 0.001384973526 seconds
# Update fuzzy membership: 6.79492950439e-05 seconds
# Update FLR: 0.000130891799927 seconds
# Update jump weights: 0.0191249847412 seconds
# Update transition weights: 0.00103616714478 seconds
# Assign membership for test case: 0.000112056732178 seconds
# Forecast next price: 0.000341176986694 seconds
# Update data: 0.00327610969543 seconds
# Partition discourse: 0.000424861907959 seconds
# Create fuzzy number: 0.00179004669189 seconds
# Update fuzzy membership: 7.5101852417e-05 seconds
# Update FLR: 0.000380992889404 seconds
# Update jump weights: 0.0171840190887 seconds
# Update transition weights: 0.000501155853271 seconds
# Assign membership for test case: 6.79492950439e-05 seconds
# Forecast next price: 0.000123977661133 seconds
# Update data: 0.00259900093079 seconds
# Partition discourse: 0.000295877456665 seconds
# Create fuzzy number: 0.00156688690186 seconds
# Update fuzzy membership: 5.19752502441e-05 seconds
# Update FLR: 0.000119924545288 seconds
# Update jump weights: 0.0165829658508 seconds
# Update transition weights: 0.000870227813721 seconds
# Assign membership for test case: 0.000154972076416 seconds
# Forecast next price: 0.000162839889526 seconds
# Update data: 0.00321888923645 seconds
# Partition discourse: 0.000328063964844 seconds
# Create fuzzy number: 0.00216007232666 seconds
# Update fuzzy membership: 7.70092010498e-05 seconds
# Update FLR: 0.00012993812561 seconds
# Update jump weights: 0.0202450752258 seconds
# Update transition weights: 0.000795125961304 seconds
# Assign membership for test case: 8.51154327393e-05 seconds
# Forecast next price: 0.000201940536499 seconds
# Update data: 0.00252389907837 seconds
# Partition discourse: 0.000287055969238 seconds
# Create fuzzy number: 0.00233101844788 seconds
# Update fuzzy membership: 7.70092010498e-05 seconds
# Update FLR: 0.00013279914856 seconds
# Update jump weights: 0.0170879364014 seconds
# Update transition weights: 0.000412940979004 seconds
# Assign membership for test case: 5.19752502441e-05 seconds
# Forecast next price: 0.000117063522339 seconds
# Update data: 0.00299406051636 seconds
# Partition discourse: 0.000324010848999 seconds
# Create fuzzy number: 0.00209808349609 seconds
# Update fuzzy membership: 8.9168548584e-05 seconds
# Update FLR: 0.000238180160522 seconds
# Update jump weights: 0.0173950195312 seconds
# Update transition weights: 0.000412940979004 seconds
# Assign membership for test case: 5.22136688232e-05 seconds
# Forecast next price: 0.000118017196655 seconds
# Update data: 0.0026650428772 seconds
# Partition discourse: 0.000533819198608 seconds
# Create fuzzy number: 0.00293302536011 seconds
# Update fuzzy membership: 7.70092010498e-05 seconds
# Update FLR: 0.000126123428345 seconds
# Update jump weights: 0.0167820453644 seconds
# Update transition weights: 0.000463008880615 seconds
# Assign membership for test case: 6.79492950439e-05 seconds
# Forecast next price: 0.000141143798828 seconds
# Update data: 0.00284194946289 seconds
# Partition discourse: 0.00031590461731 seconds
# Create fuzzy number: 0.00273990631104 seconds
# Update fuzzy membership: 0.000107049942017 seconds
# Update FLR: 0.000174045562744 seconds
# Update jump weights: 0.0169599056244 seconds
# Update transition weights: 0.000424861907959 seconds
# Assign membership for test case: 5.79357147217e-05 seconds
# Forecast next price: 0.000126123428345 seconds
# Update data: 0.00240397453308 seconds
# Partition discourse: 0.00028395652771 seconds
# Create fuzzy number: 0.00146198272705 seconds
# Update fuzzy membership: 7.29560852051e-05 seconds
# Update FLR: 0.000189065933228 seconds
# Update jump weights: 0.0154440402985 seconds
# Update transition weights: 0.000856876373291 seconds
# Assign membership for test case: 9.20295715332e-05 seconds
# Forecast next price: 0.000221014022827 seconds
# Update data: 0.00255393981934 seconds
# Partition discourse: 0.000289916992188 seconds
# Create fuzzy number: 0.00146698951721 seconds
# Update fuzzy membership: 6.19888305664e-05 seconds
# Update FLR: 0.000126838684082 seconds
# Update jump weights: 0.0151219367981 seconds
# Update transition weights: 0.000411987304688 seconds
# Assign membership for test case: 4.6968460083e-05 seconds
# Forecast next price: 0.000122785568237 seconds
# Update data: 0.00337100028992 seconds
# Partition discourse: 0.000750064849854 seconds
# Create fuzzy number: 0.0027539730072 seconds
# Update fuzzy membership: 0.000113964080811 seconds
# Update FLR: 0.000247955322266 seconds
# Update jump weights: 0.0179460048676 seconds
# Update transition weights: 0.00042200088501 seconds
# Assign membership for test case: 6.103515625e-05 seconds
# Forecast next price: 0.000133991241455 seconds
# Update data: 0.00364899635315 seconds
# Partition discourse: 0.000511169433594 seconds
# Create fuzzy number: 0.00201606750488 seconds
# Update fuzzy membership: 6.89029693604e-05 seconds
# Update FLR: 0.000123023986816 seconds
# Update jump weights: 0.0165200233459 seconds
# Update transition weights: 0.000416994094849 seconds
# Assign membership for test case: 4.6968460083e-05 seconds
# Forecast next price: 0.000117063522339 seconds
# Update data: 0.00528192520142 seconds
# Partition discourse: 0.000740051269531 seconds
# Create fuzzy number: 0.00244402885437 seconds
# Update fuzzy membership: 0.0001380443573 seconds
# Update FLR: 0.000283002853394 seconds
# ...
# Update fuzzy membership: 6.60419464111e-05 seconds
# Update FLR: 0.000137090682983 seconds
# Update jump weights: 0.014356136322 seconds
# Update transition weights: 0.000455141067505 seconds
# Assign membership for test case: 6.103515625e-05 seconds
# Forecast next price: 0.000133037567139 seconds
# Update data: 0.00247597694397 seconds
# Partition discourse: 0.000285148620605 seconds
# Create fuzzy number: 0.00156116485596 seconds
# Update fuzzy membership: 6.00814819336e-05 seconds
# Update FLR: 0.000127077102661 seconds
# Update jump weights: 0.0146470069885 seconds
# Update transition weights: 0.000416994094849 seconds
# Assign membership for test case: 4.98294830322e-05 seconds
# Forecast next price: 0.000127792358398 seconds
# Update data: 0.00308799743652 seconds
# Partition discourse: 0.000348091125488 seconds
# Create fuzzy number: 0.00159120559692 seconds
# Update fuzzy membership: 7.70092010498e-05 seconds
# Update FLR: 0.000150918960571 seconds
# Update jump weights: 0.0172121524811 seconds
# Update transition weights: 0.000800132751465 seconds
# Assign membership for test case: 8.08238983154e-05 seconds
# Forecast next price: 0.000225067138672 seconds
# Update data: 0.00261783599854 seconds
# Partition discourse: 0.000287055969238 seconds
# Create fuzzy number: 0.00195908546448 seconds
# Update fuzzy membership: 0.000105857849121 seconds
# Update FLR: 0.000141859054565 seconds
# Update jump weights: 0.0145161151886 seconds
# Update transition weights: 0.000624179840088 seconds
# Assign membership for test case: 7.29560852051e-05 seconds
# Forecast next price: 0.000166893005371 seconds
# Update data: 0.002601146698 seconds
# Partition discourse: 0.000303030014038 seconds
# Create fuzzy number: 0.00136184692383 seconds
# Update fuzzy membership: 5.10215759277e-05 seconds
# Update FLR: 0.000128984451294 seconds
# Update jump weights: 0.0149199962616 seconds
# Update transition weights: 0.000429153442383 seconds
# Assign membership for test case: 5.19752502441e-05 seconds
# Forecast next price: 0.000133037567139 seconds
# Update data: 0.0025680065155 seconds
# Partition discourse: 0.000319004058838 seconds
# Create fuzzy number: 0.0015389919281 seconds
# Update fuzzy membership: 7.20024108887e-05 seconds
# Update FLR: 0.000133991241455 seconds
# Update jump weights: 0.0146420001984 seconds
# Update transition weights: 0.000797986984253 seconds
# Assign membership for test case: 8.20159912109e-05 seconds
# Forecast next price: 0.000211954116821 seconds
# Update data: 0.0024950504303 seconds
# Partition discourse: 0.000286102294922 seconds
# Create fuzzy number: 0.00136780738831 seconds
# Update fuzzy membership: 5.41210174561e-05 seconds
# Update FLR: 0.000128984451294 seconds
# Update jump weights: 0.0146961212158 seconds
# Update transition weights: 0.000425100326538 seconds
# Assign membership for test case: 4.60147857666e-05 seconds
# Forecast next price: 0.000119924545288 seconds
# Update data: 0.00259208679199 seconds
# Partition discourse: 0.00031304359436 seconds
# Create fuzzy number: 0.00135898590088 seconds
# Update fuzzy membership: 6.103515625e-05 seconds
# Update FLR: 0.000134944915771 seconds
# Update jump weights: 0.0146429538727 seconds
# Update transition weights: 0.000416040420532 seconds
# Assign membership for test case: 4.6968460083e-05 seconds
# Forecast next price: 0.000130176544189 seconds
# Update data: 0.00269889831543 seconds
# Partition discourse: 0.000383138656616 seconds
# Create fuzzy number: 0.00178217887878 seconds
# Update fuzzy membership: 7.60555267334e-05 seconds
# Update FLR: 0.000139951705933 seconds
# Update jump weights: 0.0142719745636 seconds
# Update transition weights: 0.000580072402954 seconds
# Assign membership for test case: 7.79628753662e-05 seconds
# Forecast next price: 0.000153064727783 seconds
# Update data: 0.00289702415466 seconds
# Partition discourse: 0.000293970108032 seconds
# Create fuzzy number: 0.00136494636536 seconds
# Update fuzzy membership: 5.29289245605e-05 seconds
# Update FLR: 0.000128030776978 seconds
# Update jump weights: 0.0153250694275 seconds
# Update transition weights: 0.000422954559326 seconds
# Assign membership for test case: 4.98294830322e-05 seconds
# Forecast next price: 0.000127077102661 seconds
# Update data: 0.00238800048828 seconds
# Partition discourse: 0.000287055969238 seconds
# Create fuzzy number: 0.00135397911072 seconds
# Update fuzzy membership: 5.41210174561e-05 seconds
# Update FLR: 0.000126123428345 seconds
# Update jump weights: 0.0144560337067 seconds
# Update transition weights: 0.000417947769165 seconds
# Assign membership for test case: 4.41074371338e-05 seconds
# Forecast next price: 0.000123023986816 seconds
# Update data: 0.00256896018982 seconds
# Partition discourse: 0.000308036804199 seconds
# Create fuzzy number: 0.00138092041016 seconds
# Update fuzzy membership: 6.89029693604e-05 seconds
# Update FLR: 0.000147104263306 seconds
# Update jump weights: 0.0154860019684 seconds
# Update transition weights: 0.000828981399536 seconds
# Assign membership for test case: 9.01222229004e-05 seconds
# Forecast next price: 0.000233888626099 seconds
# Update data: 0.00281810760498 seconds
# Partition discourse: 0.000308036804199 seconds
# Create fuzzy number: 0.00161218643188 seconds
# Update fuzzy membership: 6.5803527832e-05 seconds
# Update FLR: 0.000135898590088 seconds
# Update jump weights: 0.0142929553986 seconds
# Update transition weights: 0.000427961349487 seconds
# Assign membership for test case: 5.79357147217e-05 seconds
# Forecast next price: 0.000180006027222 seconds
# Update data: 0.00324988365173 seconds
# Partition discourse: 0.000298023223877 seconds
# Create fuzzy number: 0.00141310691833 seconds
# Update fuzzy membership: 5.91278076172e-05 seconds
# Update FLR: 0.000132083892822 seconds
# Update jump weights: 0.0141689777374 seconds
# Update transition weights: 0.00042200088501 seconds
# Assign membership for test case: 5.50746917725e-05 seconds
# Forecast next price: 0.00012993812561 seconds
# Update data: 0.00243997573853 seconds
# Partition discourse: 0.000288963317871 seconds
# Create fuzzy number: 0.0013689994812 seconds
# Update fuzzy membership: 5.29289245605e-05 seconds
# Update FLR: 0.000128030776978 seconds
# Update jump weights: 0.0159089565277 seconds
# Update transition weights: 0.000655889511108 seconds
# Assign membership for test case: 0.000103950500488 seconds
# Forecast next price: 0.000241041183472 seconds
# Update data: 0.00345087051392 seconds
# Partition discourse: 0.000341892242432 seconds
# Create fuzzy number: 0.00141310691833 seconds
# Update fuzzy membership: 6.103515625e-05 seconds
# Update FLR: 0.000136852264404 seconds
# Update jump weights: 0.0147578716278 seconds
# Update transition weights: 0.000426054000854 seconds
# Assign membership for test case: 5.29289245605e-05 seconds
# Forecast next price: 0.0001380443573 seconds
# Update data: 0.00239396095276 seconds
# Partition discourse: 0.000300884246826 seconds
# Create fuzzy number: 0.0018150806427 seconds
# Update fuzzy membership: 7.9870223999e-05 seconds
# Update FLR: 0.000145196914673 seconds
# Update jump weights: 0.0143911838531 seconds
# Update transition weights: 0.000427007675171 seconds
# Assign membership for test case: 6.31809234619e-05 seconds
# Forecast next price: 0.000140905380249 seconds
# Update data: 0.0028510093689 seconds
# Partition discourse: 0.000344038009644 seconds
# Create fuzzy number: 0.00142812728882 seconds
# Update fuzzy membership: 7.10487365723e-05 seconds
# Update FLR: 0.000133991241455 seconds
# Update jump weights: 0.0146679878235 seconds
# Update transition weights: 0.000859022140503 seconds
# Assign membership for test case: 8.79764556885e-05 seconds
# Forecast next price: 0.000221967697144 seconds
# Update data: 0.00248718261719 seconds
# Partition discourse: 0.000283002853394 seconds
# Create fuzzy number: 0.00136208534241 seconds
# Update fuzzy membership: 5.60283660889e-05 seconds
# Update FLR: 0.00012993812561 seconds
# Update jump weights: 0.0142819881439 seconds
# Update transition weights: 0.000424146652222 seconds
# Assign membership for test case: 4.79221343994e-05 seconds
# Forecast next price: 0.000128984451294 seconds
# Update data: 0.002601146698 seconds
# Partition discourse: 0.000302076339722 seconds
# Create fuzzy number: 0.00156688690186 seconds
# Update fuzzy membership: 5.10215759277e-05 seconds
# Update FLR: 0.000130891799927 seconds
# Update jump weights: 0.0156629085541 seconds
# Update transition weights: 0.000420093536377 seconds
# Assign membership for test case: 5.10215759277e-05 seconds
# Forecast next price: 0.000125169754028 seconds
# Update data: 0.00242495536804 seconds
# Partition discourse: 0.000286102294922 seconds
# Create fuzzy number: 0.00176906585693 seconds
# Update fuzzy membership: 7.79628753662e-05 seconds
# Update FLR: 0.000142097473145 seconds
# Update jump weights: 0.0140459537506 seconds
# Update transition weights: 0.000794887542725 seconds
# Assign membership for test case: 8.10623168945e-05 seconds
# Forecast next price: 0.000240087509155 seconds
# Update data: 0.00335097312927 seconds
# Partition discourse: 0.000324010848999 seconds
# Create fuzzy number: 0.00138187408447 seconds
# Update fuzzy membership: 5.50746917725e-05 seconds
# Update FLR: 0.000129222869873 seconds
# Update jump weights: 0.0154008865356 seconds
# Update transition weights: 0.000426054000854 seconds
# Assign membership for test case: 5.29289245605e-05 seconds
# Forecast next price: 0.000126123428345 seconds
# Update data: 0.00239896774292 seconds
# Partition discourse: 0.000288009643555 seconds
# Create fuzzy number: 0.00135493278503 seconds
# Update fuzzy membership: 5.00679016113e-05 seconds
# Update FLR: 0.000123977661133 seconds
# Update jump weights: 0.0147321224213 seconds
# Update transition weights: 0.000425100326538 seconds
# Assign membership for test case: 4.60147857666e-05 seconds
# Forecast next price: 0.000121116638184 seconds
# Update data: 0.00252103805542 seconds
# Partition discourse: 0.000318050384521 seconds
# Create fuzzy number: 0.00139212608337 seconds
# Update fuzzy membership: 6.41345977783e-05 seconds
# Update FLR: 0.0001380443573 seconds
# Update jump weights: 0.0143518447876 seconds
# Update transition weights: 0.000502824783325 seconds
# Assign membership for test case: 6.29425048828e-05 seconds
# Forecast next price: 0.00012993812561 seconds
# Update data: 0.00263500213623 seconds
# Partition discourse: 0.000305891036987 seconds
# Create fuzzy number: 0.00136280059814 seconds
# Update fuzzy membership: 5.29289245605e-05 seconds
# Update FLR: 0.000130891799927 seconds
# Update jump weights: 0.015013217926 seconds
# Update transition weights: 0.000782012939453 seconds
# Assign membership for test case: 5.79357147217e-05 seconds
# Forecast next price: 0.000149965286255 seconds
# Update data: 0.00349402427673 seconds
# Partition discourse: 0.000308036804199 seconds
# Create fuzzy number: 0.00150394439697 seconds
# Update fuzzy membership: 6.41345977783e-05 seconds
# Update FLR: 0.000139951705933 seconds
# Update jump weights: 0.0149128437042 seconds
# Update transition weights: 0.000511169433594 seconds
# Assign membership for test case: 6.19888305664e-05 seconds
# Forecast next price: 0.000132083892822 seconds
# Update data: 0.0024619102478 seconds
# Partition discourse: 0.00028395652771 seconds
# Create fuzzy number: 0.00148296356201 seconds
# Update fuzzy membership: 6.103515625e-05 seconds
# Update FLR: 0.000130891799927 seconds
# Update jump weights: 0.0161919593811 seconds
# Update transition weights: 0.000918865203857 seconds
# Assign membership for test case: 0.000103950500488 seconds
# Forecast next price: 0.000230073928833 seconds
# Update data: 0.00372004508972 seconds
# Partition discourse: 0.000310897827148 seconds
# Create fuzzy number: 0.00139880180359 seconds
# Update fuzzy membership: 5.79357147217e-05 seconds
# Update FLR: 0.000135183334351 seconds
# Update jump weights: 0.0196869373322 seconds
# Update transition weights: 0.000446081161499 seconds
# Assign membership for test case: 6.29425048828e-05 seconds
# Forecast next price: 0.000130891799927 seconds
# Update data: 0.00268077850342 seconds
# Partition discourse: 0.000286817550659 seconds
# Create fuzzy number: 0.00135707855225 seconds
# Update fuzzy membership: 5.22136688232e-05 seconds
# Update FLR: 0.000226974487305 seconds
# Update jump weights: 0.0146160125732 seconds
# Update transition weights: 0.000420093536377 seconds
# Assign membership for test case: 5.19752502441e-05 seconds
# Forecast next price: 0.000128984451294 seconds
# Update data: 0.00269603729248 seconds
# Partition discourse: 0.000527143478394 seconds
# Create fuzzy number: 0.00184607505798 seconds
# Update fuzzy membership: 7.29560852051e-05 seconds
# Update FLR: 0.000138998031616 seconds
# Update jump weights: 0.0144040584564 seconds
# Update transition weights: 0.000424146652222 seconds
# Assign membership for test case: 4.60147857666e-05 seconds
# Forecast next price: 0.000119924545288 seconds
# Update data: 0.00243306159973 seconds
# Partition discourse: 0.000293016433716 seconds
# Create fuzzy number: 0.00137710571289 seconds
# Update fuzzy membership: 5.41210174561e-05 seconds
# Update FLR: 0.000140190124512 seconds
# Update jump weights: 0.0150690078735 seconds
# Update transition weights: 0.000531911849976 seconds
# Assign membership for test case: 5.19752502441e-05 seconds
# Forecast next price: 0.000117063522339 seconds
# Update data: 0.00239491462708 seconds
# Partition discourse: 0.000283002853394 seconds
# Create fuzzy number: 0.00156998634338 seconds
# Update fuzzy membership: 7.00950622559e-05 seconds
# Update FLR: 0.000162124633789 seconds
# Update jump weights: 0.0139498710632 seconds
# Update transition weights: 0.000791072845459 seconds
# Assign membership for test case: 8.01086425781e-05 seconds
# Forecast next price: 0.000225067138672 seconds
# Update data: 0.00334191322327 seconds
# Partition discourse: 0.000311136245728 seconds
# Create fuzzy number: 0.0013701915741 seconds
# Update fuzzy membership: 5.29289245605e-05 seconds
# Update FLR: 0.000133991241455 seconds
# Update jump weights: 0.0143489837646 seconds
# Update transition weights: 0.000450849533081 seconds
# Assign membership for test case: 5.60283660889e-05 seconds
# Forecast next price: 0.000134944915771 seconds
# Update data: 0.00250291824341 seconds
# Partition discourse: 0.000289916992188 seconds
# Create fuzzy number: 0.00180792808533 seconds
# Update fuzzy membership: 8.20159912109e-05 seconds
# Update FLR: 0.000136852264404 seconds
# Update jump weights: 0.0157799720764 seconds
# Update transition weights: 0.000422954559326 seconds
# Assign membership for test case: 5.48362731934e-05 seconds
# Forecast next price: 0.000136137008667 seconds
# Update data: 0.00242209434509 seconds
# Partition discourse: 0.000286102294922 seconds
# Create fuzzy number: 0.00135517120361 seconds
# Update fuzzy membership: 5.10215759277e-05 seconds
# Update FLR: 0.000128984451294 seconds
# Update jump weights: 0.0153419971466 seconds
# Update transition weights: 0.00081205368042 seconds
# Assign membership for test case: 8.29696655273e-05 seconds
# Forecast next price: 0.000212907791138 seconds
# Update data: 0.00317907333374 seconds
# Partition discourse: 0.000470876693726 seconds
# Create fuzzy number: 0.00211119651794 seconds
# Update fuzzy membership: 8.20159912109e-05 seconds
# Update FLR: 0.000153064727783 seconds
# Update jump weights: 0.0153329372406 seconds
# Update transition weights: 0.000455856323242 seconds
# Assign membership for test case: 5.60283660889e-05 seconds
# Forecast next price: 0.000136137008667 seconds
# Update data: 0.00291395187378 seconds
# Partition discourse: 0.000298976898193 seconds
# Create fuzzy number: 0.00134897232056 seconds
# Update fuzzy membership: 5.19752502441e-05 seconds
# Update FLR: 0.000133037567139 seconds
# Update jump weights: 0.0164270401001 seconds
# Update transition weights: 0.000449895858765 seconds
# Assign membership for test case: 5.81741333008e-05 seconds
# Forecast next price: 0.000122785568237 seconds
# Update data: 0.00240015983582 seconds
# Partition discourse: 0.000294923782349 seconds
# Create fuzzy number: 0.00135612487793 seconds
# Update fuzzy membership: 5.10215759277e-05 seconds
# Update FLR: 0.000247955322266 seconds
# Update jump weights: 0.0152509212494 seconds
# Update transition weights: 0.000988960266113 seconds
# Assign membership for test case: 0.000110149383545 seconds
# Forecast next price: 0.000240087509155 seconds
# RMSE = 136.035106284
# Time cost: 5.96824383736 seconds

# %%
print(train_data_membership_series)
# Out:
# [16, 16, 16, 16, 16, 17, 18, 18, 19, 18, 18, 18, 19, 18, 19, 18, 18, 18, 20, 19, 19, 18, 15, 14, 11, 13, 13, 13, 14, 13, 15, 15, 15, 13, 13, 15, 13, 13, 15, 12, 12, 14, 14, 14, 15, 16, 16, 17, 18, 17, 17, 17, 19, 16, 17, 16, 16, 15, 16, 14, 13, 11, 11, 12, 12, 11, 10, 11, 