# %% [markdown]
# Since the reference paper didn't make full use of the trapezoidal fuzzy function, we can change it to a simpler rectangular shape when performing membership computation to reduce computation. Here we use the universe discourse directly.

# %%
import pandas as pd
import numpy as np
import operator
import matplotlib.pyplot as plt
import plotly.plotly as py
import plotly.graph_objs as go
# %matplotlib inline
from time import time

from collections import defaultdict
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
from plotly.offline import init_notebook_mode

py.sign_in('imaginationsuper', 'PQj7gXzsTJFqNKsXkWMT')
init_notebook_mode(connected=True)
# Out:
# <script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window.Plotly) {{require(['plotly'],function(plotly) {window.Plotly=plotly;});}}</script>

# %%
def universe_partition(data, d1=10, d2=10):
    x_max, x_min = data.max(axis=0), data.min(axis=0)    
    std_val = data.std(axis=0)
    len_val = np.round(std_val / 10)
#     len_val = 20
#     u_max, u_min = 12600+len_val, 6600-len_val
    u_max, u_min = int(x_max+d2), int(x_min-d1) # bound of universe discourse
    u_b = np.arange(u_min, u_max, step=float(len_val)) # cutting points
    u_discourse = u_b
    return u_discourse

def set_fuzzy_numbers(u_discourse_raw):
    u_s = u_discourse_raw[:-1]
    u_e = u_discourse_raw[1:]
    u_discourse = zip(u_s, u_e)
    fuzzy_numbers = list()
    for i, u_i in enumerate(u_discourse):
        fuzzy_numbers.append(np.array([u_i[0], u_i[1]]))
    return fuzzy_numbers

# %%
def membership_assignment(value_time_series, fuzzy_numbers):
    membership_list = np.digitize(value_time_series, fuzzy_numbers)-1
    return membership_list.tolist()

def get_membership(value, fuzzy_numbers):
    membership_index = np.digitize([value], fuzzy_numbers)[0]-1
    return membership_index

# %%
def FLR(membership_time_series): # transition between consecutive observations
    transitions = list()
    for j, Aj in enumerate(membership_time_series):
        if j!=0:
            Ai = membership_time_series[j-1]
            transitions.append((Ai, Aj))
    return transitions

def FLR_weight(transitions, time_series): # compute jump frequency by FLR
    jumps = map(lambda x: x[1]-x[0], transitions) # compute jumps by transitions 
    jump_time_series = zip(jumps, time_series) # assign timestamp for each jump beta^t_p,p+k
    jump_counts = defaultdict(list) 
    for key, value in jump_time_series:
        jump_counts[key].append(value) # count jump by its timestamps
    jump_counts = {key: sum(value) for key, value in jump_counts.items()} # sum up total time for each jump
    total_count = float(sum(jump_counts.values()))
    for key, value in jump_counts.iteritems(): 
        jump_counts[key] = value / total_count # normalize jumps as weights
    return jump_counts

def FRG_weight(transitions, time_series): 
    transition_time_series = zip(transitions, time_series)
    transition_groups = map(lambda x: (x[0][0], (x[0][1], x[1])), transition_time_series) 
    transition_weights = defaultdict(list)
    for key, value in transition_groups:
        transition_weights[key].append(value) # group transitions by initial state A_i
    transition_weights = {key: dict(value) for key, value in transition_weights.items()}
    for key, value in transition_weights.iteritems():
        total_weight = float(sum(value.values()))
        value = {k: (v/total_weight) for k, v in value.items()} # normalize weight inside each group
        transition_weights[key] = value
    return transition_weights

# %%
# forecasting by fuzzy numbers
def fuzzy_add(A, B): # Proposition #1 (1)
    return A + B # A and B are numpy array type

def fuzzy_scale(c, A): # Proposition #1 (2)
    cA = c*A # A is numpy array type
    if c>=0:
        return cA
    else:
        return cA[::-1]

def forecast_jump(i, s, A_list):
    jumps = s.keys() # possible jumps
    m = len(A_list) # number of fuzzy numbers in model
    sA_list = list()
    sk_list = list()
    Aip_list = list()
    sA = np.array([0.0]*len(A_list[0]))
    for k in jumps:
        ip = k+i
        if (ip>=0 and ip<m): # check if index is within range
            sk_list.append(s[k])
            Aip_list.append(A_list[ip])
    sk_list = np.array(sk_list) / sum(sk_list) # normalize locally
    for i in range(sk_list.size):
        sA_list.append(fuzzy_scale(sk_list[i], Aip_list[i]))
    if len(sA_list)>0:
        for sa in sA_list:
            sA = fuzzy_add(sA, sa)
    return sA
    
def forecast_transition(i, w, A_list):
    wA = np.array([0.0]*len(A_list[0])) # default FLG relation
    if i in w.keys():
        for kj, v in w[i].iteritems():
            wA = fuzzy_add(wA, fuzzy_scale(v, A_list[kj]))
    return wA

def forecast_price(As, Aw, gamma=0.1):
    if gamma<0 or gamma>1:
        raise ValueError("gamma should be between 0.0 and 1.0 (inclusive on both ends)")     
    wAi = fuzzy_scale(1-gamma, Aw)
    if (np.sum(wAi) == 0): # no FLR observed in history
        sAi = As
    else:
        sAi = fuzzy_scale(gamma, As)
    Ai_pred = fuzzy_add(sAi, wAi)
    return np.mean(Ai_pred)

# %%
start_time = time()
datafile = '../data/IBEX35.csv'
dateparse = lambda x: pd.datetime.strptime(x, '%m/%d/%y')
df = pd.read_csv(datafile, header=0, parse_dates=['Date'], date_parser=dateparse)

split_date = pd.datetime.strptime('2014-12-31', '%Y-%m-%d')
train_data = df[df['Date'] < split_date]
test_data = df[df['Date'] >= split_date]
first_date = train_data['Date'][0] - pd.DateOffset(days=1)

option = 'Price'

# %%
# fit training data
train_features = train_data[option].tolist()[:-1]
train_prices = train_data[option].tolist()[1:]
fit_prices = list()
u_discourse = universe_partition(train_data[option], d1=1053, d2=912)
A_list = set_fuzzy_numbers(u_discourse)
train_data_membership_series = membership_assignment(train_data[option], fuzzy_numbers=u_discourse)
transition_FLR = FLR(train_data_membership_series)
train_data_days = train_data['Date'].apply(lambda x: x-first_date).dt.days.tolist() # convert Timedelta to numeric days
jump_weights = FLR_weight(transition_FLR, train_data_days[:len(transition_FLR)])
transition_weights = FRG_weight(transition_FLR, train_data_days[:len(transition_FLR)])
for price in train_features:
    index = get_membership(price, u_discourse)
    next_price = forecast_price(forecast_jump(index, jump_weights, A_list), forecast_transition(index, transition_weights, A_list), gamma=0.9)
    fit_prices.append(next_price)
print np.sqrt(mean_squared_error(train_prices, fit_prices))
# Out:
# 113.873796019

# %%
df_train = pd.DataFrame(train_data[1:]['Date'])
df_train['data training'] = pd.Series(train_prices).values
df_train['data fitting'] = pd.Series(fit_prices).values
df_train.index = df_train['Date']
plt.figure(figsize=(14,7))
df_train['data training'].plot(style='k-', linewidth=2, label='data training')
df_train['data fitting'].plot(style='b:', linewidth=3, label='data fitting')
plt.ylabel('Price', fontsize=18)
plt.legend(loc='best')
plt.title("IBEX35_fitting", fontsize=24)

# %%
# forecasting using test data
pred_prices = list()
actual_prices = test_data[option].tolist()[1:]
indices = test_data.index
for i in range(len(indices)-1):
    stm = time()
    #id = indices[i]
    prev = test_data.iloc[i]
    train_data.append(prev)
    print("Update data: %s seconds" % str(time() - stm))
    stm = time()
    u_discourse = universe_partition(train_data[option], d1=1053, d2=912)
    print("Partition discourse: %s seconds" % str(time() - stm))
    stm = time()
    A_list = set_fuzzy_numbers(u_discourse)
    print("Create fuzzy number: %s seconds" % str(time() - stm))
    stm = time()
    train_data_membership_series = membership_assignment(train_data[option], fuzzy_numbers=u_discourse)
#     train_data_ms = [ms+1 for ms in train_data_membership_series]
    print("Update fuzzy membership: %s seconds" % str(time() - stm))
    stm = time()
    transition_FLR = FLR(train_data_membership_series)
    print("Update FLR: %s seconds" % str(time() - stm))
    stm = time()
    train_data_days = train_data['Date'].apply(lambda x: x-first_date).dt.days.tolist() # convert Timedelta to numeric days
    jump_weights = FLR_weight(transition_FLR, train_data_days[:len(transition_FLR)])
    print("Update jump weights: %s seconds" % str(time() - stm))
    stm = time()
    transition_weights = FRG_weight(transition_FLR, train_data_days[:len(transition_FLR)])
    print("Update transition weights: %s seconds" % str(time() - stm))
    stm = time()
    # forecasting current test data
    price = prev[option]
    index = get_membership(price, u_discourse)
    print("Assign membership for test case: %s seconds" % str(time() - stm))
    stm = time()
    next_price = forecast_price(forecast_jump(index, jump_weights, A_list), forecast_transition(index, transition_weights, A_list), gamma=0.9)
    print("Forecast next price: %s seconds" % str(time() - stm))
    stm = time()
    pred_prices.append(next_price)
    
print "RMSE = "+str(np.sqrt(mean_squared_error(actual_prices, pred_prices)))
print "Time cost: "+str(time()-start_time)+" seconds"
# Out:
# Update data: 0.00321698188782 seconds
# Partition discourse: 0.000451803207397 seconds
# Create fuzzy number: 0.000133991241455 seconds
# Update fuzzy membership: 5.60283660889e-05 seconds
# Update FLR: 0.000123977661133 seconds
# Update jump weights: 0.0152859687805 seconds
# Update transition weights: 0.000861883163452 seconds
# Assign membership for test case: 7.60555267334e-05 seconds
# Forecast next price: 0.000216960906982 seconds
# Update data: 0.00275206565857 seconds
# Partition discourse: 0.000290155410767 seconds
# Create fuzzy number: 0.000149965286255 seconds
# Update fuzzy membership: 5.10215759277e-05 seconds
# Update FLR: 0.000123977661133 seconds
# Update jump weights: 0.0142579078674 seconds
# Update transition weights: 0.000725030899048 seconds
# Assign membership for test case: 7.39097595215e-05 seconds
# Forecast next price: 0.000203847885132 seconds
# Update data: 0.0032160282135 seconds
# Partition discourse: 0.000292062759399 seconds
# Create fuzzy number: 0.000144958496094 seconds
# Update fuzzy membership: 5.29289245605e-05 seconds
# Update FLR: 0.000123023986816 seconds
# Update jump weights: 0.014347076416 seconds
# Update transition weights: 0.000449180603027 seconds
# Assign membership for test case: 5.79357147217e-05 seconds
# Forecast next price: 0.000118970870972 seconds
# Update data: 0.00344300270081 seconds
# Partition discourse: 0.000293016433716 seconds
# Create fuzzy number: 0.000134944915771 seconds
# Update fuzzy membership: 4.88758087158e-05 seconds
# Update FLR: 0.000108957290649 seconds
# Update jump weights: 0.0174820423126 seconds
# Update transition weights: 0.000461101531982 seconds
# Assign membership for test case: 8.58306884766e-05 seconds
# Forecast next price: 0.000243902206421 seconds
# Update data: 0.00493097305298 seconds
# Partition discourse: 0.00226092338562 seconds
# Create fuzzy number: 0.000579118728638 seconds
# Update jump weights: 0.0167310237885 seconds
# Update transition weights: 0.000386953353882 seconds
# Assign membership for test case: 4.60147857666e-05 seconds
# Forecast next price: 0.000119209289551 seconds
# Update data: 0.00275611877441 seconds
# Partition discourse: 0.000389099121094 seconds
# Create fuzzy number: 0.000150918960571 seconds
# Update fuzzy membership: 5.88893890381e-05 seconds
# Update FLR: 0.000128030776978 seconds
# Update jump weights: 0.0150511264801 seconds
# Update transition weights: 0.000473976135254 seconds
# Assign membership for test case: 5.79357147217e-05 seconds
# Forecast next price: 0.000137090682983 seconds
# Update data: 0.00315308570862 seconds
# Partition discourse: 0.000468015670776 seconds
# Create fuzzy number: 0.000258922576904 seconds
# Update fuzzy membership: 7.20024108887e-05 seconds
# Update FLR: 0.000125885009766 seconds
# Update jump weights: 0.0144770145416 seconds
# Update transition weights: 0.000405073165894 seconds
# Assign membership for test case: 4.60147857666e-05 seconds
# Forecast next price: 0.000113010406494 seconds
# Update data: 0.00261878967285 seconds
# Partition discourse: 0.000293970108032 seconds
# Create fuzzy number: 0.000137090682983 seconds
# Update fuzzy membership: 5.19752502441e-05 seconds
# Update FLR: 0.000118017196655 seconds
# Update jump weights: 0.0159928798676 seconds
# Update transition weights: 0.000407934188843 seconds
# Assign membership for test case: 5.00679016113e-05 seconds
# Forecast next price: 0.000120878219604 seconds
# Update data: 0.00236701965332 seconds
# Partition discourse: 0.000470876693726 seconds
# Create fuzzy number: 0.0001540184021 seconds
# Update fuzzy membership: 6.41345977783e-05 seconds
# Update FLR: 0.000136852264404 seconds
# Update jump weights: 0.0151610374451 seconds
# Update transition weights: 0.000411033630371 seconds
# Assign membership for test case: 5.81741333008e-05 seconds
# Forecast next price: 0.000116109848022 seconds
# Update data: 0.00301909446716 seconds
# Partition discourse: 0.000295162200928 seconds
# Create fuzzy number: 0.000139951705933 seconds
# Update fuzzy membership: 5.10215759277e-05 seconds
# Update FLR: 0.0001220703125 seconds
# Update jump weights: 0.0136289596558 seconds
# Update transition weights: 0.000396966934204 seconds
# Assign membership for test case: 5.10215759277e-05 seconds
# Forecast next price: 0.000120162963867 seconds
# Update data: 0.0023410320282 seconds
# Partition discourse: 0.000320911407471 seconds
# Create fuzzy number: 0.000137090682983 seconds
# Update fuzzy membership: 5.48362731934e-05 seconds
# Update FLR: 0.000120878219604 seconds
# Update jump weights: 0.0154700279236 seconds
# Update transition weights: 0.000423908233643 seconds
# Assign membership for test case: 5.69820404053e-05 seconds
# Forecast next price: 0.000123977661133 seconds
# Update data: 0.0022919178009 seconds
# Partition discourse: 0.000265121459961 seconds
# Create fuzzy number: 0.000128030776978 seconds
# Update fuzzy membership: 4.60147857666e-05 seconds
# Update FLR: 0.000113964080811 seconds
# Update jump weights: 0.0148301124573 seconds
# Update transition weights: 0.000545978546143 seconds
# Assign membership for test case: 6.91413879395e-05 seconds
# Forecast next price: 0.000525951385498 seconds
# Update data: 0.00274205207825 seconds
# Partition discourse: 0.000288963317871 seconds
# Create fuzzy number: 0.000142812728882 seconds
# Update fuzzy membership: 5.00679016113e-05 seconds
# Update FLR: 0.000127792358398 seconds
# Update jump weights: 0.0144300460815 seconds
# Update transition weights: 0.000458002090454 seconds
# Assign membership for test case: 5.81741333008e-05 seconds
# Partition discourse: 0.000277042388916 seconds
# Create fuzzy number: 0.000133037567139 seconds
# Update fuzzy membership: 4.79221343994e-05 seconds
# Update FLR: 0.000119924545288 seconds
# Update jump weights: 0.0137820243835 seconds
# Update transition weights: 0.00041389465332 seconds
# Assign membership for test case: 5.10215759277e-05 seconds
# Forecast next price: 0.000109910964966 seconds
# Update data: 0.0023820400238 seconds
# Partition discourse: 0.000289916992188 seconds
# Create fuzzy number: 0.000137090682983 seconds
# Update fuzzy membership: 5.19752502441e-05 seconds
# Update FLR: 0.000117063522339 seconds
# Update jump weights: 0.0138731002808 seconds
# Update transition weights: 0.000391960144043 seconds
# Assign membership for test case: 4.60147857666e-05 seconds
# Forecast next price: 0.000103950500488 seconds
# Update data: 0.00224614143372 seconds
# Partition discourse: 0.000292062759399 seconds
# Create fuzzy number: 0.0001380443573 seconds
# Update fuzzy membership: 5.60283660889e-05 seconds
# Update FLR: 0.000123977661133 seconds
# Update jump weights: 0.0137820243835 seconds
# Update transition weights: 0.000447988510132 seconds
# Assign membership for test case: 6.31809234619e-05 seconds
# Forecast next price: 0.000108003616333 seconds
# Update data: 0.00253391265869 seconds
# Partition discourse: 0.000288009643555 seconds
# Create fuzzy number: 0.000136852264404 seconds
# Update fuzzy membership: 5.19752502441e-05 seconds
# Update FLR: 0.000119924545288 seconds
# Update jump weights: 0.0140030384064 seconds
# Update transition weights: 0.000396013259888 seconds
# Assign membership for test case: 4.50611114502e-05 seconds
# Forecast next price: 0.000102043151855 seconds
# Update data: 0.00222086906433 seconds
# Partition discourse: 0.000401020050049 seconds
# Create fuzzy number: 0.000138998031616 seconds
# Update fuzzy membership: 5.60283660889e-05 seconds
# Update FLR: 0.0001220703125 seconds
# Update jump weights: 0.0136761665344 seconds
# Update transition weights: 0.000398874282837 seconds
# Assign membership for test case: 4.41074371338e-05 seconds
# Forecast next price: 0.000101089477539 seconds
# Update data: 0.00240707397461 seconds
# Partition discourse: 0.000302076339722 seconds
# Create fuzzy number: 0.000138998031616 seconds
# Update fuzzy membership: 5.3882598877e-05 seconds
# Update FLR: 0.000123023986816 seconds
# Update jump weights: 0.0139319896698 seconds
# Update transition weights: 0.000453948974609 seconds
# Assign membership for test case: 6.48498535156e-05 seconds
# Forecast next price: 0.000110149383545 seconds
# Update data: 0.00252389907837 seconds
# Partition discourse: 0.000289916992188 seconds
# Create fuzzy number: 0.000133037567139 seconds
# Update fuzzy membership: 4.98294830322e-05 seconds
# Update FLR: 0.000123023986816 seconds
# Update jump weights: 0.0138051509857 seconds
# Update transition weights: 0.000394821166992 seconds
# Assign membership for test case: 4.29153442383e-05 seconds
# Forecast next price: 9.79900360107e-05 seconds
# Update data: 0.00222206115723 seconds
# Partition discourse: 0.000272989273071 seconds
# Create fuzzy number: 0.000128984451294 seconds
# Update fuzzy membership: 4.6968460083e-05 seconds
# Update FLR: 0.000116109848022 seconds
# Update jump weights: 0.0135579109192 seconds
# Update transition weights: 0.000396013259888 seconds
# Assign membership for test case: 4.10079956055e-05 seconds
# Forecast next price: 9.67979431152e-05 seconds
# Update data: 0.00221991539001 seconds
# Partition discourse: 0.000268936157227 seconds
# Create fuzzy number: 0.00012993812561 seconds
# Update fuzzy membership: 4.60147857666e-05 seconds
# Update FLR: 0.000116109848022 seconds
# Update jump weights: 0.0135519504547 seconds
# Update transition weights: 0.000761985778809 seconds
# Assign membership for test case: 8.70227813721e-05 seconds
# Forecast next price: 0.000219106674194 seconds
# Update data: 0.00237584114075 seconds
# Partition discourse: 0.000286102294922 seconds
# Create fuzzy number: 0.00013279914856 seconds
# Update fuzzy membership: 4.98294830322e-05 seconds
# Update FLR: 0.000123977661133 seconds
# Update jump weights: 0.0144100189209 seconds
# Update transition weights: 0.000396013259888 seconds
# Assign membership for test case: 4.50611114502e-05 seconds
# Forecast next price: 0.000102043151855 seconds
# Update data: 0.00224614143372 seconds
# Partition discourse: 0.000270843505859 seconds
# Create fuzzy number: 0.000133991241455 seconds
# Update fuzzy membership: 4.6968460083e-05 seconds
# Update FLR: 0.000118017196655 seconds
# Update jump weights: 0.0143578052521 seconds
# Update transition weights: 0.000396966934204 seconds
# Assign membership for test case: 4.38690185547e-05 seconds
# Forecast next price: 9.98973846436e-05 seconds
# Update data: 0.00221610069275 seconds
# Partition discourse: 0.000272035598755 seconds
# Create fuzzy number: 0.00012993812561 seconds
# Update fuzzy membership: 4.6968460083e-05 seconds
# Update FLR: 0.000116109848022 seconds
# Update jump weights: 0.0140018463135 seconds
# Update transition weights: 0.00045108795166 seconds
# Assign membership for test case: 9.3936920166e-05 seconds
# Forecast next price: 0.000117063522339 seconds
# Update data: 0.00263810157776 seconds
# Partition discourse: 0.000345945358276 seconds
# Create fuzzy number: 0.000148057937622 seconds
# Update fuzzy membership: 6.00814819336e-05 seconds
# Update FLR: 0.000124931335449 seconds
# Update jump weights: 0.0142798423767 seconds
# Update transition weights: 0.000395059585571 seconds
# Assign membership for test case: 4.29153442383e-05 seconds
# Forecast next price: 0.000103950500488 seconds
# Update data: 0.00250792503357 seconds
# Partition discourse: 0.000278949737549 seconds
# Create fuzzy number: 0.000133037567139 seconds
# Update fuzzy membership: 4.79221343994e-05 seconds
# Update FLR: 0.000123023986816 seconds
# Update jump weights: 0.0154190063477 seconds
# Update transition weights: 0.00081205368042 seconds
# Assign membership for test case: 8.70227813721e-05 seconds
# Forecast next price: 0.000202894210815 seconds
# Update data: 0.00230598449707 seconds
# Partition discourse: 0.000272035598755 seconds
# Create fuzzy number: 0.000133991241455 seconds
# Update fuzzy membership: 4.79221343994e-05 seconds
# Update FLR: 0.0001220703125 seconds
# Update jump weights: 0.0137300491333 seconds
# Update transition weights: 0.000479936599731 seconds
# Assign membership for test case: 6.79492950439e-05 seconds
# Forecast next price: 0.000128030776978 seconds
# Update data: 0.00257897377014 seconds
# Partition discourse: 0.000291109085083 seconds
# Create fuzzy number: 0.000133037567139 seconds
# Update fuzzy membership: 5.29289245605e-05 seconds
# Update FLR: 0.000124216079712 seconds
# Update jump weights: 0.0139660835266 seconds
# Update transition weights: 0.000397920608521 seconds
# Assign membership for test case: 4.60147857666e-05 seconds
# Forecast next price: 0.000115156173706 seconds
# Update data: 0.00222587585449 seconds
# Partition discourse: 0.000271081924438 seconds
# Create fuzzy number: 0.000132083892822 seconds
# Update fuzzy membership: 5.19752502441e-05 seconds
# Update FLR: 0.000120162963867 seconds
# Update jump weights: 0.0136179924011 seconds
# Update transition weights: 0.000540018081665 seconds
# Assign membership for test case: 5.00679016113e-05 seconds
# Forecast next price: 0.000113010406494 seconds
# Update data: 0.00226092338562 seconds
# Partition discourse: 0.000269889831543 seconds
# Create fuzzy number: 0.000136852264404 seconds
# Update fuzzy membership: 4.79221343994e-05 seconds
# Update FLR: 0.000120162963867 seconds
# Update jump weights: 0.0137898921967 seconds
# Update transition weights: 0.000517129898071 seconds
# Assign membership for test case: 7.00950622559e-05 seconds
# Forecast next price: 0.000128984451294 seconds
# Update data: 0.00257301330566 seconds
# ...
# Update FLR: 0.000127792358398 seconds
# Update jump weights: 0.01398396492 seconds
# Update transition weights: 0.000398874282837 seconds
# Assign membership for test case: 4.29153442383e-05 seconds
# Forecast next price: 0.000110864639282 seconds
# Update data: 0.00222301483154 seconds
# Partition discourse: 0.00026798248291 seconds
# Create fuzzy number: 0.000130891799927 seconds
# Update fuzzy membership: 4.60147857666e-05 seconds
# Update FLR: 0.000124931335449 seconds
# Update jump weights: 0.0134739875793 seconds
# Update transition weights: 0.000397205352783 seconds
# Assign membership for test case: 4.10079956055e-05 seconds
# Forecast next price: 0.000108003616333 seconds
# Update data: 0.0022280216217 seconds
# Partition discourse: 0.000270843505859 seconds
# Create fuzzy number: 0.00013279914856 seconds
# Update fuzzy membership: 4.6968460083e-05 seconds
# Update FLR: 0.000121116638184 seconds
# Update jump weights: 0.0138249397278 seconds
# Update transition weights: 0.00085186958313 seconds
# Assign membership for test case: 9.60826873779e-05 seconds
# Forecast next price: 0.000212907791138 seconds
# Update data: 0.00363802909851 seconds
# Partition discourse: 0.000301122665405 seconds
# Create fuzzy number: 0.000133991241455 seconds
# Update fuzzy membership: 5.41210174561e-05 seconds
# Update FLR: 0.000130891799927 seconds
# Update jump weights: 0.0140380859375 seconds
# Update transition weights: 0.000407934188843 seconds
# Assign membership for test case: 4.60147857666e-05 seconds
# Forecast next price: 0.000110864639282 seconds
# Update data: 0.00226211547852 seconds
# Partition discourse: 0.000272989273071 seconds
# Create fuzzy number: 0.000133991241455 seconds
# Update fuzzy membership: 4.79221343994e-05 seconds
# Update FLR: 0.000124931335449 seconds
# Update jump weights: 0.0138170719147 seconds
# Update transition weights: 0.000396013259888 seconds
# Assign membership for test case: 4.38690185547e-05 seconds
# Forecast next price: 0.000108003616333 seconds
# Update data: 0.00226593017578 seconds
# Partition discourse: 0.000339031219482 seconds
# Create fuzzy number: 0.000245094299316 seconds
# Update fuzzy membership: 6.50882720947e-05 seconds
# Update FLR: 0.000130891799927 seconds
# Update jump weights: 0.0134809017181 seconds
# Update transition weights: 0.00046181678772 seconds
# Assign membership for test case: 6.00814819336e-05 seconds
# Forecast next price: 0.000118970870972 seconds
# Update data: 0.00271701812744 seconds
# Partition discourse: 0.000295877456665 seconds
# Create fuzzy number: 0.000136852264404 seconds
# Update fuzzy membership: 5.19752502441e-05 seconds
# Update FLR: 0.000128984451294 seconds
# Update jump weights: 0.0135850906372 seconds
# Update transition weights: 0.000395059585571 seconds
# Assign membership for test case: 4.19616699219e-05 seconds
# Forecast next price: 0.000107049942017 seconds
# Update data: 0.00250196456909 seconds
# Partition discourse: 0.000280141830444 seconds
# Create fuzzy number: 0.000132083892822 seconds
# Update fuzzy membership: 4.79221343994e-05 seconds
# Update FLR: 0.000128984451294 seconds
# Update jump weights: 0.0133509635925 seconds
# Update transition weights: 0.000396966934204 seconds
# Assign membership for test case: 4.29153442383e-05 seconds
# Forecast next price: 0.000109910964966 seconds
# Update data: 0.00303196907043 seconds
# Partition discourse: 0.000278949737549 seconds
# Create fuzzy number: 0.000137090682983 seconds
# Update fuzzy membership: 4.79221343994e-05 seconds
# Update FLR: 0.000130176544189 seconds
# Update jump weights: 0.0136799812317 seconds
# Update transition weights: 0.000878095626831 seconds
# Assign membership for test case: 0.000133037567139 seconds
# Forecast next price: 0.000220060348511 seconds
# Update data: 0.00348377227783 seconds
# Partition discourse: 0.000465869903564 seconds
# Create fuzzy number: 0.000205039978027 seconds
# Update fuzzy membership: 7.60555267334e-05 seconds
# Update FLR: 0.000191926956177 seconds
# Update jump weights: 0.0148839950562 seconds
# Update transition weights: 0.00042200088501 seconds
# Assign membership for test case: 4.60147857666e-05 seconds
# Forecast next price: 0.000113010406494 seconds
# Update data: 0.00237107276917 seconds
# Partition discourse: 0.000290870666504 seconds
# Create fuzzy number: 0.000132083892822 seconds
# Update fuzzy membership: 5.07831573486e-05 seconds
# Update FLR: 0.000120878219604 seconds
# Update jump weights: 0.013659954071 seconds
# Update transition weights: 0.000413179397583 seconds
# Assign membership for test case: 4.60147857666e-05 seconds
# Forecast next price: 0.000111103057861 seconds
# Update data: 0.00235080718994 seconds
# Partition discourse: 0.000291109085083 seconds
# Create fuzzy number: 0.000130891799927 seconds
# Update fuzzy membership: 5.19752502441e-05 seconds
# Update FLR: 0.000122785568237 seconds
# Update jump weights: 0.0137040615082 seconds
# Update transition weights: 0.000462055206299 seconds
# Assign membership for test case: 6.79492950439e-05 seconds
# Forecast next price: 0.000124931335449 seconds
# Update data: 0.00275993347168 seconds
# Partition discourse: 0.000351905822754 seconds
# Create fuzzy number: 0.000144004821777 seconds
# Update fuzzy membership: 5.91278076172e-05 seconds
# Update FLR: 0.000136852264404 seconds
# Update jump weights: 0.0140948295593 seconds
# Update transition weights: 0.000397920608521 seconds
# Assign membership for test case: 4.41074371338e-05 seconds
# Forecast next price: 0.00011420249939 seconds
# Update data: 0.00223278999329 seconds
# Partition discourse: 0.000268936157227 seconds
# Create fuzzy number: 0.00012993812561 seconds
# Update fuzzy membership: 4.79221343994e-05 seconds
# Update FLR: 0.000125885009766 seconds
# Update jump weights: 0.0138511657715 seconds
# Update transition weights: 0.000402927398682 seconds
# Assign membership for test case: 4.29153442383e-05 seconds
# Forecast next price: 0.000108957290649 seconds
# Update data: 0.00222897529602 seconds
# Partition discourse: 0.000270843505859 seconds
# Create fuzzy number: 0.000133037567139 seconds
# Update fuzzy membership: 4.6968460083e-05 seconds
# Update FLR: 0.000123977661133 seconds
# Update jump weights: 0.0135610103607 seconds
# Update transition weights: 0.000456094741821 seconds
# Assign membership for test case: 6.103515625e-05 seconds
# Forecast next price: 0.000120162963867 seconds
# Update data: 0.00253391265869 seconds
# Partition discourse: 0.000289916992188 seconds
# Create fuzzy number: 0.000133037567139 seconds
# Update fuzzy membership: 5.10215759277e-05 seconds
# Update FLR: 0.000130891799927 seconds
# Update jump weights: 0.0136108398438 seconds
# Update transition weights: 0.000395059585571 seconds
# Assign membership for test case: 4.29153442383e-05 seconds
# Forecast next price: 0.000111103057861 seconds
# Update data: 0.00221705436707 seconds
# Partition discourse: 0.000275850296021 seconds
# Create fuzzy number: 0.000128984451294 seconds
# Update fuzzy membership: 4.79221343994e-05 seconds
# Update FLR: 0.000133991241455 seconds
# Update jump weights: 0.0137560367584 seconds
# Update transition weights: 0.000394821166992 seconds
# Assign membership for test case: 4.50611114502e-05 seconds
# Forecast next price: 0.000115156173706 seconds
# Update data: 0.00223588943481 seconds
# Partition discourse: 0.000269889831543 seconds
# Create fuzzy number: 0.000133991241455 seconds
# Update fuzzy membership: 5.10215759277e-05 seconds
# Update FLR: 0.000127077102661 seconds
# Update jump weights: 0.0137410163879 seconds
# Update transition weights: 0.000458002090454 seconds
# Assign membership for test case: 6.31809234619e-05 seconds
# Forecast next price: 0.0001220703125 seconds
# Update data: 0.00258588790894 seconds
# Partition discourse: 0.000294923782349 seconds
# Create fuzzy number: 0.000133991241455 seconds
# Update fuzzy membership: 5.3882598877e-05 seconds
# Update FLR: 0.000164031982422 seconds
# Update jump weights: 0.0140340328217 seconds
# Update transition weights: 0.000398874282837 seconds
# Assign membership for test case: 4.50611114502e-05 seconds
# Forecast next price: 0.000113964080811 seconds
# Update data: 0.00248599052429 seconds
# Partition discourse: 0.000290870666504 seconds
# Create fuzzy number: 0.000134944915771 seconds
# Update fuzzy membership: 4.88758087158e-05 seconds
# Update FLR: 0.000131130218506 seconds
# Update jump weights: 0.0135569572449 seconds
# Update transition weights: 0.000397920608521 seconds
# Assign membership for test case: 4.19616699219e-05 seconds
# Forecast next price: 0.000108957290649 seconds
# Update data: 0.00251984596252 seconds
# Partition discourse: 0.000298023223877 seconds
# Create fuzzy number: 0.000135898590088 seconds
# Update fuzzy membership: 5.19752502441e-05 seconds
# Update FLR: 0.000130891799927 seconds
# Update jump weights: 0.0135719776154 seconds
# Update transition weights: 0.000457048416138 seconds
# Assign membership for test case: 6.103515625e-05 seconds
# Forecast next price: 0.000117063522339 seconds
# Update data: 0.00281691551208 seconds
# Partition discourse: 0.000291109085083 seconds
# Create fuzzy number: 0.000131130218506 seconds
# Update fuzzy membership: 5.10215759277e-05 seconds
# Update FLR: 0.000155925750732 seconds
# Update jump weights: 0.0136501789093 seconds
# Update transition weights: 0.000402927398682 seconds
# Assign membership for test case: 5.69820404053e-05 seconds
# Forecast next price: 0.000117063522339 seconds
# Update data: 0.00225400924683 seconds
# Partition discourse: 0.000272989273071 seconds
# Create fuzzy number: 0.000133037567139 seconds
# Update fuzzy membership: 4.6968460083e-05 seconds
# Update FLR: 0.000126123428345 seconds
# Update jump weights: 0.0137629508972 seconds
# Update transition weights: 0.00042200088501 seconds
# Assign membership for test case: 5.00679016113e-05 seconds
# Forecast next price: 0.000120878219604 seconds
# Update data: 0.0024299621582 seconds
# Partition discourse: 0.000289916992188 seconds
# Create fuzzy number: 0.000134944915771 seconds
# Update fuzzy membership: 5.10215759277e-05 seconds
# Update FLR: 0.000127077102661 seconds
# Update jump weights: 0.0139260292053 seconds
# Update transition weights: 0.000504970550537 seconds
# Assign membership for test case: 6.69956207275e-05 seconds
# Forecast next price: 0.00012993812561 seconds
# Update data: 0.00271892547607 seconds
# Partition discourse: 0.000292062759399 seconds
# Create fuzzy number: 0.000131130218506 seconds
# Update fuzzy membership: 5.07831573486e-05 seconds
# Update FLR: 0.000132083892822 seconds
# Update jump weights: 0.0137481689453 seconds
# Update transition weights: 0.000396966934204 seconds
# Assign membership for test case: 4.57763671875e-05 seconds
# Forecast next price: 0.000112056732178 seconds
# Update data: 0.00224685668945 seconds
# Partition discourse: 0.000277996063232 seconds
# Create fuzzy number: 0.000130891799927 seconds
# Update fuzzy membership: 4.79221343994e-05 seconds
# Update FLR: 0.000128984451294 seconds
# Update jump weights: 0.0138659477234 seconds
# Update transition weights: 0.000419139862061 seconds
# Assign membership for test case: 4.60147857666e-05 seconds
# Forecast next price: 0.000112056732178 seconds
# Update data: 0.00233912467957 seconds
# Partition discourse: 0.000288009643555 seconds
# Create fuzzy number: 0.000133037567139 seconds
# Update fuzzy membership: 5.00679016113e-05 seconds
# Update FLR: 0.000124931335449 seconds
# Update jump weights: 0.0153410434723 seconds
# Update transition weights: 0.000746965408325 seconds
# Assign membership for test case: 8.60691070557e-05 seconds
# Forecast next price: 0.000210046768188 seconds
# Update data: 0.00250816345215 seconds
# Partition discourse: 0.000288963317871 seconds
# Create fuzzy number: 0.00012993812561 seconds
# Update fuzzy membership: 5.00679016113e-05 seconds
# Update FLR: 0.000131845474243 seconds
# Update jump weights: 0.0137221813202 seconds
# Update transition weights: 0.000398874282837 seconds
# Assign membership for test case: 4.19616699219e-05 seconds
# Forecast next price: 0.000105857849121 seconds
# Update data: 0.00222110748291 seconds
# Partition discourse: 0.000272035598755 seconds
# Create fuzzy number: 0.000270128250122 seconds
# Update fuzzy membership: 9.70363616943e-05 seconds
# Update FLR: 0.000255107879639 seconds
# Update jump weights: 0.0162079334259 seconds
# Update transition weights: 0.000442981719971 seconds
# Assign membership for test case: 5.10215759277e-05 seconds
# Forecast next price: 0.000114917755127 seconds
# Update data: 0.00234794616699 seconds
# Partition discourse: 0.000271797180176 seconds
# Create fuzzy number: 0.000133991241455 seconds
# Update fuzzy membership: 4.81605529785e-05 seconds
# Update FLR: 0.000128984451294 seconds
# Update jump weights: 0.0138509273529 seconds
# Update transition weights: 0.000458955764771 seconds
# Assign membership for test case: 6.38961791992e-05 seconds
# Forecast next price: 0.000124216079712 seconds
# Update data: 0.00255990028381 seconds
# Partition discourse: 0.000478029251099 seconds
# Create fuzzy number: 0.0001380443573 seconds
# Update fuzzy membership: 6.103515625e-05 seconds
# Update FLR: 0.000133991241455 seconds
# Update jump weights: 0.0138309001923 seconds
# Update transition weights: 0.000417947769165 seconds
# Assign membership for test case: 5.00679016113e-05 seconds
# Forecast next price: 0.000118970870972 seconds
# Update data: 0.00287079811096 seconds
# Partition discourse: 0.000282049179077 seconds
# Create fuzzy number: 0.000133991241455 seconds
# Update fuzzy membership: 4.81605529785e-05 seconds
# Update FLR: 0.000131130218506 seconds
# Update jump weights: 0.0133490562439 seconds
# Update transition weights: 0.000400066375732 seconds
# Assign membership for test case: 4.41074371338e-05 seconds
# Forecast next price: 0.0001060962677 seconds
# Update data: 0.00256991386414 seconds
# Partition discourse: 0.000293016433716 seconds
# Create fuzzy number: 0.000136137008667 seconds
# Update fuzzy membership: 5.07831573486e-05 seconds
# Update FLR: 0.000133037567139 seconds
# Update jump weights: 0.0137391090393 seconds
# Update transition weights: 0.000523090362549 seconds
# Assign membership for test case: 7.10487365723e-05 seconds
# Forecast next price: 0.00012993812561 seconds
# Update data: 0.00262498855591 seconds
# Partition discourse: 0.000277042388916 seconds
# Create fuzzy number: 0.000132083892822 seconds
# Update fuzzy membership: 4.6968460083e-05 seconds
# Update FLR: 0.000133037567139 seconds
# Update jump weights: 0.0137071609497 seconds
# Update transition weights: 0.000401973724365 seconds
# Assign membership for test case: 4.72068786621e-05 seconds
# Forecast next price: 0.000111103057861 seconds
# Update data: 0.00224113464355 seconds
# Partition discourse: 0.000269889831543 seconds
# Create fuzzy number: 0.000136852264404 seconds
# Update fuzzy membership: 4.6968460083e-05 seconds
# Update FLR: 0.000126123428345 seconds
# Update jump weights: 0.014032125473 seconds
# Update transition weights: 0.000398874282837 seconds
# Assign membership for test case: 4.50611114502e-05 seconds
# Forecast next price: 0.000111818313599 seconds
# Update data: 0.0023341178894 seconds
# Partition discourse: 0.000272989273071 seconds
# Create fuzzy number: 0.000128984451294 seconds
# Update fuzzy membership: 4.6968460083e-05 seconds
# Update FLR: 0.000128030776978 seconds
# Update jump weights: 0.0135550498962 seconds
# Update transition weights: 0.000905990600586 seconds
# Assign membership for test case: 0.000109910964966 seconds
# Forecast next price: 0.00021505355835 seconds
# Update data: 0.00231599807739 seconds
# Partition discourse: 0.000274181365967 seconds
# Create fuzzy number: 0.000133991241455 seconds
# Update fuzzy membership: 4.79221343994e-05 seconds
# Update FLR: 0.000135898590088 seconds
# Update jump weights: 0.0137119293213 seconds
# Update transition weights: 0.000406980514526 seconds
# Assign membership for test case: 4.41074371338e-05 seconds
# Forecast next price: 0.000108003616333 seconds
# Update data: 0.00224304199219 seconds
# Partition discourse: 0.000272035598755 seconds
# Create fuzzy number: 0.00012993812561 seconds
# Update fuzzy membership: 4.79221343994e-05 seconds
# Update FLR: 0.000128984451294 seconds
# Update jump weights: 0.0141599178314 seconds
# Update transition weights: 0.000423908233643 seconds
# Assign membership for test case: 4.6968460083e-05 seconds
# Forecast next price: 0.000110149383545 seconds
# RMSE = 137.499770881
# Time cost: 5.61609196663 seconds

# %%
df_test = pd.DataFrame(test_data.iloc[1:]['Date'])
df_test['data testing'] = pd.Series(actual_prices).values
df_test['forecasting'] = pd.Series(pred_prices).values
df_test.index = df_test['Date']
plt.figure(figsize=(14,7))
df_test['data testing'].plot(style='k-', linewidth=2, label='data testing')
df_test['forecasting'].plot(style='g:', linewidth=3, label='forecasting')
plt.ylabel('Price', fontsize=18)
plt.legend(loc='best')
plt.title("IBEX35_forecasting", fontsize=24)
