# %% [markdown]
# Update: online learning and

# %%
import pandas as pd
import numpy as np
import operator
import matplotlib.pyplot as plt
import plotly.plotly as py
import plotly.graph_objs as go
# %matplotlib inline
from time import time

from collections import defaultdict
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
from plotly.offline import init_notebook_mode

py.sign_in('imaginationsuper', 'PQj7gXzsTJFqNKsXkWMT')
init_notebook_mode(connected=True)
# Out:
# <script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window.Plotly) {{require(['plotly'],function(plotly) {window.Plotly=plotly;});}}</script>

# %%
def universe_partition(data, d1=10, d2=10):
    x_max, x_min = data.max(axis=0), data.min(axis=0)
    std_val = data.std(axis=0)
    len_val = np.round(std_val / 10)
#     len_val = 30
    u_max, u_min = int(x_max+d2), int(x_min-d1) # bound of universe discourse
    u_b = np.arange(u_min, u_max, step=float(len_val)) # cutting points
    u_s = u_b[:-1] # u1
    u_e = u_b[1:] # u2
    u_discourse = zip(u_b, u_e) # interval
    return u_discourse

def set_fuzzy_numbers(u_discourse):
    fuzzy_numbers = list()
    for i, u_i in enumerate(u_discourse):
        if (i!=0) and (i!=len(u_discourse)-1):
            u_l, u_r = u_discourse[i-1], u_discourse[i+1]
            A_l, A_r = np.mean(u_l), np.mean(u_r)
            fuzzy_numbers.append((A_l, u_i[0], u_i[1], A_r))
    return fuzzy_numbers

# %%
def membership_evaluation(value, fuzzy_number):
    A_l, u_1, u_2, A_r = fuzzy_number
    mu = 0 # membership indication
    try:
        if np.logical_and(value>=A_l, value <u_1):
            mu = (value - A_l) / (u_1 - A_l)
        elif np.logical_and(value>=u_1, value<=u_2):
            mu = 1
        elif np.logical_and(value>u_2, value<=A_r):
            mu = (value - u_2) / (A_r - u_2)
    except ZeroDivisionError:
        mu = 0
    return mu

def membership_assignment(value_time_series, fuzzy_numbers):
    n_fuzzy_numbers = len(fuzzy_numbers)
    membership_list = list()
    for i, value in enumerate(value_time_series):
        value_rep = [value] * n_fuzzy_numbers
        memberships = map(lambda val, A: membership_evaluation(val, A), value_rep, fuzzy_numbers)
        max_index, _ = max(enumerate(memberships), key=operator.itemgetter(1))
        membership_list.append(max_index)
    return membership_list

def get_membership(value, fuzzy_numbers):
    n_fuzzy_numbers = len(fuzzy_numbers)
    membership_index = 0
    value_rep = [value] * n_fuzzy_numbers
    memberships = map(lambda val, Ai: membership_evaluation(val, Ai), value_rep, fuzzy_numbers)
    membership_index, _ = max(enumerate(memberships), key=operator.itemgetter(1))
    return membership_index

# %%
def FLR(membership_time_series): # transition between consecutive observations
    transitions = list()
    for j, Aj in enumerate(membership_time_series):
        if j!=0:
            Ai = membership_time_series[j-1]
            transitions.append((Ai, Aj))
    return transitions

def FLR_weight(transitions, time_series): # compute jump frequency by FLR
    jumps = map(lambda x: x[1]-x[0], transitions) # compute jumps by transitions 
    jump_time_series = zip(jumps, time_series) # assign timestamp for each jump beta^t_p,p+k
    jump_counts = defaultdict(list) 
    for key, value in jump_time_series:
        jump_counts[key].append(value) # count jump by its timestamps
    jump_counts = {key: np.sum(value) for key, value in jump_counts.items()} # sum up total time for each jump
    total_count = float(np.sum(jump_counts.values()))
    for key, value in jump_counts.iteritems(): 
        jump_counts[key] = value / total_count # normalize jumps as weights
    return jump_counts

def FRG_weight(transitions, time_series): 
    transition_time_series = zip(transitions, time_series)
    transition_groups = map(lambda x: (x[0][0], (x[0][1], x[1])), transition_time_series) 
    transition_weights = defaultdict(list)
    for key, value in transition_groups:
        transition_weights[key].append(value) # group transitions by initial state A_i
    transition_weights = {key: dict(value) for key, value in transition_weights.items()}
    for key, value in transition_weights.iteritems():
        total_weight = float(np.sum(value.values()))
        value = {k: (v/total_weight) for k, v in value.items()} # normalize weight inside each group
        transition_weights[key] = value
    return transition_weights

# %%
# forecasting by fuzzy numbers
def fuzzy_add(A, B): # Proposition #1 (1)
    return tuple([np.sum(x) for x in zip(A, B)])

def fuzzy_scale(c, A): # Proposition #1 (2)
    cA = [c*a for a in A]
    if c>=0:
        return tuple(cA)
    else:
        cA.reverse()
        return tuple(cA)

def forecast_jump(i, s, A_list):
    jumps = s.keys() # possible jumps
    m = len(A_list) # number of fuzzy numbers in model
    sA_list = list()
    sk_list = list()
    Aip_list = list()
    sA = tuple([0]*len(A_list[0]))
    for k in jumps:
        ip = k+i
        if (ip>=0 and ip<m): # check if index is within range
            sk_list.append(s[k])
            Aip_list.append(A_list[ip])
    sk_tot = np.sum(sk_list)
    sk_list = [sk/float(sk_tot) for sk in sk_list] # normalize locally
    for i in range(len(sk_list)):
        sA_list.append(fuzzy_scale(sk_list[i], Aip_list[i]))
    if len(sA_list)>0:
        for sa in sA_list:
            sA = fuzzy_add(sA, sa)
    return sA
    
def forecast_transition(i, w, A_list):
    wA = tuple([0]*len(A_list[0])) # default FLG relation
    if i in w.keys():
        for kj, v in w[i].iteritems():
            wA = fuzzy_add(wA, fuzzy_scale(v, A_list[kj]))
    return wA

def forecast_price(As, Aw, gamma=0.1):
    if gamma<0 or gamma>1:
        raise ValueError("gamma should be between 0.0 and 1.0 (inclusive on both ends)")     
    wAi = fuzzy_scale(1-gamma, Aw)
    if (np.sum(wAi) == 0): # no FLR observed in history
        sAi = As
    else:
        sAi = fuzzy_scale(gamma, As)
    Ai_pred = fuzzy_add(sAi, wAi)
    return np.mean(Ai_pred)

# %%
start_time = time()
# datafile = '../data/IBEX35(201301-201512).xlsx'
# xl = pd.ExcelFile(datafile)
# df = xl.parse(u'Sheet1')
datafile = '../data/IBEX35.csv'
dateparse = lambda x: pd.datetime.strptime(x, '%m/%d/%y')
df = pd.read_csv(datafile, header=0, parse_dates=['Date'], date_parser=dateparse)

# %%
split_date = pd.datetime.strptime('2014-12-31', '%Y-%m-%d')
train_data = df[df['Date'] < split_date]
test_data = df[df['Date'] >= split_date]
first_date = train_data['Date'][0]

# %%
option = 'Price'
pred_prices = list()
actual_prices = test_data[option].tolist()[1:]
indices = test_data.index
for i in range(len(indices)-1):
    stm = time()
    #id = indices[i]
    prev = test_data.iloc[i]
    train_data.append(prev)
    print("Update data: %s seconds" % str(time() - stm))
    stm = time()
    u_discourse = universe_partition(train_data[option], d1=1053, d2=912)
    print("Partition discourse: %s seconds" % str(time() - stm))
    stm = time()
    A_list = set_fuzzy_numbers(u_discourse)
    print("Create fuzzy number: %s seconds" % str(time() - stm))
    stm = time()
    train_data_membership_series = membership_assignment(train_data[option], fuzzy_numbers=A_list)
#     train_data_ms = [ms+1 for ms in train_data_membership_series]
    print("Update fuzzy membership: %s seconds" % str(time() - stm))
    stm = time()
    transition_FLR = FLR(train_data_membership_series)
    print("Update FLR: %s seconds" % str(time() - stm))
    stm = time()
    train_data_days = train_data['Date'].apply(lambda x: x-first_date).dt.days.tolist() # convert Timedelta to numeric days
    jump_weights = FLR_weight(transition_FLR, train_data_days[:len(transition_FLR)])
    print("Update jump weights: %s seconds" % str(time() - stm))
    stm = time()
    transition_weights = FRG_weight(transition_FLR, train_data_days[:len(transition_FLR)])
    print("Update transition weights: %s seconds" % str(time() - stm))
    stm = time()
    # forecasting current test data
    price = prev[option]
    index = get_membership(price, A_list)
    print("Assign membership for test case: %s seconds" % str(time() - stm))
    stm = time()
    next_price = forecast_price(forecast_jump(index, jump_weights, A_list), forecast_transition(index, transition_weights, A_list), gamma=0.9)
    print("Forecast next price: %s seconds" % str(time() - stm))
    stm = time()
    pred_prices.append(next_price)
    
print "RMSE = "+str(np.sqrt(mean_squared_error(actual_prices, pred_prices)))
print "Time cost: "+str(time()-start_time)+" seconds"
# Out:
# Update data: 0.00321698188782 seconds
# Partition discourse: 0.000467777252197 seconds
# Create fuzzy number: 0.00145888328552 seconds
# Update fuzzy membership: 0.0958740711212 seconds
# Update FLR: 0.000257968902588 seconds
# Update jump weights: 0.0181231498718 seconds
# Update transition weights: 0.000817060470581 seconds
# Assign membership for test case: 0.000488042831421 seconds
# Forecast next price: 0.00207304954529 seconds
# Update data: 0.00647592544556 seconds
# Partition discourse: 0.000286102294922 seconds
# Create fuzzy number: 0.00116205215454 seconds
# Update fuzzy membership: 0.0985188484192 seconds
# Update FLR: 0.000159025192261 seconds
# Update jump weights: 0.0189349651337 seconds
# Update transition weights: 0.00134086608887 seconds
# Assign membership for test case: 0.00039005279541 seconds
# Forecast next price: 0.000823020935059 seconds
# Update data: 0.00550198554993 seconds
# Partition discourse: 0.000353097915649 seconds
# Create fuzzy number: 0.00268316268921 seconds
# Update fuzzy membership: 0.103214025497 seconds
# Update FLR: 0.000169038772583 seconds
# Update jump weights: 0.0181810855865 seconds
# Update transition weights: 0.000701904296875 seconds
# Assign membership for test case: 0.000627994537354 seconds
# Forecast next price: 0.00123906135559 seconds
# Update data: 0.00544810295105 seconds
# Partition discourse: 0.000864028930664 seconds
# Create fuzzy number: 0.00250506401062 seconds
# Update fuzzy membership: 0.105150938034 seconds
# Update FLR: 0.000247001647949 seconds
# Update jump weights: 0.0199761390686 seconds
# Update transition weights: 0.00115394592285 seconds
# Assign membership for test case: 0.000411987304688 seconds
# Forecast next price: 0.00139284133911 seconds
# Update data: 0.0237200260162 seconds
# Partition discourse: 0.000495910644531 seconds
# Create fuzzy number: 0.00118708610535 seconds
# Update FLR: 0.000163078308105 seconds
# Update jump weights: 0.0147049427032 seconds
# Update transition weights: 0.00068211555481 seconds
# Assign membership for test case: 0.000233173370361 seconds
# Forecast next price: 0.000319004058838 seconds
# Update data: 0.00231313705444 seconds
# Partition discourse: 0.000294208526611 seconds
# Create fuzzy number: 0.00119113922119 seconds
# Update fuzzy membership: 0.111061811447 seconds
# Update FLR: 0.000248908996582 seconds
# Update jump weights: 0.0369129180908 seconds
# Update transition weights: 0.00124597549438 seconds
# Assign membership for test case: 0.000441074371338 seconds
# Forecast next price: 0.000414133071899 seconds
# Update data: 0.00430202484131 seconds
# Partition discourse: 0.000370025634766 seconds
# Create fuzzy number: 0.00158309936523 seconds
# Update fuzzy membership: 0.15764093399 seconds
# Update FLR: 0.000186920166016 seconds
# Update jump weights: 0.0173759460449 seconds
# Update transition weights: 0.00144219398499 seconds
# Assign membership for test case: 0.000500917434692 seconds
# Forecast next price: 0.00091290473938 seconds
# Update data: 0.00560688972473 seconds
# Partition discourse: 0.00034499168396 seconds
# Create fuzzy number: 0.00119304656982 seconds
# Update fuzzy membership: 0.118748903275 seconds
# Update FLR: 0.00016188621521 seconds
# Update jump weights: 0.018590927124 seconds
# Update transition weights: 0.000792026519775 seconds
# Assign membership for test case: 0.000247001647949 seconds
# Forecast next price: 0.000404119491577 seconds
# Update data: 0.00314402580261 seconds
# Partition discourse: 0.000892877578735 seconds
# Create fuzzy number: 0.00203084945679 seconds
# Update fuzzy membership: 0.116895198822 seconds
# Update FLR: 0.0002760887146 seconds
# Update jump weights: 0.0187649726868 seconds
# Update transition weights: 0.0015389919281 seconds
# Assign membership for test case: 0.000275135040283 seconds
# Forecast next price: 0.000511169433594 seconds
# Update data: 0.00331616401672 seconds
# Partition discourse: 0.000432968139648 seconds
# Create fuzzy number: 0.00119996070862 seconds
# Update fuzzy membership: 0.18116402626 seconds
# Update FLR: 0.000185012817383 seconds
# Update jump weights: 0.0147540569305 seconds
# Update transition weights: 0.000680208206177 seconds
# Assign membership for test case: 0.000244855880737 seconds
# Forecast next price: 0.000432014465332 seconds
# Update data: 0.00236201286316 seconds
# Partition discourse: 0.000464916229248 seconds
# Create fuzzy number: 0.00155687332153 seconds
# Update fuzzy membership: 0.0965061187744 seconds
# Update FLR: 0.000192165374756 seconds
# Update jump weights: 0.0141870975494 seconds
# Update transition weights: 0.00190091133118 seconds
# Assign membership for test case: 0.000489950180054 seconds
# Forecast next price: 0.000962018966675 seconds
# Update data: 0.00449204444885 seconds
# Partition discourse: 0.000563144683838 seconds
# Create fuzzy number: 0.0024049282074 seconds
# Update fuzzy membership: 0.105320930481 seconds
# Update FLR: 0.000226020812988 seconds
# Update jump weights: 0.0267648696899 seconds
# Update transition weights: 0.000827074050903 seconds
# Assign membership for test case: 0.000253915786743 seconds
# Forecast next price: 0.000384092330933 seconds
# Update data: 0.00446009635925 seconds
# Partition discourse: 0.000343084335327 seconds
# ...
# Partition discourse: 0.000806093215942 seconds
# Create fuzzy number: 0.00175809860229 seconds
# Update fuzzy membership: 0.125164985657 seconds
# Update FLR: 0.000231027603149 seconds
# Update jump weights: 0.018571138382 seconds
# Update transition weights: 0.000684976577759 seconds
# Assign membership for test case: 0.00023889541626 seconds
# Forecast next price: 0.000487089157104 seconds
# Update data: 0.00328898429871 seconds
# Partition discourse: 0.000647068023682 seconds
# Create fuzzy number: 0.00390315055847 seconds
# Update fuzzy membership: 0.105661869049 seconds
# Update FLR: 0.000267028808594 seconds
# Update jump weights: 0.0147290229797 seconds
# Update transition weights: 0.000690221786499 seconds
# Assign membership for test case: 0.000242948532104 seconds
# Forecast next price: 0.000538110733032 seconds
# Update data: 0.00299906730652 seconds
# Partition discourse: 0.000313997268677 seconds
# Create fuzzy number: 0.0011990070343 seconds
# Update fuzzy membership: 0.09632396698 seconds
# Update FLR: 0.000164985656738 seconds
# Update jump weights: 0.0147700309753 seconds
# Update transition weights: 0.000679016113281 seconds
# Assign membership for test case: 0.000236988067627 seconds
# Forecast next price: 0.000456094741821 seconds
# Update data: 0.00241899490356 seconds
# Partition discourse: 0.000303030014038 seconds
# Create fuzzy number: 0.00117897987366 seconds
# Update fuzzy membership: 0.0988698005676 seconds
# Update FLR: 0.000245094299316 seconds
# Update jump weights: 0.0163600444794 seconds
# Update transition weights: 0.000736951828003 seconds
# Assign membership for test case: 0.000246047973633 seconds
# Forecast next price: 0.000500917434692 seconds
# Update data: 0.00254416465759 seconds
# Partition discourse: 0.000319004058838 seconds
# Create fuzzy number: 0.00163412094116 seconds
# Update fuzzy membership: 0.0974609851837 seconds
# Update FLR: 0.000261068344116 seconds
# Update jump weights: 0.0142509937286 seconds
# Update transition weights: 0.000669956207275 seconds
# Assign membership for test case: 0.000231027603149 seconds
# Forecast next price: 0.000460863113403 seconds
# Update data: 0.00232100486755 seconds
# Partition discourse: 0.000298023223877 seconds
# Create fuzzy number: 0.00120711326599 seconds
# Update fuzzy membership: 0.0953159332275 seconds
# Update FLR: 0.000241041183472 seconds
# Update jump weights: 0.0142328739166 seconds
# Update transition weights: 0.00067400932312 seconds
# Assign membership for test case: 0.000237941741943 seconds
# Forecast next price: 0.000461101531982 seconds
# Update data: 0.0023307800293 seconds
# Partition discourse: 0.000298976898193 seconds
# Create fuzzy number: 0.00118899345398 seconds
# Update fuzzy membership: 0.093435049057 seconds
# Update FLR: 0.000169038772583 seconds
# Update jump weights: 0.0171270370483 seconds
# Update transition weights: 0.000783920288086 seconds
# Assign membership for test case: 0.000267028808594 seconds
# Forecast next price: 0.00054407119751 seconds
# Update data: 0.00259399414062 seconds
# Partition discourse: 0.000295877456665 seconds
# Create fuzzy number: 0.00171113014221 seconds
# Update fuzzy membership: 0.130993843079 seconds
# Update FLR: 0.000173091888428 seconds
# Update jump weights: 0.0253608226776 seconds
# Update transition weights: 0.000746011734009 seconds
# Assign membership for test case: 0.000253200531006 seconds
# Forecast next price: 0.000609159469604 seconds
# Update data: 0.00281810760498 seconds
# Partition discourse: 0.000370025634766 seconds
# Create fuzzy number: 0.00121283531189 seconds
# Update fuzzy membership: 0.127445936203 seconds
# Update FLR: 0.000152826309204 seconds
# Update jump weights: 0.0167381763458 seconds
# Update transition weights: 0.000699996948242 seconds
# Assign membership for test case: 0.000245094299316 seconds
# Forecast next price: 0.000607013702393 seconds
# Update data: 0.00253200531006 seconds
# Partition discourse: 0.000318050384521 seconds
# Create fuzzy number: 0.00143218040466 seconds
# Update fuzzy membership: 0.111321926117 seconds
# Update FLR: 0.000241041183472 seconds
# Update jump weights: 0.0147140026093 seconds
# Update transition weights: 0.000695943832397 seconds
# Assign membership for test case: 0.000247955322266 seconds
# Forecast next price: 0.000904083251953 seconds
# Update data: 0.00239992141724 seconds
# Partition discourse: 0.000300884246826 seconds
# Create fuzzy number: 0.00119304656982 seconds
# Update fuzzy membership: 0.0999760627747 seconds
# Update FLR: 0.000260829925537 seconds
# Update jump weights: 0.0153429508209 seconds
# Update transition weights: 0.000931978225708 seconds
# Assign membership for test case: 0.000248908996582 seconds
# Forecast next price: 0.00046706199646 seconds
# Update data: 0.00255703926086 seconds
# Partition discourse: 0.000343084335327 seconds
# Create fuzzy number: 0.00120210647583 seconds
# Update fuzzy membership: 0.0970380306244 seconds
# Update FLR: 0.000250101089478 seconds
# Update jump weights: 0.0145359039307 seconds
# Update transition weights: 0.000671863555908 seconds
# Assign membership for test case: 0.000239849090576 seconds
# Forecast next price: 0.000611066818237 seconds
# Update data: 0.00304698944092 seconds
# Partition discourse: 0.000311136245728 seconds
# Create fuzzy number: 0.0011899471283 seconds
# Update fuzzy membership: 0.106216192245 seconds
# Update FLR: 0.000147104263306 seconds
# Update jump weights: 0.0250809192657 seconds
# Update transition weights: 0.00284099578857 seconds
# Assign membership for test case: 0.00121212005615 seconds
# Forecast next price: 0.00118803977966 seconds
# Update data: 0.00751399993896 seconds
# Partition discourse: 0.00071382522583 seconds
# Create fuzzy number: 0.00254607200623 seconds
# Update fuzzy membership: 0.133023023605 seconds
# Update FLR: 0.000375986099243 seconds
# Update jump weights: 0.0212240219116 seconds
# Update transition weights: 0.000677824020386 seconds
# Assign membership for test case: 0.000241041183472 seconds
# Forecast next price: 0.000452995300293 seconds
# Update data: 0.00236988067627 seconds
# Partition discourse: 0.000326156616211 seconds
# Create fuzzy number: 0.00147414207458 seconds
# Update fuzzy membership: 0.121576786041 seconds
# Update FLR: 0.000362157821655 seconds
# Update jump weights: 0.0171010494232 seconds
# Update transition weights: 0.00327205657959 seconds
# Assign membership for test case: 0.000300884246826 seconds
# Forecast next price: 0.000744104385376 seconds
# Update data: 0.00227093696594 seconds
# Partition discourse: 0.000290155410767 seconds
# Create fuzzy number: 0.00136399269104 seconds
# Update fuzzy membership: 0.124461174011 seconds
# Update FLR: 0.000523090362549 seconds
# Update jump weights: 0.0192170143127 seconds
# Update transition weights: 0.000720024108887 seconds
# Assign membership for test case: 0.00025200843811 seconds
# Forecast next price: 0.000599145889282 seconds
# Update data: 0.00247001647949 seconds
# Partition discourse: 0.00030779838562 seconds
# Create fuzzy number: 0.00119519233704 seconds
# Update fuzzy membership: 0.139642953873 seconds
# Update FLR: 0.000349044799805 seconds
# Update jump weights: 0.0188300609589 seconds
# Update transition weights: 0.000891923904419 seconds
# Assign membership for test case: 0.000242948532104 seconds
# Forecast next price: 0.000462055206299 seconds
# Update data: 0.00243091583252 seconds
# Partition discourse: 0.000313997268677 seconds
# Create fuzzy number: 0.00119185447693 seconds
# Update fuzzy membership: 0.0977210998535 seconds
# Update FLR: 0.000169038772583 seconds
# Update jump weights: 0.0139429569244 seconds
# Update transition weights: 0.000684022903442 seconds
# Assign membership for test case: 0.000245094299316 seconds
# Forecast next price: 0.00048303604126 seconds
# Update data: 0.00233316421509 seconds
# Partition discourse: 0.000297784805298 seconds
# Create fuzzy number: 0.00121998786926 seconds
# Update fuzzy membership: 0.0963699817657 seconds
# Update FLR: 0.000237941741943 seconds
# Update jump weights: 0.0141069889069 seconds
# Update transition weights: 0.000677824020386 seconds
# Assign membership for test case: 0.000236034393311 seconds
# Forecast next price: 0.000488042831421 seconds
# Update data: 0.00235199928284 seconds
# Partition discourse: 0.000298976898193 seconds
# Create fuzzy number: 0.00124192237854 seconds
# Update fuzzy membership: 0.0964379310608 seconds
# Update FLR: 0.000245094299316 seconds
# Update jump weights: 0.0143749713898 seconds
# Update transition weights: 0.000672101974487 seconds
# Assign membership for test case: 0.000237941741943 seconds
# Forecast next price: 0.000457048416138 seconds
# Update data: 0.00234913825989 seconds
# Partition discourse: 0.000303030014038 seconds
# Create fuzzy number: 0.00117301940918 seconds
# Update fuzzy membership: 0.10017991066 seconds
# Update FLR: 0.000169038772583 seconds
# Update jump weights: 0.0209259986877 seconds
# Update transition weights: 0.00323510169983 seconds
# Assign membership for test case: 0.000788927078247 seconds
# Forecast next price: 0.000695943832397 seconds
# Update data: 0.00365805625916 seconds
# Partition discourse: 0.000480175018311 seconds
# Create fuzzy number: 0.00121283531189 seconds
# Update fuzzy membership: 0.132521867752 seconds
# Update FLR: 0.000258922576904 seconds
# Update jump weights: 0.0163331031799 seconds
# Update transition weights: 0.000690937042236 seconds
# Assign membership for test case: 0.000247955322266 seconds
# Forecast next price: 0.000503063201904 seconds
# Update data: 0.00268816947937 seconds
# Partition discourse: 0.00040602684021 seconds
# Create fuzzy number: 0.0012321472168 seconds
# Update fuzzy membership: 0.118358135223 seconds
# Update FLR: 0.000560998916626 seconds
# Update jump weights: 0.0174400806427 seconds
# Update transition weights: 0.000810861587524 seconds
# Assign membership for test case: 0.000370979309082 seconds
# Forecast next price: 0.000481843948364 seconds
# Update data: 0.00409293174744 seconds
# Partition discourse: 0.000334978103638 seconds
# Create fuzzy number: 0.00119304656982 seconds
# Update fuzzy membership: 0.114928007126 seconds
# Update FLR: 0.000182867050171 seconds
# Update jump weights: 0.0175428390503 seconds
# Update transition weights: 0.000649929046631 seconds
# Assign membership for test case: 0.000230073928833 seconds
# Forecast next price: 0.000470876693726 seconds
# Update data: 0.0032958984375 seconds
# Partition discourse: 0.000720977783203 seconds
# Create fuzzy number: 0.00144195556641 seconds
# Update fuzzy membership: 0.120260000229 seconds
# Update FLR: 0.00016188621521 seconds
# Update jump weights: 0.0178179740906 seconds
# Update transition weights: 0.00155186653137 seconds
# Assign membership for test case: 0.000419855117798 seconds
# Forecast next price: 0.00047492980957 seconds
# Update data: 0.00254011154175 seconds
# Partition discourse: 0.000304937362671 seconds
# Create fuzzy number: 0.0013120174408 seconds
# Update fuzzy membership: 0.114147186279 seconds
# Update FLR: 0.000244855880737 seconds
# Update jump weights: 0.0174899101257 seconds
# Update transition weights: 0.000886917114258 seconds
# Assign membership for test case: 0.000255107879639 seconds
# Forecast next price: 0.000449895858765 seconds
# Update data: 0.00473499298096 seconds
# Partition discourse: 0.00094199180603 seconds
# Create fuzzy number: 0.00155305862427 seconds
# Update fuzzy membership: 0.102540016174 seconds
# Update FLR: 0.00023889541626 seconds
# Update jump weights: 0.0143151283264 seconds
# Update transition weights: 0.000671148300171 seconds
# Assign membership for test case: 0.00023889541626 seconds
# Forecast next price: 0.000453948974609 seconds
# Update data: 0.00317001342773 seconds
# Partition discourse: 0.000321865081787 seconds
# Create fuzzy number: 0.00119304656982 seconds
# Update fuzzy membership: 0.0961501598358 seconds
# Update FLR: 0.000236988067627 seconds
# Update jump weights: 0.014004945755 seconds
# Update transition weights: 0.000669002532959 seconds
# Assign membership for test case: 0.000233888626099 seconds
# Forecast next price: 0.00040602684021 seconds
# Update data: 0.00232100486755 seconds
# Partition discourse: 0.000298023223877 seconds
# Create fuzzy number: 0.00142407417297 seconds
# Update fuzzy membership: 0.104912996292 seconds
# Update FLR: 0.000397205352783 seconds
# Update jump weights: 0.0253880023956 seconds
# Update transition weights: 0.000965118408203 seconds
# Assign membership for test case: 0.000342130661011 seconds
# Forecast next price: 0.0010290145874 seconds
# Update data: 0.00504994392395 seconds
# Partition discourse: 0.000694036483765 seconds
# Create fuzzy number: 0.00294303894043 seconds
# Update fuzzy membership: 0.119061946869 seconds
# Update FLR: 0.000226020812988 seconds
# Update jump weights: 0.0184700489044 seconds
# Update transition weights: 0.000698804855347 seconds
# Assign membership for test case: 0.000245809555054 seconds
# Forecast next price: 0.000488042831421 seconds
# Update data: 0.00241613388062 seconds
# Partition discourse: 0.00042200088501 seconds
# Create fuzzy number: 0.00209021568298 seconds
# Update fuzzy membership: 0.109745979309 seconds
# Update FLR: 0.000179052352905 seconds
# Update jump weights: 0.0143849849701 seconds
# Update transition weights: 0.000675916671753 seconds
# Assign membership for test case: 0.000239849090576 seconds
# Forecast next price: 0.000433921813965 seconds
# Update data: 0.00274205207825 seconds
# Partition discourse: 0.000322818756104 seconds
# Create fuzzy number: 0.00133299827576 seconds
# Update fuzzy membership: 0.100728034973 seconds
# Update FLR: 0.000170946121216 seconds
# Update jump weights: 0.0145950317383 seconds
# Update transition weights: 0.000670194625854 seconds
# Assign membership for test case: 0.000236034393311 seconds
# Forecast next price: 0.000589847564697 seconds
# Update data: 0.00284194946289 seconds
# Partition discourse: 0.000308036804199 seconds
# Create fuzzy number: 0.00121998786926 seconds
# Update fuzzy membership: 0.0975050926208 seconds
# Update FLR: 0.000289916992188 seconds
# Update jump weights: 0.0152010917664 seconds
# Update transition weights: 0.000671863555908 seconds
# Assign membership for test case: 0.000232934951782 seconds
# Forecast next price: 0.000407934188843 seconds
# Update data: 0.0026741027832 seconds
# Partition discourse: 0.000343084335327 seconds
# Create fuzzy number: 0.00124597549438 seconds
# Update fuzzy membership: 0.0955891609192 seconds
# Update FLR: 0.000248908996582 seconds
# Update jump weights: 0.0144181251526 seconds
# Update transition weights: 0.000676155090332 seconds
# Assign membership for test case: 0.000243902206421 seconds
# Forecast next price: 0.000402927398682 seconds
# Update data: 0.00237011909485 seconds
# Partition discourse: 0.000303983688354 seconds
# Create fuzzy number: 0.0011899471283 seconds
# Update fuzzy membership: 0.098207950592 seconds
# Update FLR: 0.000174045562744 seconds
# Update jump weights: 0.0144040584564 seconds
# Update transition weights: 0.000671863555908 seconds
# Assign membership for test case: 0.000235080718994 seconds
# Forecast next price: 0.000406980514526 seconds
# Update data: 0.00233387947083 seconds
# Partition discourse: 0.000297069549561 seconds
# Create fuzzy number: 0.00119090080261 seconds
# Update fuzzy membership: 0.0961120128632 seconds
# Update FLR: 0.000174045562744 seconds
# Update jump weights: 0.0139858722687 seconds
# Update transition weights: 0.000707149505615 seconds
# Assign membership for test case: 0.000238180160522 seconds
# Forecast next price: 0.00042986869812 seconds
# Update data: 0.00234699249268 seconds
# Partition discourse: 0.000298023223877 seconds
# Create fuzzy number: 0.0011830329895 seconds
# Update fuzzy membership: 0.093729019165 seconds
# Update FLR: 0.000170230865479 seconds
# Update jump weights: 0.0139968395233 seconds
# Update transition weights: 0.000674962997437 seconds
# Assign membership for test case: 0.000234127044678 seconds
# Forecast next price: 0.00040602684021 seconds
# Update data: 0.00248098373413 seconds
# Partition discourse: 0.000316143035889 seconds
# Create fuzzy number: 0.00137901306152 seconds
# Update fuzzy membership: 0.0986220836639 seconds
# Update FLR: 0.000195026397705 seconds
# Update jump weights: 0.0149841308594 seconds
# Update transition weights: 0.000684022903442 seconds
# Assign membership for test case: 0.000288963317871 seconds
# Forecast next price: 0.000452995300293 seconds
# RMSE = 136.034952705
# Time cost: 35.0918178558 seconds

# %%
df_test = pd.DataFrame(test_data.iloc[1:]['Date'])
df_test['data testing'] = pd.Series(actual_prices).values
df_test['forecasting'] = pd.Series(pred_prices).values
df_test.index = df_test['Date']
plt.figure(figsize=(14,7))
df_test['data testing'].plot(style='k-', linewidth=2, label='data testing')
df_test['forecasting'].plot(style='g:', linewidth=3, label='forecasting')
plt.ylabel('Price', fontsize=18)
plt.legend(loc='best')
plt.title("IBEX35_forecasting", fontsize=24)
