# %% [markdown]
# Continue with v1, but dynamically update the parameters weekly (5 trading days per week)

# %%
from rectangle_fuzzy import *

import pandas as pd
import numpy as np
import operator
import matplotlib.pyplot as plt
# %matplotlib inline
from time import time

from collections import defaultdict
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error

# %%
# helper functions
def binary_to_decimal(binary, di=0):
    decimal = 0
    for i in range(len(binary)):
        if i<len(binary)-di+1:
            power = len(binary)-(i+1)-di
            decimal += int(binary[i]) * (2**power)
        else:
            power = len(binary)-(i+1)-di
            decimal += int(binary[i]) * (2**(-power))
    return decimal

def universe_partition_adjusted(data, n=10, d1=10, d2=10):
    x_max, x_min = data.max(axis=0), data.min(axis=0)   
    delta = x_max - x_min
    std_val = data.std(axis=0)
    len_val = np.round(std_val / (n+5)) # partition interval
    u_max, u_min = int(x_max+(d2+1)*(delta/100)), int(x_min-(d1+1)*(delta/100)) # bound of universe discourse
    u_b = np.arange(u_min, u_max, step=float(len_val)) # cutting points
    u_discourse = u_b
    return u_discourse

def compute_fitness(data, n, d1, d2, option='Price'):
    reserved_days = 200
    first_date = data['Date'][0] - pd.DateOffset(days=1)
    train_data = data.iloc[:-reserved_days]
    valid_data = data.iloc[-(reserved_days+1):]
    fit_prices = list()
    u_discourse = universe_partition_adjusted(train_data[option], n, d1, d2)
    A_list = set_fuzzy_numbers(u_discourse)
    train_data_membership_series = membership_assignment(train_data[option], fuzzy_numbers=u_discourse)
    transition_FLR = FLR(train_data_membership_series)
    train_data_days = train_data['Date'].apply(lambda x: x-first_date).dt.days.tolist()
    jump_weights = FLR_weight(transition_FLR, train_data_days[:len(transition_FLR)])
    transition_weights = FRG_weight(transition_FLR, train_data_days[:len(transition_FLR)])
    for price in valid_data.iloc[:-1][option]:
        index = get_membership(price, u_discourse)
        next_price = forecast_price(forecast_jump(index, jump_weights, A_list), forecast_transition(index, transition_weights, A_list), gamma=0.9)
        fit_prices.append(next_price)
    return np.sqrt(mean_squared_error(valid_data.iloc[1:][option], fit_prices))

def parameter_tuning_ASHLO(data, option):
    # initialize hyperparameters
    d1_digits = 4
    n_digits = 6
    d2_digits = 4
    population = 20
    iter_max = 100
    pr = 0.1
    pi = 0.9
    # initialize data structures
    dim_IKD = d1_digits+n_digits+d2_digits
    RMSE_list = list() # training data RMSE as fitness function value
    IKD = np.zeros((population, dim_IKD), dtype=int) # individual learning 
    SKD = np.array([]) # social network learning
    RMSE_min = 0 # best fitness value
    for i in range(population):
        for j in range(dim_IKD):
            r = np.random.rand()
            if r>0.5:
                IKD[i, j] = 0
            else:
                IKD[i, j] = 1
        d1 = binary_to_decimal(IKD[i, 0:d1_digits])
        d2 = binary_to_decimal(IKD[i, (d1_digits+n_digits): dim_IKD])
        n_par = binary_to_decimal(IKD[i, d1_digits:(d1_digits+n_digits)])
        rmse = compute_fitness(data, n_par, d1, d2)
        RMSE_list.append(rmse)
    RMSE_min = np.min(RMSE_list) # best individual fitness
    SKD = np.array(IKD[np.argmin(RMSE_list)])
    # learning iterations
    for iter_count in range(iter_max):
        temp_IKD = np.zeros((population, dim_IKD))
        temp_rmse_list = list()
        # learning process
        for i in range(population):
            for j in range(dim_IKD):
                p = np.random.rand()
                if p < pi:
                    r = np.random.rand()
                    if r > 0.5:
                        temp_IKD[i, j] = 1
                elif pi <= p <= pr:
                    temp_IKD[i,j] = IKD[i, j]
                else:
                    temp_IKD[i,j] = SKD[j]
        # update fitness of newly learned knowledge 
        for i in range(population):
            d1 = binary_to_decimal(temp_IKD[i, 0:d1_digits])
            d2 = binary_to_decimal(temp_IKD[i, (d1_digits+n_digits): dim_IKD])
            n_par = binary_to_decimal(temp_IKD[i, d1_digits:(d1_digits+n_digits)])
            rmse = compute_fitness(data, n_par, d1, d2)
            temp_rmse_list.append(rmse)

        # update knowledge base if necessary
        RMSE_max = np.max(RMSE_list) # worst individual fitness
        RMSE_max_index = np.argmax(RMSE_list)
        for i in range(population):
            if temp_rmse_list[i] < RMSE_max:
                IKD[RMSE_max_index] = temp_IKD[i]
                RMSE_list[RMSE_max_index] = temp_rmse_list[i]
                RMSE_max = np.max(RMSE_list)
                RMSE_max_index = np.argmax(RMSE_list)
        temp_rmse_min = np.min(RMSE_list) # best individual fitness
        if RMSE_min > temp_rmse_min:
            SKD = np.array(IKD[np.argmin(RMSE_list)])
            RMSE_min = temp_rmse_min
    # output optimal parameter settings        
    d1 = binary_to_decimal(SKD[0:d1_digits])
    d2 = binary_to_decimal(SKD[(d1_digits+n_digits): ])
    n_par = binary_to_decimal(SKD[d1_digits:(d1_digits+n_digits)])
    return d1, n_par, d2

# %%
# Load data 
start_time = time()
datafile = '../data/IBEX35.csv'
dateparse = lambda x: pd.datetime.strptime(x, '%m/%d/%y')
df = pd.read_csv(datafile, header=0, parse_dates=['Date'], date_parser=dateparse)

split_date = pd.datetime.strptime('2014-12-31', '%Y-%m-%d')
train_data = df[df['Date'] < split_date]
test_data = df[df['Date'] >= split_date]
first_date = train_data['Date'][0] - pd.DateOffset(days=1)

option = 'Price'
update_interval = 1 # days

# %%
# forecasting using test data
start_time = time()
pred_prices = list()
error_percentages = list() # percentage of forecasting residual
actual_prices = test_data[option].tolist()[1:]
indices = test_data.index
for i in range(len(indices)-1):
    print("Iteration #%s" % str(i))
    prev = test_data.iloc[i]
    train_data.append(prev)
    if (i % update_interval)==0:
        print("\tUpdate parameter setting and fuzzy sets ...")
        d1, n_par, d2 = parameter_tuning_ASHLO(train_data, option)
        print("\t\td1=%f, d2=%f, n=%f" % (d1, d2, n_par))
        u_discourse = universe_partition_adjusted(train_data[option], n_par, d1, d2)
        A_list = set_fuzzy_numbers(u_discourse)
        train_data_membership_series = membership_assignment(train_data[option], fuzzy_numbers=u_discourse)
        transition_FLR = FLR(train_data_membership_series)
        train_data_days = train_data['Date'].apply(lambda x: x-first_date).dt.days.tolist() # convert Timedelta to numeric days
        jump_weights = FLR_weight(transition_FLR, train_data_days[:len(transition_FLR)])
        transition_weights = FRG_weight(transition_FLR, train_data_days[:len(transition_FLR)])
    price = prev[option]
    index = get_membership(price, u_discourse)
    next_price = forecast_price(forecast_jump(index, jump_weights, A_list), forecast_transition(index, transition_weights, A_list), gamma=0.9)
    pred_prices.append(next_price)
    pred_ep = (np.abs(actual_prices[i] - next_price)/actual_prices[i])
    error_percentages.append(pred_ep)
    print("\t---- error percentage = %f" % pred_ep)
    
print "RMSE = "+str(np.sqrt(mean_squared_error(actual_prices, pred_prices)))
print("Average Error Percentage = %f" % np.mean(error_percentages))
print "Time cost: "+str(time()-start_time)+" seconds"
# Out:
# Iteration #0
# 	Update parameter setting and fuzzy sets ...
# 		d1=12.000000, d2=15.000000, n=57.000000
# 	---- error percentage = 0.011333
# Iteration #1
# 	Update parameter setting and fuzzy sets ...
# 		d1=3.000000, d2=15.000000, n=39.000000
# 	---- error percentage = 0.011935
# Iteration #2
# 	Update parameter setting and fuzzy sets ...
# 		d1=3.000000, d2=15.000000, n=39.000000
# 	---- error percentage = 0.022939
# Iteration #3
# 	Update parameter setting and fuzzy sets ...
# 		d1=7.000000, d2=15.000000, n=59.000000
# 	---- error percentage = 0.012149
# Iteration #4
# 	Update parameter setting and fuzzy sets ...
# 		d1=3.000000, d2=15.000000, n=40.000000
# 	---- error percentage = 0.009777
# Iteration #5
# 	Update parameter setting and fuzzy sets ...
# 		d1=3.000000, d2=15.000000, n=59.000000
# 	---- error percentage = 0.002379
# Iteration #6
# 	Update parameter setting and fuzzy sets ...
# 		d1=3.000000, d2=15.000000, n=39.000000
# 	---- error percentage = 0.028426
# Iteration #7
# 	Update parameter setting and fuzzy sets ...
# 		d1=3.000000, d2=15.000000, n=40.000000
# 	---- error percentage = 0.005051
# Iteration #8
# 	Update parameter setting and fuzzy sets ...
# 		d1=3.000000, d2=15.000000, n=59.000000
# 	---- error percentage = 0.003838
# Iteration #9
# 	Update parameter setting and fuzzy sets ...
# 		d1=3.000000, d2=15.000000, n=56.000000
# 	---- error percentage = 0.015011
# Iteration #10
# 	Update parameter setting and fuzzy sets ...
# 		d1=3.000000, d2=15.000000, n=59.000000
# 	---- error percentage = 0.001269
# Iteration #11
# 	Update parameter setting and fuzzy sets ...
# 		d1=3.000000, d2=15.000000, n=56.000000
# 	---- error percentage = 0.012925
# Iteration #12
# 	Update parameter setting and fuzzy sets ...
# 		d1=12.000000, d2=15.000000, n=58.000000
# 	---- error percentage = 0.009210
# Iteration #13
# 	Update parameter setting and fuzzy sets ...
# 		d1=3.000000, d2=15.000000, n=59.000000
# 	---- error percentage = 0.013099
# Iteration #14
# 	Update parameter setting and fuzzy sets ...
# 		d1=3.000000, d2=15.000000, n=40.000000
# 	---- error percentage = 0.004704
# Iteration #15
# 	Update parameter setting and fuzzy sets ...
# 		d1=3.000000, d2=15.000000, n=40.000000
# 	---- error percentage = 0.020289
# Iteration #16
# 	Update parameter setting and fuzzy sets ...
# 		d1=3.000000, d2=15.000000, n=40.000000
# 	---- error percentage = 0.009902
# Iteration #17
# 	Update parameter setting and fuzzy sets ...
# 		d1=13.000000, d2=15.000000, n=39.000000
# 	---- error percentage = 0.015129
# Iteration #18
# 	Update parameter setting and fuzzy sets ...
# 		d1=12.000000, d2=15.000000, n=58.000000
# 	---- error percentage = 0.000777
# Iteration #19
# 	Update parameter setting and fuzzy sets ...
# 		d1=3.000000, d2=15.000000, n=58.000000
# 	---- error percentage = 0.028264
# Iteration #20
# 	Update parameter setting and fuzzy sets ...
# 		d1=3.000000, d2=15.000000, n=57.000000
# 	---- error percentage = 0.015916
# Iteration #21
# 	Update parameter setting and fuzzy sets ...
# 		d1=12.000000, d2=15.000000, n=59.000000
# 	---- error percentage = 0.016262
# Iteration #22
# 	Update parameter setting and fuzzy sets ...
# 		d1=12.000000, d2=15.000000, n=58.000000
# 	---- error percentage = 0.002721
# Iteration #23
# 	Update parameter setting and fuzzy sets ...
# 		d1=3.000000, d2=15.000000, n=39.000000
# 	---- error percentage = 0.017856
# Iteration #24
# 	Update parameter setting and fuzzy sets ...
# 		d1=3.000000, d2=15.000000, n=57.000000
# 	---- error percentage = 0.014997
# Iteration #25
# 	Update parameter setting and fuzzy sets ...
# 		d1=12.000000, d2=15.000000, n=56.000000
# 	---- error percentage = 0.009184
# Iteration #26
# 	Update parameter setting and fuzzy sets ...
# 		d1=3.000000, d2=15.000000, n=57.000000
# 	---- error percentage = 0.007527
# Iteration #27
# 	Update parameter setting and fuzzy sets ...
# 		d1=12.000000, d2=15.000000, n=59.000000
# 	---- error percentage = 0.006455
# Iteration #28
# 	Update parameter setting and fuzzy sets ...
# 		d1=3.000000, d2=15.000000, n=39.000000
# 	---- error percentage = 0.010133
# Iteration #29
# 	Update parameter setting and fuzzy sets ...
# 		d1=3.000000, d2=15.000000, n=57.000000
# 	---- error percentage = 0.013931
# Iteration #30
# 	Update parameter setting and fuzzy sets ...
# 		d1=3.000000, d2=15.000000, n=39.000000
# 	---- error percentage = 0.024776
# Iteration #31
# 	Update parameter setting and fuzzy sets ...
# 		d1=3.000000, d2=15.000000, n=59.000000
# 	---- error percentage = 0.009169
# Iteration #32
# 	Update parameter setting and fuzzy sets ...
# 		d1=12.000000, d2=15.000000, n=57.000000
# 	---- error percentage = 0.012228
# Iteration #33
# 	Update parameter setting and fuzzy sets ...
# 		d1=3.000000, d2=15.000000, n=39.000000
# 	---- error percentage = 0.016079
# Iteration #34
# 	Update parameter setting and fuzzy sets ...
# 		d1=3.000000, d2=15.000000, n=59.000000
# 	---- error percentage = 0.000420
# Iteration #35
# 	Update parameter setting and fuzzy sets ...
# 		d1=12.000000, d2=15.000000, n=57.000000
# 	---- error percentage = 0.009697
# Iteration #36
# 	Update parameter setting and fuzzy sets ...
# 		d1=8.000000, d2=15.000000, n=40.000000
# 	---- error percentage = 0.010332
# Iteration #37
# 	Update parameter setting and fuzzy sets ...
# 		d1=3.000000, d2=15.000000, n=40.000000
# 	---- error percentage = 0.001913
# Iteration #38
# 	Update parameter setting and fuzzy sets ...
# 		d1=12.000000, d2=15.000000, n=56.000000
# 	---- error percentage = 0.000408
# Iteration #39
# 	Update parameter setting and fuzzy sets ...
# 		d1=12.000000, d2=15.000000, n=56.000000
# 	---- error percentage = 0.000826
# Iteration #40
# 	Update parameter setting and fuzzy sets ...
# 		d1=13.000000, d2=15.000000, n=39.000000
# 	---- error percentage = 0.011565
# Iteration #41
# 	Update parameter setting and fuzzy sets ...
# 		d1=12.000000, d2=15.000000, n=58.000000
# 	---- error percentage = 0.004225
# Iteration #42
# 	Update parameter setting and fuzzy sets ...
# 		d1=12.000000, d2=15.000000, n=56.000000
# 	---- error percentage = 0.000178
# Iteration #43
# 	Update parameter setting and fuzzy sets ...
# 		d1=13.000000, d2=15.000000, n=40.000000
# 	---- error percentage = 0.013571
# Iteration #44
# 	Update parameter setting and fuzzy sets ...
# 		d1=3.000000, d2=15.000000, n=59.000000
# 	---- error percentage = 0.002580
# Iteration #45
# 	Update parameter setting and fuzzy sets ...
# 		d1=3.000000, d2=15.000000, n=39.000000
# 	---- error percentage = 0.006988
# Iteration #46
# 	Update parameter setting and fuzzy sets ...
# 		d1=3.000000, d2=15.000000, n=58.000000
# 	---- error percentage = 0.012293
# Iteration #47
# 	Update parameter setting and fuzzy sets ...
# 		d1=8.000000, d2=15.000000, n=39.000000
# 	---- error percentage = 0.004398
# Iteration #48
# 	Update parameter setting and fuzzy sets ...
# 		d1=12.000000, d2=15.000000, n=56.000000
# 	---- error percentage = 0.009380
# Iteration #49
# 	Update parameter setting and fuzzy sets ...
# 		d1=12.000000, d2=15.000000, n=58.000000
# 	---- error percentage = 0.005801
# Iteration #50
# 	Update parameter setting and fuzzy sets ...
# 		d1=8.000000, d2=15.000000, n=39.000000
# 	---- error percentage = 0.003160
# Iteration #51
# 	Update parameter setting and fuzzy sets ...
# 		d1=3.000000, d2=15.000000, n=39.000000
# 	---- error percentage = 0.001423
# Iteration #52
# 	Update parameter setting and fuzzy sets ...
# 		d1=3.000000, d2=15.000000, n=40.000000
# 	---- error percentage = 0.001696
# Iteration #53
# 	Update parameter setting and fuzzy sets ...
# 		d1=12.000000, d2=15.000000, n=57.000000
# 	---- error percentage = 0.003581
# Iteration #54
# 	Update parameter setting and fuzzy sets ...
# 		d1=3.000000, d2=15.000000, n=58.000000
# 	---- error percentage = 0.001209
# Iteration #55
# 	Update parameter setting and fuzzy sets ...
# 		d1=3.000000, d2=15.000000, n=55.000000
# 	---- error percentage = 0.005334
# Iteration #56
# 	Update parameter setting and fuzzy sets ...
# 		d1=3.000000, d2=15.000000, n=40.000000
# 	---- error percentage = 0.025523
# Iteration #57
# 	Update parameter setting and fuzzy sets ...
# 		d1=12.000000, d2=15.000000, n=57.000000
# 	---- error percentage = 0.002353
# Iteration #58
# 	Update parameter setting and fuzzy sets ...
# 		d1=3.000000, d2=15.000000, n=58.000000
# 	---- error percentage = 0.011835
# Iteration #59
# 	Update parameter setting and fuzzy sets ...
# 		d1=3.000000, d2=15.000000, n=59.000000
# 	---- error percentage = 0.013964
# Iteration #60
# 	Update parameter setting and fuzzy sets ...
# 		d1=12.000000, d2=15.000000, n=57.000000
# 	---- error percentage = 0.005936
# Iteration #61
# 	Update parameter setting and fuzzy sets ...
# 		d1=3.000000, d2=15.000000, n=39.000000
# 	---- error percentage = 0.000307
# Iteration #62
# 	Update parameter setting and fuzzy sets ...
# 		d1=13.000000, d2=15.000000, n=39.000000
# 	---- error percentage = 0.005069
# Iteration #63
# 	Update parameter setting and fuzzy sets ...
# 		d1=3.000000, d2=15.000000, n=39.000000
# 	---- error percentage = 0.002061
# Iteration #64
# 	Update parameter setting and fuzzy sets ...
# 		d1=3.000000, d2=15.000000, n=58.000000
# 	---- error percentage = 0.008399
# Iteration #65
# 	Update parameter setting and fuzzy sets ...
# 		d1=3.000000, d2=15.000000, n=40.000000
# 	---- error percentage = 0.012662
# Iteration #66
# 	Update parameter setting and fuzzy sets ...
# 		d1=12.000000, d2=15.000000, n=59.000000
# 	---- error percentage = 0.008231
# Iteration #67
# 	Update parameter setting and fuzzy sets ...
# 		d1=3.000000, d2=15.000000, n=56.000000
# 	---- error percentage = 0.003289
# Iteration #68
# 	Update parameter setting and fuzzy sets ...
# 		d1=3.000000, d2=15.000000, n=55.000000
# 	---- error percentage = 0.010402
# Iteration #69
# 	Update parameter setting and fuzzy sets ...
# 		d1=3.000000, d2=15.000000, n=40.000000
# 	---- error percentage = 0.009128
# Iteration #70
# 	Update parameter setting and fuzzy sets ...
# 		d1=12.000000, d2=15.000000, n=55.000000
# 	---- error percentage = 0.012425
# Iteration #71
# 	Update parameter setting and fuzzy sets ...
# 		d1=12.000000, d2=15.000000, n=56.000000
# 	---- error percentage = 0.007707
# Iteration #72
# 	Update parameter setting and fuzzy sets ...
# 		d1=12.000000, d2=15.000000, n=58.000000
# 	---- error percentage = 0.010032
# Iteration #73
# 	Update parameter setting and fuzzy sets ...
# 		d1=12.000000, d2=15.000000, n=58.000000
# 	---- error percentage = 0.007669
# Iteration #74
# 	Update parameter setting and fuzzy sets ...
# 		d1=12.000000, d2=15.000000, n=55.000000
# 	---- error percentage = 0.014113
# Iteration #75
# 	Update parameter setting and fuzzy sets ...
# 		d1=3.000000, d2=15.000000, n=39.000000
# 	---- error percentage = 0.003794
# Iteration #76
# 	Update parameter setting and fuzzy sets ...
# 		d1=3.000000, d2=15.000000, n=59.000000
# 	---- error percentage = 0.001075
# Iteration #77
# 	Update parameter setting and fuzzy sets ...
# 		d1=3.000000, d2=15.000000, n=39.000000
# 	---- error percentage = 0.004013
# Iteration #78
# 	Update parameter setting and fuzzy sets ...
# 		d1=3.000000, d2=15.000000, n=40.000000
# 	---- error percentage = 0.004558
# Iteration #79
# 	Update parameter setting and fuzzy sets ...
# 		d1=3.000000, d2=15.000000, n=40.000000
# 	---- error percentage = 0.005956
# Iteration #80
# 	Update parameter setting and fuzzy sets ...
# 		d1=3.000000, d2=15.000000, n=39.000000
# 	---- error percentage = 0.011140
# Iteration #81
# 	Update parameter setting and fuzzy sets ...
# 		d1=3.000000, d2=15.000000, n=58.000000
# 	---- error percentage = 0.000664
# Iteration #82
# 	Update parameter setting and fuzzy sets ...
# 		d1=3.000000, d2=15.000000, n=39.000000
# 	---- error percentage = 0.022185
# Iteration #83
# 	Update parameter setting and fuzzy sets ...
# 		d1=3.000000, d2=15.000000, n=39.000000
# 	---- error percentage = 0.000132
# Iteration #84
# 	Update parameter setting and fuzzy sets ...
# 		d1=3.000000, d2=15.000000, n=55.000000
# 	---- error percentage = 0.006026
# Iteration #85
# 	Update parameter setting and fuzzy sets ...
# 		d1=3.000000, d2=15.000000, n=40.000000
# 	---- error percentage = 0.028550
# Iteration #86
# 	Update parameter setting and fuzzy sets ...
# 		d1=3.000000, d2=15.000000, n=55.000000
# 	---- error percentage = 0.002796
# Iteration #87
# 	Update parameter setting and fuzzy sets ...
# 		d1=3.000000, d2=15.000000, n=40.000000
# 	---- error percentage = 0.013996
# Iteration #88
# 	Update parameter setting and fuzzy sets ...
# 		d1=3.000000, d2=15.000000, n=57.000000
# 	---- error percentage = 0.014964
# Iteration #89
# 	Update parameter setting and fuzzy sets ...
# 		d1=3.000000, d2=15.000000, n=57.000000
# 	---- error percentage = 0.008766
# Iteration #90
# 	Update parameter setting and fuzzy sets ...
# 		d1=3.000000, d2=15.000000, n=57.000000
# 	---- error percentage = 0.003114
# Iteration #91
# 	Update parameter setting and fuzzy sets ...
# 		d1=3.000000, d2=15.000000, n=56.000000
# 	---- error percentage = 0.005308
# Iteration #92
# 	Update parameter setting and fuzzy sets ...
# 		d1=3.000000, d2=15.000000, n=39.000000
# 	---- error percentage = 0.011820
# Iteration #93
# 	Update parameter setting and fuzzy sets ...
# 		d1=3.000000, d2=15.000000, n=55.000000
# 	---- error percentage = 0.009839
# Iteration #94
# 	Update parameter setting and fuzzy sets ...
# 		d1=12.000000, d2=15.000000, n=59.000000
# 	---- error percentage = 0.005345
# Iteration #95
# 	Update parameter setting and fuzzy sets ...
# 		d1=12.000000, d2=15.000000, n=56.000000
# 	---- error percentage = 0.008995
# Iteration #96
# 	Update parameter setting and fuzzy sets ...
# 		d1=3.000000, d2=15.000000, n=40.000000
# 	---- error percentage = 0.001062
# Iteration #97
# 	Update parameter setting and fuzzy sets ...
# 		d1=3.000000, d2=15.000000, n=40.000000
# 	---- error percentage = 0.007679
# Iteration #98
# 	Update parameter setting and fuzzy sets ...
# 		d1=3.000000, d2=15.000000, n=58.000000
# 	---- error percentage = 0.014320
# Iteration #99
# 	Update parameter setting and fuzzy sets ...
# 		d1=3.000000, d2=15.000000, n=39.000000
# 	---- error percentage = 0.010641
# Iteration #100
# 	Update parameter setting and fuzzy sets ...
# 		d1=3.000000, d2=15.000000, n=59.000000
# 	---- error percentage = 0.001368
# Iteration #101
# 	Update parameter setting and fuzzy sets ...
# 		d1=3.000000, d2=15.000000, n=55.000000
# 	---- error percentage = 0.009510
# Iteration #102
# 	Update parameter setting and fuzzy sets ...
# 		d1=4.000000, d2=15.000000, n=21.000000
# 	---- error percentage = 0.002241
# Iteration #103
# 	Update parameter setting and fuzzy sets ...
# 		d1=12.000000, d2=15.000000, n=58.000000
# 	---- error percentage = 0.009972
# Iteration #104
# 	Update parameter setting and fuzzy sets ...
# 		d1=3.000000, d2=15.000000, n=39.000000
# 	---- error percentage = 0.005029
# Iteration #105
# 	Update parameter setting and fuzzy sets ...
# 		d1=13.000000, d2=15.000000, n=39.000000
# 	---- error percentage = 0.001127
# Iteration #106
# 	Update parameter setting and fuzzy sets ...
# 		d1=3.000000, d2=15.000000, n=39.000000
# 	---- error percentage = 0.009142
# Iteration #107
# 	Update parameter setting and fuzzy sets ...
# 		d1=3.000000, d2=15.000000, n=40.000000
# 	---- error percentage = 0.013569
# Iteration #108
# 	Update parameter setting and fuzzy sets ...
# 		d1=12.000000, d2=15.000000, n=58.000000
# 	---- error percentage = 0.002424
# Iteration #109
# 	Update parameter setting and fuzzy sets ...
# 		d1=13.000000, d2=15.000000, n=39.000000
# 	---- error percentage = 0.010925
# Iteration #110
# 	Update parameter setting and fuzzy sets ...
# 		d1=3.000000, d2=15.000000, n=39.000000
# 	---- error percentage = 0.000440
# Iteration #111
# 	Update parameter setting and fuzzy sets ...
# 		d1=3.000000, d2=15.000000, n=39.000000
# 	---- error percentage = 0.019185
# Iteration #112
# 	Update parameter setting and fuzzy sets ...
# 		d1=12.000000, d2=15.000000, n=56.000000
# 	---- error percentage = 0.002084
# Iteration #113
# 	Update parameter setting and fuzzy sets ...
# 		d1=3.000000, d2=15.000000, n=58.000000
# 	---- error percentage = 0.020887
# Iteration #114
# 	Update parameter setting and fuzzy sets ...
# 		d1=3.000000, d2=15.000000, n=40.000000
# 	---- error percentage = 0.011024
# Iteration #115
# 	Update parameter setting and fuzzy sets ...
# 		d1=3.000000, d2=15.000000, n=57.000000
# 	---- error percentage = 0.011245
# Iteration #116
# 	Update parameter setting and fuzzy sets ...
# 		d1=12.000000, d2=15.000000, n=57.000000
# 	---- error percentage = 0.010498
# Iteration #117
# 	Update parameter setting and fuzzy sets ...
# 		d1=12.000000, d2=15.000000, n=55.000000
# 	---- error percentage = 0.009779
# Iteration #118
# 	Update parameter setting and fuzzy sets ...
# 		d1=3.000000, d2=15.000000, n=40.000000
# 	---- error percentage = 0.026806
# Iteration #119
# 	Update parameter setting and fuzzy sets ...
# 		d1=12.000000, d2=15.000000, n=55.000000
# 	---- error percentage = 0.024682
# Iteration #120
# 	Update parameter setting and fuzzy sets ...
# 		d1=12.000000, d2=15.000000, n=58.000000
# 	---- error percentage = 0.003230
# Iteration #121
# 	Update parameter setting and fuzzy sets ...
# 		d1=3.000000, d2=15.000000, n=39.000000
# 	---- error percentage = 0.015324
# Iteration #122
# 	Update parameter setting and fuzzy sets ...
# 		d1=3.000000, d2=15.000000, n=39.000000
# 	---- error percentage = 0.001682
# Iteration #123
# 	Update parameter setting and fuzzy sets ...
# 		d1=12.000000, d2=15.000000, n=57.000000
# 	---- error percentage = 0.008989
# Iteration #124
# 	Update parameter setting and fuzzy sets ...
# 		d1=3.000000, d2=15.000000, n=57.000000
# 	---- error percentage = 0.030257
# Iteration #125
# 	Update parameter setting and fuzzy sets ...
# 		d1=12.000000, d2=15.000000, n=59.000000
# 	---- error percentage = 0.003883
# Iteration #126
# 	Update parameter setting and fuzzy sets ...
# 		d1=3.000000, d2=15.000000, n=40.000000
# 	---- error percentage = 0.005681
# Iteration #127
# 	Update parameter setting and fuzzy sets ...
# 		d1=3.000000, d2=15.000000, n=57.000000
# 	---- error percentage = 0.009247
# Iteration #128
# 	Update parameter setting and fuzzy sets ...
# 		d1=3.000000, d2=15.000000, n=39.000000
# 	---- error percentage = 0.025602
# Iteration #129
# 	Update parameter setting and fuzzy sets ...
# 		d1=3.000000, d2=15.000000, n=59.000000
# 	---- error percentage = 0.001470
# Iteration #130
# 	Update parameter setting and fuzzy sets ...
# 		d1=3.000000, d2=15.000000, n=39.000000
# 	---- error percentage = 0.019906
# Iteration #131
# 	Update parameter setting and fuzzy sets ...
# 		d1=3.000000, d2=15.000000, n=56.000000
# 	---- error percentage = 0.011890
# Iteration #132
# 	Update parameter setting and fuzzy sets ...
# 		d1=3.000000, d2=15.000000, n=55.000000
# 	---- error percentage = 0.044280
# Iteration #133
# 	Update parameter setting and fuzzy sets ...
# 		d1=3.000000, d2=15.000000, n=58.000000
# 	---- error percentage = 0.019614
# Iteration #134
# 	Update parameter setting and fuzzy sets ...
# 		d1=3.000000, d2=15.000000, n=40.000000
# 	---- error percentage = 0.002938
# Iteration #135
# 	Update parameter setting and fuzzy sets ...
# 		d1=3.000000, d2=15.000000, n=57.000000
# 	---- error percentage = 0.002966
# Iteration #136
# 	Update parameter setting and fuzzy sets ...
# 		d1=3.000000, d2=15.000000, n=40.000000
# 	---- error percentage = 0.012942
# Iteration #137
# 	Update parameter setting and fuzzy sets ...
# 		d1=3.000000, d2=15.000000, n=57.000000
# 	---- error percentage = 0.011831
# Iteration #138
# 	Update parameter setting and fuzzy sets ...
# 		d1=4.000000, d2=15.000000, n=21.000000
# 	---- error percentage = 0.003755
# Iteration #139
# 	Update parameter setting and fuzzy sets ...
# 		d1=8.000000, d2=15.000000, n=40.000000
# 	---- error percentage = 0.005267
# Iteration #140
# 	Update parameter setting and fuzzy sets ...
# 		d1=3.000000, d2=15.000000, n=40.000000
# 	---- error percentage = 0.015633
# Iteration #141
# 	Update parameter setting and fuzzy sets ...
# 		d1=3.000000, d2=15.000000, n=39.000000
# 	---- error percentage = 0.013539
# Iteration #142
# 	Update parameter setting and fuzzy sets ...
# 		d1=3.000000, d2=15.000000, n=39.000000
# 	---- error percentage = 0.011570
# Iteration #143
# 	Update parameter setting and fuzzy sets ...
# 		d1=3.000000, d2=15.000000, n=39.000000
# 	---- error percentage = 0.014629
# Iteration #144
# 	Update parameter setting and fuzzy sets ...
# 		d1=3.000000, d2=15.000000, n=40.000000
# 	---- error percentage = 0.006986
# Iteration #145
# 	Update parameter setting and fuzzy sets ...
# 		d1=3.000000, d2=15.000000, n=39.000000
# 	---- error percentage = 0.010863
# Iteration #146
# 	Update parameter setting and fuzzy sets ...
# 		d1=3.000000, d2=15.000000, n=40.000000
# 	---- error percentage = 0.003886
# Iteration #147
# 	Update parameter setting and fuzzy sets ...
# 		d1=3.000000, d2=15.000000, n=39.000000
# 	---- error percentage = 0.013502
# Iteration #148
# 	Update parameter setting and fuzzy sets ...
# 		d1=12.000000, d2=15.000000, n=56.000000
# 	---- error percentage = 0.001342
# Iteration #149
# 	Update parameter setting and fuzzy sets ...
# 		d1=12.000000, d2=15.000000, n=55.000000
# 	---- error percentage = 0.005489
# Iteration #150
# 	Update parameter setting and fuzzy sets ...
# 		d1=12.000000, d2=15.000000, n=58.000000
# 	---- error percentage = 0.004835
# Iteration #151
# 	Update parameter setting and fuzzy sets ...
# 		d1=3.000000, d2=15.000000, n=57.000000
# 	---- error percentage = 0.006304
# Iteration #152
# 	Update parameter setting and fuzzy sets ...
# 		d1=3.000000, d2=15.000000, n=58.000000
# 	---- error percentage = 0.001799
# Iteration #153
# 	Update parameter setting and fuzzy sets ...
# 		d1=3.000000, d2=15.000000, n=39.000000
# 	---- error percentage = 0.001610
# Iteration #154
# 	Update parameter setting and fuzzy sets ...
# 		d1=3.000000, d2=15.000000, n=55.000000
# 	---- error percentage = 0.002917
# Iteration #155
# 	Update parameter setting and fuzzy sets ...
# 		d1=12.000000, d2=15.000000, n=56.000000
# 	---- error percentage = 0.020645
# Iteration #156
# 	Update parameter setting and fuzzy sets ...
# 		d1=12.000000, d2=15.000000, n=55.000000
# 	---- error percentage = 0.002014
# Iteration #157
# 	Update parameter setting and fuzzy sets ...
# 		d1=12.000000, d2=15.000000, n=57.000000
# 	---- error percentage = 0.007304
# Iteration #158
# 	Update parameter setting and fuzzy sets ...
# 		d1=3.000000, d2=15.000000, n=40.000000
# 	---- error percentage = 0.002495
# Iteration #159
# 	Update parameter setting and fuzzy sets ...
# 		d1=12.000000, d2=15.000000, n=57.000000
# 	---- error percentage = 0.009818
# Iteration #160
# 	Update parameter setting and fuzzy sets ...
# 		d1=3.000000, d2=15.000000, n=40.000000
# 	---- error percentage = 0.003780
# Iteration #161
# 	Update parameter setting and fuzzy sets ...
# 		d1=12.000000, d2=15.000000, n=55.000000
# 	---- error percentage = 0.008703
# Iteration #162
# 	Update parameter setting and fuzzy sets ...
# 		d1=12.000000, d2=15.000000, n=58.000000
# 	---- error percentage = 0.030332
# Iteration #163
# 	Update parameter setting and fuzzy sets ...
# 		d1=3.000000, d2=15.000000, n=55.000000
# 	---- error percentage = 0.045895
# Iteration #164
# 	Update parameter setting and fuzzy sets ...
# 		d1=12.000000, d2=15.000000, n=56.000000
# 	---- error percentage = 0.009794
# Iteration #165
# 	Update parameter setting and fuzzy sets ...
# 		d1=3.000000, d2=15.000000, n=59.000000
# 	---- error percentage = 0.010353
# Iteration #166
# 	Update parameter setting and fuzzy sets ...
# 		d1=3.000000, d2=15.000000, n=40.000000
# 	---- error percentage = 0.020959
# Iteration #167
# 	Update parameter setting and fuzzy sets ...
# 		d1=3.000000, d2=15.000000, n=40.000000
# 	---- error percentage = 0.008885
# Iteration #168
# 	Update parameter setting and fuzzy sets ...
# 		d1=13.000000, d2=15.000000, n=40.000000
# 	---- error percentage = 0.002731
# Iteration #169
# 	Update parameter setting and fuzzy sets ...
# 		d1=12.000000, d2=15.000000, n=58.000000
# 	---- error percentage = 0.017092
# Iteration #170
# 	Update parameter setting and fuzzy sets ...
# 		d1=12.000000, d2=15.000000, n=55.000000
# 	---- error percentage = 0.014027
# Iteration #171
# 	Update parameter setting and fuzzy sets ...
# 		d1=12.000000, d2=15.000000, n=56.000000
# 	---- error percentage = 0.000717
# Iteration #172
# 	Update parameter setting and fuzzy sets ...
# 		d1=3.000000, d2=15.000000, n=59.000000
# 	---- error percentage = 0.008956
# Iteration #173
# 	Update parameter setting and fuzzy sets ...
# 		d1=8.000000, d2=15.000000, n=40.000000
# 	---- error percentage = 0.006430
# Iteration #174
# 	Update parameter setting and fuzzy sets ...
# 		d1=12.000000, d2=15.000000, n=56.000000
# 	---- error percentage = 0.003779
# Iteration #175
# 	Update parameter setting and fuzzy sets ...
# 		d1=12.000000, d2=15.000000, n=59.000000
# 	---- error percentage = 0.021635
# Iteration #176
# 	Update parameter setting and fuzzy sets ...
# 		d1=8.000000, d2=15.000000, n=40.000000
# 	---- error percentage = 0.016323
# Iteration #177
# 	Update parameter setting and fuzzy sets ...
# 		d1=3.000000, d2=15.000000, n=56.000000
# 	---- error percentage = 0.007036
# Iteration #178
# 	Update parameter setting and fuzzy sets ...
# 		d1=3.000000, d2=15.000000, n=58.000000
# 	---- error percentage = 0.010738
# Iteration #179
# 	Update parameter setting and fuzzy sets ...
# 		d1=3.000000, d2=15.000000, n=58.000000
# 	---- error percentage = 0.005746
# Iteration #180
# 	Update parameter setting and fuzzy sets ...
# 		d1=3.000000, d2=15.000000, n=40.000000
# 	---- error percentage = 0.014829
# Iteration #181
# 	Update parameter setting and fuzzy sets ...
# 		d1=3.000000, d2=15.000000, n=40.000000
# 	---- error percentage = 0.013831
# Iteration #182
# 	Update parameter setting and fuzzy sets ...
# 		d1=3.000000, d2=15.000000, n=58.000000
# 	---- error percentage = 0.003045
# Iteration #183
# 	Update parameter setting and fuzzy sets ...
# 		d1=3.000000, d2=15.000000, n=39.000000
# 	---- error percentage = 0.025051
# Iteration #184
# 	Update parameter setting and fuzzy sets ...
# 		d1=13.000000, d2=15.000000, n=40.000000
# 	---- error percentage = 0.002609
# Iteration #185
# 	Update parameter setting and fuzzy sets ...
# 		d1=3.000000, d2=15.000000, n=59.000000
# 	---- error percentage = 0.034814
# Iteration #186
# 	Update parameter setting and fuzzy sets ...
# 		d1=13.000000, d2=15.000000, n=39.000000
# 	---- error percentage = 0.001868
# Iteration #187
# 	Update parameter setting and fuzzy sets ...
# 		d1=3.000000, d2=15.000000, n=40.000000
# 	---- error percentage = 0.004489
# Iteration #188
# 	Update parameter setting and fuzzy sets ...
# 		d1=12.000000, d2=15.000000, n=57.000000
# 	---- error percentage = 0.005714
# Iteration #189
# 	Update parameter setting and fuzzy sets ...
# 		d1=12.000000, d2=15.000000, n=55.000000
# 	---- error percentage = 0.025264
# Iteration #190
# 	Update parameter setting and fuzzy sets ...
# 		d1=3.000000, d2=15.000000, n=40.000000
# 	---- error percentage = 0.031713
# Iteration #191
# 	Update parameter setting and fuzzy sets ...
# 		d1=3.000000, d2=15.000000, n=59.000000
# 	---- error percentage = 0.008664
# Iteration #192
# 	Update parameter setting and fuzzy sets ...
# 		d1=8.000000, d2=15.000000, n=40.000000
# 	---- error percentage = 0.003313
# Iteration #193
# 	Update parameter setting and fuzzy sets ...
# 		d1=7.000000, d2=15.000000, n=59.000000
# 	---- error percentage = 0.012903
# Iteration #194
# 	Update parameter setting and fuzzy sets ...
# 		d1=12.000000, d2=15.000000, n=56.000000
# 	---- error percentage = 0.022048
# Iteration #195
# 	Update parameter setting and fuzzy sets ...
# 		d1=7.000000, d2=15.000000, n=55.000000
# 	---- error percentage = 0.015882
# Iteration #196
# 	Update parameter setting and fuzzy sets ...
# 		d1=12.000000, d2=15.000000, n=57.000000
# 	---- error percentage = 0.003617
# Iteration #197
# 	Update parameter setting and fuzzy sets ...
# 		d1=3.000000, d2=15.000000, n=40.000000
# 	---- error percentage = 0.014231
# Iteration #198
# 	Update parameter setting and fuzzy sets ...
# 		d1=3.000000, d2=15.000000, n=21.000000
# 	---- error percentage = 0.004045
# Iteration #199
# 	Update parameter setting and fuzzy sets ...
# 		d1=3.000000, d2=15.000000, n=56.000000
# 	---- error percentage = 0.009694
# Iteration #200
# 	Update parameter setting and fuzzy sets ...
# 		d1=3.000000, d2=15.000000, n=56.000000
# 	---- error percentage = 0.016991
# Iteration #201
# 	Update parameter setting and fuzzy sets ...
# 		d1=3.000000, d2=15.000000, n=39.000000
# 	---- error percentage = 0.005906
# Iteration #202
# 	Update parameter setting and fuzzy sets ...
# 		d1=12.000000, d2=15.000000, n=56.000000
# 	---- error percentage = 0.002437
# Iteration #203
# 	Update parameter setting and fuzzy sets ...
# 		d1=3.000000, d2=15.000000, n=40.000000
# 	---- error percentage = 0.004769
# Iteration #204
# 	Update parameter setting and fuzzy sets ...
# 		d1=3.000000, d2=15.000000, n=59.000000
# 	---- error percentage = 0.003817
# Iteration #205
# 	Update parameter setting and fuzzy sets ...
# 		d1=12.000000, d2=15.000000, n=56.000000
# 	---- error percentage = 0.006497
# Iteration #206
# 	Update parameter setting and fuzzy sets ...
# 		d1=12.000000, d2=15.000000, n=55.000000
# 	---- error percentage = 0.000287
# Iteration #207
# 	Update parameter setting and fuzzy sets ...
# 		d1=12.000000, d2=15.000000, n=57.000000
# 	---- error percentage = 0.030862
# Iteration #208
# 	Update parameter setting and fuzzy sets ...
# 		d1=12.000000, d2=15.000000, n=57.000000
# 	---- error percentage = 0.002260
# Iteration #209
# 	Update parameter setting and fuzzy sets ...
# 		d1=3.000000, d2=15.000000, n=40.000000
# 	---- error percentage = 0.000888
# Iteration #210
# 	Update parameter setting and fuzzy sets ...
# 		d1=12.000000, d2=15.000000, n=57.000000
# 	---- error percentage = 0.013324
# Iteration #211
# 	Update parameter setting and fuzzy sets ...
# 		d1=3.000000, d2=15.000000, n=40.000000
# 	---- error percentage = 0.012967
# Iteration #212
# 	Update parameter setting and fuzzy sets ...
# 		d1=3.000000, d2=15.000000, n=58.000000
# 	---- error percentage = 0.005715
# Iteration #213
# 	Update parameter setting and fuzzy sets ...
# 		d1=3.000000, d2=15.000000, n=40.000000
# 	---- error percentage = 0.012155
# Iteration #214
# 	Update parameter setting and fuzzy sets ...
# 		d1=3.000000, d2=15.000000, n=40.000000
# 	---- error percentage = 0.010351
# Iteration #215
# 	Update parameter setting and fuzzy sets ...
# 		d1=3.000000, d2=15.000000, n=40.000000
# 	---- error percentage = 0.011455
# Iteration #216
# 	Update parameter setting and fuzzy sets ...
# 		d1=3.000000, d2=15.000000, n=40.000000
# 	---- error percentage = 0.003027
# Iteration #217
# 	Update parameter setting and fuzzy sets ...
# 		d1=3.000000, d2=15.000000, n=59.000000
# 	---- error percentage = 0.005006
# Iteration #218
# 	Update parameter setting and fuzzy sets ...
# 		d1=3.000000, d2=15.000000, n=59.000000
# 	---- error percentage = 0.001497
# Iteration #219
# 	Update parameter setting and fuzzy sets ...
# 		d1=12.000000, d2=15.000000, n=56.000000
# 	---- error percentage = 0.008320
# Iteration #220
# 	Update parameter setting and fuzzy sets ...
# 		d1=3.000000, d2=15.000000, n=40.000000
# 	---- error percentage = 0.000998
# Iteration #221
# 	Update parameter setting and fuzzy sets ...
# 		d1=3.000000, d2=15.000000, n=40.000000
# 	---- error percentage = 0.001665
# Iteration #222
# 	Update parameter setting and fuzzy sets ...
# 		d1=3.000000, d2=15.000000, n=40.000000
# 	---- error percentage = 0.023435
# Iteration #223
# 	Update parameter setting and fuzzy sets ...
# 		d1=12.000000, d2=15.000000, n=58.000000
# 	---- error percentage = 0.011712
# Iteration #224
# 	Update parameter setting and fuzzy sets ...
# 		d1=3.000000, d2=15.000000, n=56.000000
# 	---- error percentage = 0.019347
# Iteration #225
# 	Update parameter setting and fuzzy sets ...
# 		d1=12.000000, d2=15.000000, n=55.000000
# 	---- error percentage = 0.008091
# Iteration #226
# 	Update parameter setting and fuzzy sets ...
# 		d1=3.000000, d2=15.000000, n=40.000000
# 	---- error percentage = 0.004790
# Iteration #227
# 	Update parameter setting and fuzzy sets ...
# 		d1=12.000000, d2=15.000000, n=56.000000
# 	---- error percentage = 0.002415
# Iteration #228
# 	Update parameter setting and fuzzy sets ...
# 		d1=3.000000, d2=15.000000, n=40.000000
# 	---- error percentage = 0.012418
# Iteration #229
# 	Update parameter setting and fuzzy sets ...
# 		d1=12.000000, d2=15.000000, n=57.000000
# 	---- error percentage = 0.003683
# Iteration #230
# 	Update parameter setting and fuzzy sets ...
# 		d1=12.000000, d2=15.000000, n=58.000000
# 	---- error percentage = 0.005067
# Iteration #231
# 	Update parameter setting and fuzzy sets ...
# 		d1=3.000000, d2=15.000000, n=58.000000
# 	---- error percentage = 0.002696
# Iteration #232
# 	Update parameter setting and fuzzy sets ...
# 		d1=3.000000, d2=15.000000, n=55.000000
# 	---- error percentage = 0.004800
# Iteration #233
# 	Update parameter setting and fuzzy sets ...
# 		d1=3.000000, d2=15.000000, n=40.000000
# 	---- error percentage = 0.000780
# Iteration #234
# 	Update parameter setting and fuzzy sets ...
# 		d1=3.000000, d2=15.000000, n=39.000000
# 	---- error percentage = 0.011425
# Iteration #235
# 	Update parameter setting and fuzzy sets ...
# 		d1=3.000000, d2=15.000000, n=39.000000
# 	---- error percentage = 0.000735
# Iteration #236
# 	Update parameter setting and fuzzy sets ...
# 		d1=3.000000, d2=15.000000, n=40.000000
# 	---- error percentage = 0.004911
# Iteration #237
# 	Update parameter setting and fuzzy sets ...
# 		d1=3.000000, d2=15.000000, n=56.000000
# 	---- error percentage = 0.030728
# Iteration #238
# 	Update parameter setting and fuzzy sets ...
# 		d1=3.000000, d2=15.000000, n=40.000000
# 	---- error percentage = 0.009134
# Iteration #239
# 	Update parameter setting and fuzzy sets ...
# 		d1=12.000000, d2=15.000000, n=55.000000
# 	---- error percentage = 0.012075
# Iteration #240
# 	Update parameter setting and fuzzy sets ...
# 		d1=12.000000, d2=15.000000, n=56.000000
# 	---- error percentage = 0.016272
# Iteration #241
# 	Update parameter setting and fuzzy sets ...
# 		d1=12.000000, d2=15.000000, n=57.000000
# 	---- error percentage = 0.009054
# Iteration #242
# 	Update parameter setting and fuzzy sets ...
# 		d1=3.000000, d2=15.000000, n=58.000000
# 	---- error percentage = 0.000594
# Iteration #243
# 	Update parameter setting and fuzzy sets ...
# 		d1=12.000000, d2=15.000000, n=56.000000
# 	---- error percentage = 0.011999
# Iteration #244
# 	Update parameter setting and fuzzy sets ...
# 		d1=12.000000, d2=15.000000, n=59.000000
# 	---- error percentage = 0.017779
# Iteration #245
# 	Update parameter setting and fuzzy sets ...
# 		d1=3.000000, d2=15.000000, n=40.000000
# 	---- error percentage = 0.024321
# Iteration #246
# 	Update parameter setting and fuzzy sets ...
# 		d1=12.000000, d2=15.000000, n=57.000000
# 	---- error percentage = 0.013645
# Iteration #247
# 	Update parameter setting and fuzzy sets ...
# 		d1=7.000000, d2=15.000000, n=55.000000
# 	---- error percentage = 0.012041
# Iteration #248
# 	Update parameter setting and fuzzy sets ...
# 		d1=3.000000, d2=15.000000, n=57.000000
# 	---- error percentage = 0.029745
# Iteration #249
# 	Update parameter setting and fuzzy sets ...
# 		d1=12.000000, d2=15.000000, n=55.000000
# 	---- error percentage = 0.007152
# Iteration #250
# 	Update parameter setting and fuzzy sets ...
# 		d1=3.000000, d2=15.000000, n=40.000000
# 	---- error percentage = 0.005057
# Iteration #251
# 	Update parameter setting and fuzzy sets ...
# 		d1=12.000000, d2=15.000000, n=59.000000
# 	---- error percentage = 0.014660
# Iteration #252
# 	Update parameter setting and fuzzy sets ...
# 		d1=3.000000, d2=15.000000, n=39.000000
# 	---- error percentage = 0.000402
# Iteration #253
# 	Update parameter setting and fuzzy sets ...
# 		d1=3.000000, d2=15.000000, n=39.000000
# 	---- error percentage = 0.007053
# Iteration #254
# 	Update parameter setting and fuzzy sets ...
# 		d1=12.000000, d2=15.000000, n=56.000000
# 	---- error percentage = 0.004545
# Iteration #255
# 	Update parameter setting and fuzzy sets ...
# 		d1=8.000000, d2=15.000000, n=40.000000
# 	---- error percentage = 0.005146
# RMSE = 133.877239541
# Average Error Percentage = 0.009862
# Time cost: 26140.3959558 seconds

# %%
df_test = pd.DataFrame(test_data.iloc[1:]['Date'])
df_test['data testing'] = pd.Series(actual_prices).values
df_test['forecasting'] = pd.Series(pred_prices).values
df_test.index = df_test['Date']
plt.figure(figsize=(14,7))
df_test['data testing'].plot(style='k-', linewidth=2, label='data testing')
df_test['forecasting'].plot(style='g:', linewidth=3, label='forecasting')
plt.ylabel('Price', fontsize=18)
plt.legend(loc='best')
plt.title("IBEX35_forecasting", fontsize=24)
